# %% [markdown]
# # Jira Board Connection

# %% [markdown]
# # Needs Kernel Python 3.14.0

# %%
#! pip3 install jira
#! python3 -m pip install jira
# ! pip3 install tabulate
#! pip3 install fpdf
#! pip3 install seaborn
#! pip3 install tabulate

# %% [markdown]
# ## --- Import Libraries ---

# %%
# Import necessary libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np # For grouped bar chart calculations
from collections import defaultdict, Counter
from jira import JIRA
from getpass import getpass # To securely get the API token
import json
import sys # To exit gracefully on error
import seaborn as sns
from tabulate import tabulate
from datetime import date
import numpy as np
import datetime
from fpdf import FPDF # Using fpdf2 is recommended for more features (pip install fpdf2)
                     # If using original fpdf (pip install fpdf), some advanced multi_cell args might not be available
                     # but the core logic for table drawing will be similar.

# %% [markdown]
# ## --- Read the Local Credentials Json file ---

# %%
# --- Configuration File Handling ---
CONFIG_FILENAME = "config.json"

def load_config(filepath=CONFIG_FILENAME):
    """
    Loads configuration data from a JSON file.

    Args:
        filepath (str): The path to the configuration file.
                        Defaults to CONFIG_FILENAME in the script's directory.

    Returns:
        dict: A dictionary containing the configuration data.
            Returns None if the file cannot be read or parsed.
    """
    config_path = os.path.join(os.getcwd(), filepath) # Look in the current working directory

    if not os.path.exists(config_path):
        print(f"Error: Configuration file not found at '{config_path}'")
        print("Please create the file with your Jira server, email, and API token.")
        return None

    try:
        with open(config_path, 'r') as f:
            config_data = json.load(f)
            # Basic validation (check if essential keys exist)
            required_keys = ["jira_server", "jira_email", "jira_api_token"]
            if not all(key in config_data for key in required_keys):
                missing = [key for key in required_keys if key not in config_data]
                print(f"Error: Configuration file '{config_path}' is missing required keys: {missing}")
                return None
            # Optional: Add more specific validation (e.g., check if token is not empty)
            if not config_data.get("jira_api_token"):
                print(f"Error: 'jira_api_token' found in '{config_path}' but it is empty.")
                return None

            print(f"Successfully loaded configuration from '{config_path}'")
            return config_data

    except json.JSONDecodeError as e:
        print(f"Error: Could not parse JSON in configuration file '{config_path}'.")
        print(f"Details: {e}")
        return None
    except Exception as e:
        print(f"Error: An unexpected error occurred while reading '{config_path}'.")
        print(f"Details: {e}")
        return None

# %%
# Load configuration at the start
config = load_config()

if config is None:
    print("Exiting due to configuration error.")
    sys.exit(1) # Exit with a non-zero code indicating an error

# Now access credentials from the loaded config dictionary
jira_server = config.get("jira_server")
jira_email = config.get("jira_email")
jira_token = config.get("jira_api_token")

# --- You can now use these variables in your Jira connection logic ---
# (Example snippet from previous code)
# from jira import JIRA

# print(f"\nConnecting to Jira at {JIRA_SERVER} using credentials from config...")
# try:
#     jira_options = {'server': JIRA_SERVER}
#     # Use the loaded credentials for basic_auth
#     jira = JIRA(options=jira_options, basic_auth=(JIRA_EMAIL, JIRA_API_TOKEN))
#     print("Successfully connected to Jira.")
#     # ... rest of your Jira interaction code ...

# except Exception as e:
#     print(f"Failed to connect to Jira: {e}")
#     sys.exit(1)

# --- Placeholder for rest of your script ---
print("\nCredentials loaded:")
#print(f"  Server: {jira_server}")
#print(f"  Email: {jira_email}")
# Avoid printing the token itself for security!
#print(f"  API Token: {'*' * len(jira_token) if jira_token else 'Not Loaded'}")

# ... (Your code to fetch issues, visualize, etc. would go here) ...

print("\nScript finished executing.")
# --- End of Configuration File Handling ---
# Out:
# Successfully loaded configuration from '/Users/jorge.rodriguez/Library/CloudStorage/GoogleDrive-jorge.rodriguez@audacy.com/My Drive/GitHub/Jira-1/config.json'
#
# Credentials loaded:
#
# Script finished executing.

# %% [markdown]
# ## --- Validate Connection to the Jira Server ---

# %%
# Authentication
# Jira server URL
#jira_server = "https://xxxxxxxxxx"  # Replace with your Jira instance URL
# Authentication options
# Option 1: Using Personal Access Token (PAT) - Recommended for Jira Cloud
#jira_email = "xxxxxxxxx"  # Replace with your Jira email address
#jira_token = "xxxxxxxxx"  # Replace with your Jira API token

auth_type = "pat"

jira_options = {'server': jira_server}

try:
    if auth_type == "pat":
        jira = JIRA(options=jira_options, basic_auth=(jira_email, jira_token))
        print(f"Successfully connected to Jira at {jira_server} using Personal Access Token.")
    elif auth_type == "basic":
        jira = JIRA(options=jira_options, basic_auth=(jira_username, jira_password))
        print(f"Successfully connected to Jira at {jira_server} using Basic Authentication.")
    else:
        print("Invalid authentication type selected.")
except Exception as e:
    print(f"Error connecting to Jira or accessing boards: {e}")
# Out:
# Successfully connected to Jira at https://entercomdigitalservices.atlassian.net using Personal Access Token.

# %% [markdown]
# ## --- Get a list of all the Jira Boards ---

# %%
# Get all boards
boards = jira.boards()
print("\n--- All Boards ---")
for board in boards:
    print(f"ID: {board.id}, Name: {board.name}")
print(f"\nTotal Boards Found: {len(boards)}")
# Get all projects
projects = jira.projects()
print("\n--- All Projects ---")
for project in projects:
    print(f"Key: {project.key}, Name: {project.name}")
print(f"\nTotal Projects Found: {len(projects)}")
# Out:
# --- All Boards ---
# ID: 1184, Name: EIT Kanban Board
# ID: 1052, Name: ADT Board Current
# ID: 1085, Name: Central BI Scrum Board
# ID: 1118, Name: STG Kanban Board
# ID: 1151, Name: NetOps Engineering
# ID: 478, Name: AW AdTech Scrum Board
# ID: 1349, Name: DAC AI Labs Scrum Board
# ID: 1316, Name: ST&AWPOD_QA_Legends
# ID: 1283, Name: ST&AWPOD_QualityForge
# ID: 187, Name: Product Ops (Kanban)
# ID: 637, Name: DPM Planning v3
# ID: 346, Name: UPMS Scrum Board
# ID: 281, Name: RDC RW
# ID: 343, Name: Unity Support Bugs  (WIP)
# ID: 255, Name: Management Board
# ID: 446, Name: Scrum Board for PMO Test Project
# ID: 383, Name: EPMO Kanban Board
# ID: 508, Name: Work & Co
# ID: 551, Name: Ops A2 Readiness
# ID: 286, Name: SAFe Feature Design Status
# ID: 359, Name: INIT board
# ID: 326, Name: DRAUTO KANBAN
# ID: 387, Name: Lodge QAE
# ID: 388, Name: On Demand Kanban Board
# ID: 304, Name: MARKETOPS board
# ID: 303, Name: ENGSUPPORT board
# ID: 302, Name: Marconi Epics
# ID: 340, Name: UMS
# ID: 297, Name: UNITY Dev Velocity
# ID: 174, Name: Audio Admin
# ID: 322, Name: VE board
# ID: 394, Name: Roc Lite
# ID: 344, Name: BASS Scrum Board
# ID: 402, Name: Marconi Release Prep
# ID: 491, Name: Design
# ID: 351, Name: Data Engineering Scrum Board
# ID: 441, Name: Data Engineering Kanban
# ID: 431, Name: Audio Admin Scrum Board
# ID: 436, Name: Content Review Board
# ID: 318, Name: QA Team Board
# ID: 314, Name: Epic Scrum Board
# ID: 315, Name: Back Up
# ID: 316, Name: WOPR
# ID: 325, Name: DROID Auto Scrum Board
# ID: 360, Name: SecOps Engineering
# ID: 639, Name: AWFE Only (No AWPOD)
# ID: 331, Name: Cadence13
# ID: 324, Name: Streaming Ops Kanban
# ID: 275, Name: Eventful Epic Kanban Board
# ID: 269, Name: Admin Epic Kanban Board
#
# Total Boards Found: 50
#
# --- All Projects ---
# Key: GAT, Name: Global App Testing
# Key: ELS, Name: Eventful Lift & Shift
# Key: TAP, Name: TapClicks
# Key: TSUITE, Name: Track Suite
# Key: REL, Name: Release Mgmt
# Key: PMO, Name: Den-Eng-PMO
# Key: VE, Name: Video Engineering
# Key: CAR, Name: Release Management
# Key: DRAUTO, Name: DROIDAUTO
# Key: TPFP, Name: Demo Project for the PMO
# Key: IMP, Name: Incident Management Process
# Key: C13, Name: Cadence13
# Key: PDLC, Name: Product Development
# Key: CS, Name: Client Services
# Key: UPMS, Name: User Profile Management System
# Key: COBRA, Name: COBRA
# Key: SECOPS, Name: Security Operations
# Key: CBI, Name: Central BI
# Key: DE, Name: Data Engineering
# Key: INIT, Name: Initiative
# Key: ARDVRK, Name: Aardvark
# Key: MOC, Name: Marconi Ops Center
# Key: DIGI, Name: Exclusive Stations (fka Digital Stations)
# Key: OD, Name: On Demand
# Key: EPMO, Name: PMO
# Key: DAT, Name: DataTeam
# Key: SCOTT, Name: Scott Ennover Task Tracking Test Project
# Key: TOKN, Name: Token
# Key: PODSERVE, Name: PodCatcher Service
# Key: WTP, Name: Workflow Test Project
# Key: TMPT, Name: Team Managed Project Test Project
# Key: NET, Name: New Engineering Initiatives
# Key: GITLAB, Name: GitLab
# Key: MES, Name: Marketing Exclusive Stations
# Key: MAC, Name: Mobile App Client
# Key: PAVEL, Name: Pavel's Project
# Key: WWTAPI, Name: WWT-API
# Key: BRAQ, Name: Booster Rocket Audacy QA
# Key: BOOST, Name: Booster Rocket
# Key: AARB, Name: Audacy Architecture Review Board
# Key: CDB, Name: Content Decision Board
# Key: TW, Name: Tech Writing
# Key: PRODTRI, Name: Product Problem Triage
# Key: PAC, Name: Project Pacific
# Key: STG, Name: STG (Snowflake to GCP Migration)
# Key: PTPTEST, Name: ProdOps - Project Templates
# Key: AWPOD, Name: AmperWave Podcasting
# Key: ADTECH, Name: AmperWave AdTech
# Key: AW, Name: AmperWave
# Key: AWSTR, Name: AmperWave Streaming
# Key: AWQA, Name: AmperWave QA
# Key: AWST, Name:  AmperWave Support Tools
# Key: AD, Name: AmperWave Design
# Key: OIB, Name: Organizational Improvement Backlog
# Key: AWDN, Name: AmperWave Dev-Null
# Key: AWS, Name: AmperWave Support
# Key: AQA, Name: AmperWave QA Automation
# Key: AUDACYD2C, Name: Audacy D2C Product Funnel
# Key: A2, Name: A2
# Key: APRE, Name: AWS Personalize Reco Engine
# Key: AR, Name: AmperWave Requests
# Key: AWDS, Name: Amperwave DevOps
# Key: DENUL, Name: DEVNULL
# Key: DTR, Name: Data Team Roadmap
# Key: AWPRD, Name: AW Product (Test)
# Key: ETT, Name: Tim Test Project
# Key: ENGT, Name: Engineering Training
# Key: AT, Name: Attribution
# Key: MI, Name: MarTech initiatives
# Key: AWPLAY, Name: AW_Playground
# Key: ARC, Name: AmperWave Arc
# Key: SWAT, Name: a2-SWAT
# Key: ID, Name: Identity
# Key: REC, Name: Recommendation
# Key: BEAT, Name: BEAT
# Key: DIGDESIGN, Name: DIGITAL DESIGN
# Key: DTC, Name: DTC Roadmap
# Key: HED, Name: Hackathon2022-EllensDegenerates
# Key: CMD, Name: Clients Monitoring Dashboard
# Key: BOOP, Name: Boop
# Key: AWR, Name: AW Reports
# Key: CCS, Name: Clients & Client Services
# Key: MT, Name: Matt Test
# Key: PI, Name: Partner Integrations
# Key: MT2, Name: Matt Test 2
# Key: ADT, Name: Audacy Adtech
# Key: DTL, Name: Data Team Legends
# Key: SRE, Name: AmperWave SRE
# Key: APOC, Name: Architecture POC
# Key: SOC, Name: SOC Controls
# Key: AWDATA, Name: AW Data Reporting
# Key: CI, Name: CapEx Initiatives
# Key: AWFE, Name: AmperWave Front End
# Key: DPM, Name: Digital Portfolio Management
# Key: MD, Name: Matt DTC
# Key: ASE, Name: Audacy Solutions Engineering
# Key: EDE, Name: EDE
# Key: AWPLAN, Name: AW Planning
# Key: BET, Name: BetQL
# Key: QAA, Name: CCS SOW WWT
# Key: ZIT, Name: ZenDesk Jira Integration Test
# Key: EIT, Name: Enterprise IT
# Key: CCSM, Name: CCS Matrix
# Key: SEC, Name: SecOps
# Key: APP, Name: Audacy Projects Portfolio
# Key: ARE, Name: Audacy Reliability Engineering
# Key: PLAYER, Name: Web Player
# Key: ADMIN, Name: Audio Admin
# Key: ST, Name: Station Tools
# Key: OOP, Name: Owned & Operated Platform
# Key: DESIGN, Name: DESIGN
# Key: EV, Name: Eventful
# Key: FREQ, Name: Frequency 2.0
# Key: PRODOPS, Name: Product Operations
# Key: INFRA, Name: IT & Infrastructure
# Key: ON, Name: Project Unity
# Key: DAC, Name: Data & Commercialization
# Key: API, Name: API
# Key: TEST, Name: Test Project
# Key: IOS, Name: iOS App
# Key: DROID, Name: Android App
# Key: DEVOPS, Name: DevOps
# Key: TV, Name: TV Applications
# Key: STREAMS, Name: Smart Streams
# Key: EV2, Name: Eventful 2.0
# Key: STREAM, Name: StreamingOps
# Key: VOIC, Name: Voice
# Key: QA, Name: Quality Assurance
# Key: APPREV, Name: QA: Support Escalated Tickets
# Key: SAM, Name: SAM
# Key: RA, Name: Revenue Analytics
# Key: UMS, Name: User Management
# Key: CAB, Name: Archived Change Advisory Board
# Key: PARTNER, Name: Partnerships
# Key: PROG, Name: Audio Program
# Key: VID, Name: Video
# Key: SUPPORT, Name: Support Operations
# Key: ROKU, Name: Roku
# Key: AP, Name: Audio Product
# Key: E20S, Name: Eventful 2.0 Scrum
# Key: GQL, Name: GraphQL
# Key: AAS, Name: Audio Ad Service
# Key: CPR, Name: Cuepoint Processor
# Key: PPR, Name: Podcast Processor
# Key: DPR, Name: Developer Portal
# Key: MMS, Name: Media Management
# Key: UR, Name: User Research
# Key: BASS, Name: BASS
# Key: PA, Name: Product Analytics
# Key: SA, Name: Marconi
# Key: UX, Name: UX
# Key: CLOUDOPS, Name: CloudOps
# Key: ENGSUPPORT, Name: Engineering Support
# Key: MARKETOPS, Name: Market Operations
#
# Total Projects Found: 154

# %%
# Key: EIT, Name: Enterprise IT
# Key: DEVOPS, Name: DevOps

# %% [markdown]
# ## --- DevOps Projects in Jira ---

# %%
# --- Accessing Projects ---

projects = jira.projects()
print("\n--- All Projects ---")
for project in projects:
    if project.key == "DEVOPS":
        print(f"Found DevOps project Key: {project.key}, Name: {project.name}, ID: {project.id}")
    #print(f"Key: {project.key}, Name: {project.name}, ID: {project.id}")
    if "DevOps" in project.name:
        print(f"Found DevOps project Key: {project.key}, Name: {project.name}, ID: {project.id}")
print(f"\nTotal Projects Found: {len(projects)}")
if "DevOps" in projects:
    print("DevOps project found!")
else:
    print("DevOps project not found.")
# Out:
# --- All Projects ---
# Found DevOps project Key: AWDS, Name: Amperwave DevOps, ID: 13912
# Found DevOps project Key: DEVOPS, Name: DevOps, ID: 13769
# Found DevOps project Key: DEVOPS, Name: DevOps, ID: 13769
#
# Total Projects Found: 154
# DevOps project not found.

# %% [markdown]
# ## --- Enterprise IT Projects in Jira ---

# %%
# --- Accessing Projects ---

projects = jira.projects()
print("\n--- All Projects ---")
for project in projects:
    if project.key == "EIT":
        print(f"Found Enterprise IT project Key: {project.key}, Name: {project.name}, ID: {project.id}")
    #print(f"Key: {project.key}, Name: {project.name}, ID: {project.id}")
    if "EIT" in project.name:
        print(f"Found Enterprise IT project Key: {project.key}, Name: {project.name}, ID: {project.id}")
print(f"\nTotal Projects Found: {len(projects)}")
if "EIT" in projects:
    print("Enterprise IT project found!")
else:
    print("Enterprise IT project not found.")
# Out:
# --- All Projects ---
# Found Enterprise IT project Key: EIT, Name: Enterprise IT, ID: 13969
#
# Total Projects Found: 154
# Enterprise IT project not found.

# %% [markdown]
# ## --- Accessing Kanban Statuses DevOps ---

# %%
# --- Accessing Kanban Statuses ---

project_key_to_check = "DEVOPS"  # Replace with the project key you want to check
found_project = None
for project in projects:
    if project.key == project_key_to_check:
        found_project = project
        break
boards = jira.boards(projectKeyOrID=found_project.id)  # get all boards related to the project
print(boards)
print(f"\n--- All Boards for Project '{found_project.name}' ---")
for board in boards:
    #print(board)
    print(f"ID: {board.id}, Name: {board.name}")        
print(f"\nTotal Boards Found: {len(boards)}")
# Out:
# [<JIRA Board: name='IT-INFRA', id=222>, <JIRA Board: name='ARCHIVED CLOUD-ENG', id=550>, <JIRA Board: name='ARCHIVED Platform Engineering Board', id=618>, <JIRA Board: name='DevOps Status Board ', id=594>]
#
# --- All Boards for Project 'DevOps' ---
# ID: 222, Name: IT-INFRA
# ID: 550, Name: ARCHIVED CLOUD-ENG
# ID: 618, Name: ARCHIVED Platform Engineering Board
# ID: 594, Name: DevOps Status Board
#
# Total Boards Found: 4

# %% [markdown]
# ## --- Accessing Kanban Statuses EIT ---

# %%
# --- Accessing Kanban Statuses ---

project_key_to_check = "EIT"  # Replace with the project key you want to check
found_project = None
for project in projects:
    if project.key == project_key_to_check:
        found_project = project
        break
boards = jira.boards(projectKeyOrID=found_project.id)  # get all boards related to the project
print(boards)
print(f"\n--- All Boards for Project '{found_project.name}' ---")
for board in boards:
    #print(board)
    print(f"ID: {board.id}, Name: {board.name}")        
print(f"\nTotal Boards Found: {len(boards)}")
# Out:
# [<JIRA Board: name='EIT Kanban Board', id=1184>]
#
# --- All Boards for Project 'Enterprise IT' ---
# ID: 1184, Name: EIT Kanban Board
#
# Total Boards Found: 1

# %% [markdown]
# ## --- Fetch Issues (Tickets) from the Project DevOPs ---

# %%
from collections import Counter

# --- Fetch Issues from the Project ---
PROJECT_KEY = "DEVOPS"  # Replace with your project key
#PROJECT_KEY = "EIT"  # Replace with your project key

print(f"Fetching issues for project '{PROJECT_KEY}'...")
issues_in_project = []
jql_query = f'project = "{PROJECT_KEY}" ORDER BY created DESC'
status_counts = Counter()
# jira-python handles pagination automatically when iterating
try:
    # Search issues iteratively (handles pagination)
    # Increase maxResults if needed, but iteration is generally preferred
    #search_params = {'jql': jql_query, 'maxResults': False, 'fields': 'status'} # Fetch only status field
    search_params = {
        "jql": jql_query,
        "maxResults": 5000,
        "fields": "status,summary"
    }

    # Correct API endpoint
    url = f"{jira_server}/rest/api/3/search/jql"
    next_token = None
    status_counts = Counter()
    total_issues_processed = 0
    while True:
        if next_token:
            search_params["nextPageToken"] = next_token
        response = jira._session.get(url,params=search_params)

        issues_iterator = response.json()

        #print(f"Total issues found: {len(issues_iterator.get('issues', []))}")
        for issue in issues_iterator.get("issues", []):
            #print(issue["fields"]['status']['name'])
            status_name = issue["fields"]["status"]["name"]
            status_counts[status_name] += 1
            total_issues_processed += 1
            # Optional: Print progress
            if total_issues_processed % 2000 == 0:
                print(f"Processed {total_issues_processed} issues...")
                
        next_token = issues_iterator.get("nextPageToken")
        if not next_token:
            break
    
    print(f"Finished fetching. Found {total_issues_processed} issues in total.")
    
    if not status_counts:
        print(f"No issues found for project '{PROJECT_KEY}' or couldn't retrieve statuses.")
        exit()

except Exception as e:
    print(f"An error occurred while fetching issues: {e}")
    # Check if it's an authentication error
    if "401" in str(e):
        print("Hint: Check if your JIRA_EMAIL and API Token are correct and have permissions.")
    # Check if it's a project not found error
    elif "404" in str(e) or "project" in str(e).lower():
        print(f"Hint: Check if the project key '{PROJECT_KEY}' is correct.")
    exit()


# --- Prepare Data for Visualization ---
# Remove "Done" and "Will Not Do" statuses if they exist
status_counts.pop("Done", None)
status_counts.pop("Will Not Do", None)

statuses = list(status_counts.keys())
counts = list(status_counts.values())

print("\nTicket Counts per Stage:")
for status, count in status_counts.items():
    print(f"- {status}: {count}")

#print(statuses)

print("Script finished.")
# Out:
# Fetching issues for project 'DEVOPS'...
# Processed 2000 issues...
# Processed 4000 issues...
# Processed 6000 issues...
# Processed 8000 issues...
# Finished fetching. Found 8146 issues in total.
#
# Ticket Counts per Stage:
# - Triage: 5
# - Tech Discovery Required: 10
# - In Progress: 26
# - To Do: 52
# - Validating: 5
# - Blocked: 7
# - On Hold: 7
# - Technical Debt: 6
# - Resource Constrained: 29
# Script finished.

# %% [markdown]
# # --- Create Visualization ---

# %%
KANBAN_COLUMN_ORDER = [
    "Triage", "Tech Discovery Required", "Technical Debt", "Resource Constrained", "To Do", "Blocked", "On Hold", "Plan Release",
    "In Progress", "Build Release", "Deploy Replease", "Validating", "Post Implementation Review", "Done", "Will Not Do",
    "Closed", "Resolved", "Cancelled", "Released Successfully to Production", "❌ Rolled Back"
]

# %%
# --- Create Visualization ---
print("\nGenerating visualization...")

ordered_statuses = [s for s in KANBAN_COLUMN_ORDER if s in status_counts]
fig, ax = plt.subplots(figsize=(10, 6)) # Adjust figure size as needed

bars = ax.bar(ordered_statuses, [status_counts[s] for s in ordered_statuses], color='C1', edgecolor='black')

# Add counts above the bars
ax.bar_label(bars, padding=3)

ax.set_xlabel("Issue Status (Stage)")
ax.set_ylabel("Number of Tickets")
ax.set_title(f"Ticket Distribution by Status for Project '{PROJECT_KEY} for {date.today()}'")
ax.set_ylim(0, max(counts) * 1.2)  # Add some space above the highest bar
#ax.tick_params(axis='x', rotation=90, ha='right') # Rotate labels if they overlap
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels overlapping

# --- Display the Plot ---
print("Displaying plot. Close the plot window to exit the script.")
plt.show()
# Out:
# Generating visualization...
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/854326199.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10) # Rotate x-axis labels for better readability
# Displaying plot. Close the plot window to exit the script.

# %% [markdown]
# ## --- Fetch Issues (Tickets) from the Project EIT ---

# %%
# --- Fetch Issues from the Project ---
PROJECT_KEY = "EIT"  # Replace with your project key
#PROJECT_KEY = "EIT"  # Replace with your project key

print(f"Fetching issues for project '{PROJECT_KEY}'...")
issues_in_project = []
jql_query = f'project = "{PROJECT_KEY}" ORDER BY created DESC'
status_counts = Counter()
# jira-python handles pagination automatically when iterating
try:
    # Search issues iteratively (handles pagination)
    # Increase maxResults if needed, but iteration is generally preferred
    #search_params = {'jql': jql_query, 'maxResults': False, 'fields': 'status'} # Fetch only status field
    search_params = {
        "jql": jql_query,
        "maxResults": 5000,
        "fields": "status,summary"
    }

    # Correct API endpoint
    url = f"{jira_server}/rest/api/3/search/jql"
    next_token = None
    status_counts = Counter()
    total_issues_processed = 0
    while True:
        if next_token:
            search_params["nextPageToken"] = next_token
        response = jira._session.get(url,params=search_params)

        issues_iterator = response.json()

        #print(f"Total issues found: {len(issues_iterator.get('issues', []))}")
        
        for issue in issues_iterator.get("issues", []):
            #print(issue["fields"]['status']['name'])
            status_name = issue["fields"]["status"]["name"]
            status_counts[status_name] += 1
            total_issues_processed += 1
            # Optional: Print progress
            if total_issues_processed % 2000 == 0:
                print(f"Processed {total_issues_processed} issues...")
                
        next_token = issues_iterator.get("nextPageToken")
        if not next_token:
            break
    
    print(f"Finished fetching. Found {total_issues_processed} issues in total.")
    
    if not status_counts:
        print(f"No issues found for project '{PROJECT_KEY}' or couldn't retrieve statuses.")
        exit()

except Exception as e:
    print(f"An error occurred while fetching issues: {e}")
    # Check if it's an authentication error
    if "401" in str(e):
        print("Hint: Check if your JIRA_EMAIL and API Token are correct and have permissions.")
    # Check if it's a project not found error
    elif "404" in str(e) or "project" in str(e).lower():
        print(f"Hint: Check if the project key '{PROJECT_KEY}' is correct.")
    exit()


# --- Prepare Data for Visualization ---
# Remove "Done" and "Will Not Do" statuses if they exist
status_counts.pop("Done", None)
status_counts.pop("Will Not Do", None)

statuses = list(status_counts.keys())
counts = list(status_counts.values())

print("\nTicket Counts per Stage:")
for status, count in status_counts.items():
    print(f"- {status}: {count}")

print(statuses)

print("Script finished.")
# Out:
# Fetching issues for project 'EIT'...
# Finished fetching. Found 567 issues in total.
#
# Ticket Counts per Stage:
# - Triage: 44
# - In Progress: 1
# - Backlog: 9
# ['Triage', 'In Progress', 'Backlog']
# Script finished.

# %% [markdown]
# # --- Create Visualization ---

# %%
# --- Create Visualization ---
print("\nGenerating visualization...")
fig, ax = plt.subplots(figsize=(10, 6)) # Adjust figure size as needed

#bars = ax.bar(statuses, counts, color='C1', edgecolor='black')
bars = ax.bar(ordered_statuses, [status_counts[s] for s in ordered_statuses], color='C1', edgecolor='black')

# Add counts above the bars
ax.bar_label(bars, padding=3)

ax.set_xlabel("Issue Status (Stage)")
ax.set_ylabel("Number of Tickets")
ax.set_title(f"Ticket Distribution by Status for Project '{PROJECT_KEY} for {date.today()}'")
ax.set_ylim(0, max(counts) * 1.2)  # Add some space above the highest bar
#ax.tick_params(axis='x', rotation=90, ha='right') # Rotate labels if they overlap
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels overlapping

# --- Display the Plot ---
print("Displaying plot. Close the plot window to exit the script.")
plt.show()
# Out:
# Generating visualization...
# Displaying plot. Close the plot window to exit the script.
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/1809314337.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=10) # Rotate x-axis labels for better readability

# %%
# --- Example JSON Response for an Issue ---
'''
{
  "expand": "renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations",
  "id": "10001",
  "self": "https://your-jira-instance.atlassian.net/rest/api/3/issue/10001",
  "key": "PROJECT-123",
  "fields": {
    "summary": "Example Issue: Fix the login button alignment",
    "description": {
        "type": "doc",
        "version": 1,
        "content": [
            {
                "type": "paragraph",
                "content": [
                    {
                        "type": "text",
                        "text": "The login button on the main page is slightly misaligned on mobile viewports."
                    }
                ]
            }
        ]
    },
    "issuetype": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/issuetype/10000",
      "id": "10000",
      "description": "A task that needs to be done.",
      "iconUrl": "https://your-jira-instance.atlassian.net/...",
      "name": "Task",
      "subtask": false,
      "avatarId": 10318
    },
    "project": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/project/10000",
      "id": "10000",
      "key": "PROJECT",
      "name": "Example Project",
      "projectTypeKey": "software",
      "simplified": false,
      "avatarUrls": {
        "48x48": "...",
        "24x24": "...",
        "16x16": "...",
        "32x32": "..."
      }
    },
    "resolution": null, // Example: null if the issue is unresolved
    "resolutiondate": null, // Example: null if the issue is unresolved
    "created": "2023-10-27T10:05:00.123+0000",
    "updated": "2023-10-27T11:15:30.456+0000",
    "priority": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/priority/3",
      "iconUrl": "https://your-jira-instance.atlassian.net/images/icons/priorities/medium.svg",
      "name": "Medium",
      "id": "3"
    },
    "status": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/status/10001",
      "description": "The issue is currently being worked on.",
      "iconUrl": "https://your-jira-instance.atlassian.net/...",
      "name": "In Progress",
      "id": "10001",
      "statusCategory": {
        "self": "https://your-jira-instance.atlassian.net/rest/api/3/statuscategory/4",
        "id": 4,
        "key": "indeterminate",
        "colorName": "yellow",
        "name": "In Progress"
      }
    },
    "labels": [
      "ui-bug",
      "mobile"
    ],
    "assignee": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/user?accountId=...",
      "accountId": "...",
      "emailAddress": "developer@example.com",
      "avatarUrls": { ... },
      "displayName": "Jane Developer",
      "active": true,
      "timeZone": "America/Los_Angeles"
    },
    "reporter": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/user?accountId=...",
      "accountId": "...",
      "emailAddress": "reporter@example.com",
      "avatarUrls": { ... },
      "displayName": "Bob Reporter",
      "active": true,
      "timeZone": "Europe/London"
    },
    "creator": {
      "self": "https://your-jira-instance.atlassian.net/rest/api/3/user?accountId=...",
      "accountId": "...",
      "emailAddress": "reporter@example.com", // Often the same as reporter, but not always
      "avatarUrls": { ... },
      "displayName": "Bob Reporter",
      "active": true,
      "timeZone": "Europe/London"
    },
    "components": [
      {
        "self": "https://your-jira-instance.atlassian.net/rest/api/3/component/10000",
        "id": "10000",
        "name": "User Interface",
        "description": "Handles the frontend display"
      }
    ],
    "fixVersions": [
       {
        "self": "https://your-jira-instance.atlassian.net/rest/api/3/version/10001",
        "id": "10001",
        "description": "Release for Q4 features",
        "name": "Version 2.1",
        "archived": false,
        "released": false,
        "releaseDate": "2023-12-15"
      }
    ],
    "environment": "Production - Mobile Web (iOS Safari)",
    "duedate": "2023-11-10",
    "votes": {
      "self": "...",
      "votes": 5,
      "hasVoted": false
    },
    "watches": {
      "self": "...",
      "watchCount": 3,
      "isWatching": true
    },
    "workratio": -1, // Or a calculated value if time tracking is used
    "timespent": 7200, // Example: in seconds (2 hours)
    "timeoriginalestimate": 14400, // Example: in seconds (4 hours)
    "aggregatetimespent": 7200,
    "aggregatetimeoriginalestimate": 14400,
    "security": null, // Or an object if security level is set
    "versions": [], // Affected versions
    // --- Custom Fields ---
    // Custom fields vary greatly. They are identified by 'customfield_xxxxx'
    "customfield_10010": "Some text value", // Example: Text Field (single line)
    "customfield_10011": { // Example: Select List (single choice)
        "self": "...",
        "value": "Option B",
        "id": "10021"
    },
    "customfield_10012": [ // Example: Select List (multiple choices)
        { "self": "...", "value": "Alpha", "id": "10030" },
        { "self": "...", "value": "Gamma", "id": "10032" }
    ],
    "customfield_10013": 123.45, // Example: Number Field
    "customfield_10014": "2023-11-01", // Example: Date Picker
    "customfield_10015": "2023-10-27T14:30:00.000+0000", // Example: Date Time Picker
    "customfield_10016": { // Example: User Picker (single user)
        "self": "...",
        "accountId": "...",
        "displayName": "Alice QA",
        "active": true
        // ... other user details
    },
    "customfield_10017": null // Example: A custom field that hasn't been set
    // ... potentially many more custom fields ...
  }
}
# --- Example JSON Response for an Issue ---
# This is a simplified example. The actual response will contain more fields and nested structures.
'''
# Out:
# '\n{\n  "expand": "renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations",\n  "id": "10001",\n  "self": "https://your-jira-instance.atlassian.net/rest/api/3/issue/10001",\n  "key": "PROJECT-123",\n  "fields": {\n    "summary": "Example Issue: Fix the login button alignment",\n    "description": {\n        "type": "doc",\n        "version": 1,\n        "content": [\n            {\n                "type": "paragraph",\n                "content": [\n                    {\n                        "type": "text",\n                        "text": "The login button on the main page is slightly misaligned on mobile viewports."\n                    }\n                ]\n            }\n        ]\n    },\n    "issuetype": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/issuetype/10000",\n      "id": "10000",\n      "description": "A task that needs to be done.",\n      "iconUrl": "https://your-jira-instance.atlassian.net/...",\n      "name": "Task",\n      "subtask": false,\n      "avatarId": 10318\n    },\n    "project": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/project/10000",\n      "id": "10000",\n      "key": "PROJECT",\n      "name": "Example Project",\n      "projectTypeKey": "software",\n      "simplified": false,\n      "avatarUrls": {\n        "48x48": "...",\n        "24x24": "...",\n        "16x16": "...",\n        "32x32": "..."\n      }\n    },\n    "resolution": null, // Example: null if the issue is unresolved\n    "resolutiondate": null, // Example: null if the issue is unresolved\n    "created": "2023-10-27T10:05:00.123+0000",\n    "updated": "2023-10-27T11:15:30.456+0000",\n    "priority": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/priority/3",\n      "iconUrl": "https://your-jira-instance.atlassian.net/images/icons/priorities/medium.svg",\n      "name": "Medium",\n      "id": "3"\n    },\n    "status": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/status/10001",\n      "description": "The issue is currently being worked on.",\n      "iconUrl": "https://your-jira-instance.atlassian.net/...",\n      "name": "In Progress",\n      "id": "10001",\n      "statusCategory": {\n        "self": "https://your-jira-instance.atlassian.net/rest/api/3/statuscategory/4",\n        "id": 4,\n        "key": "indeterminate",\n        "colorName": "yellow",\n        "name": "In Progress"\n      }\n    },\n    "labels": [\n      "ui-bug",\n      "mobile"\n    ],\n    "assignee": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/user?accountId=...",\n      "accountId": "...",\n      "emailAddress": "developer@example.com",\n      "avatarUrls": { ... },\n      "displayName": "Jane Developer",\n      "active": true,\n      "timeZone": "America/Los_Angeles"\n    },\n    "reporter": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/user?accountId=...",\n      "accountId": "...",\n      "emailAddress": "reporter@example.com",\n      "avatarUrls": { ... },\n      "displayName": "Bob Reporter",\n      "active": true,\n      "timeZone": "Europe/London"\n    },\n    "creator": {\n      "self": "https://your-jira-instance.atlassian.net/rest/api/3/user?accountId=...",\n      "accountId": "...",\n      "emailAddress": "reporter@example.com", // Often the same as reporter, but not always\n      "avatarUrls": { ... },\n      "displayName": "Bob Reporter",\n      "active": true,\n      "timeZone": "Europe/London"\n    },\n    "components": [\n      {\n        "self": "https://your-jira-instance.atlassian.net/rest/api/3/component/10000",\n        "id": "10000",\n        "name": "User Interface",\n        "description": "Handles the frontend display"\n      }\n    ],\n    "fixVersions": [\n       {\n        "self": "https://your-jira-instance.atlassian.net/rest/api/3/version/10001",\n        "id": "10001",\n        "description": "Release for Q4 features",\n        "name": "Version 2.1",\n  ...

# %% [markdown]
# ## --- Define JQL Query ---
# ### --- Fetch issues, including assignee, key, and summary fields ---

# %%
# --- Define JQL Query ---

CF_BUSINESS_LEAD    = "customfield_11751"
CF_PLANNING_RANK    = "customfield_11445"
CF_PORTFOLIO_RANK   = "customfield_11312"
CF_PARENT_LINK      = "customfield_10300"   # Legend link lives here
CF_EPIC_LINK        = "customfield_10009"   # Story  Epic
CF_EPIC_NAME        = "customfield_10008"   # Epic Name (text)
CF_REQUEST_TYPE     = "customfield_10977"
CF_TARGET_END       = "customfield_10947"
CF_TIME_IN_PROGRESS = "customfield_11261"


# Fetch issues, including assignee, key, and summary fields
PROJECT_KEY = "DEVOPS"  # Replace with your project key
PROJECT_KEY_2 = "EIT"  # Replace with your project key
PROJECT_KEY_3 = "CAR"  # Replace with your project key


fields_to_fetch = "assignee, summary, key, status, created, updated, issuetype, creator, project, duedate, priority, customfield_10947, customfield_11751,customfield_11445,customfield_11312,customfield_10300," \
"parentProject, parent" # Fields to fetch

# Start with a base JQL query
jql_clauses = []
if PROJECT_KEY:
    jql_clauses.append(f'project = "{PROJECT_KEY}" OR project = "{PROJECT_KEY_2}" OR project = "{PROJECT_KEY_3}"')  # Handle case sensitivity
    print(f"Fetching issues for project '{PROJECT_KEY}', {PROJECT_KEY_2}, {PROJECT_KEY_3}...")
else:
    # Warning: Fetching all issues without a project filter can be very slow
    # and return a huge number of results depending on your Jira instance size
    # and permissions. Consider adding other filters (e.g., status, updatedDate).
    print("Warning: Fetching issues across all accessible projects. This might take a while.")
    # Example: Add a filter for only assigned issues if searching all projects
    # jql_clauses.append("assignee is not EMPTY")

# Combine clauses and add ordering
jql_query = " AND ".join(jql_clauses) if jql_clauses else "" # Handle case with no clauses
jql_query += " ORDER BY assignee ASC, updated DESC"
jql_query = jql_query.strip() # Remove leading/trailing whitespace if needed

print(f"Using JQL: {jql_query if jql_query else 'Searching all issues (no specific JQL)'}")


# --- Fetch and Group Issues by Assignee ---
# Use defaultdict to easily group issues; value is a list of issue details
issues_by_assignee = defaultdict(list)

try:
    #search_params = {'jql': jql_query, 'maxResults': False, 'fields': fields_to_fetch}
    #issues_iterator = jira.search_issues(jql_str=search_params['jql'],
    #                                     maxResults=search_params['maxResults'],
    #                                     fields=search_params['fields'],
    #                                     expand=None,
    #                                     json_result=False) # Get Issue objects

    search_params = {
        "jql": jql_query,
        "maxResults": 5000,
        "fields": fields_to_fetch
    }

    # Correct API endpoint
    url = f"{jira_server}/rest/api/3/search/jql"
    next_token = None
    total_issues_processed = 0
    issues_iterator_all = []
    while True:
        if next_token:
            search_params["nextPageToken"] = next_token
        response = jira._session.get(url,params=search_params)

        issues_iterator = response.json()
        issues_iterator_all = issues_iterator_all + issues_iterator['issues']

        #print(f"Total issues found: {len(issues_iterator.get('issues', []))}")
        
        for issue in issues_iterator.get("issues", []):
            #print(issue["fields"]['status']['name'])
            #print(issue["fields"]['summary'])
            #print(issue["fields"]['assignee'])
            #print(issue["fields"]['assignee']['displayName'] if issue["fields"]['assignee'] else "Unassigned")
            assignee_name = issue["fields"]['assignee']['displayName'] if issue["fields"]['assignee'] else "Unassigned"
            # Store relevant issue info (e.g., key and summary)
            issue_info = {
                "key": issue['key'],
                "summary": issue['fields']['summary']
            }
            #status_name = issue["fields"]["status"]["name"]
            issues_by_assignee[assignee_name].append(issue_info)
            total_issues_processed += 1
            # Optional: Print progress
            if total_issues_processed % 2000 == 0:
                print(f"Processed {total_issues_processed} issues...")
                
        next_token = issues_iterator.get("nextPageToken")
        if not next_token:
            break

    print(f"Finished processing. Found {total_issues_processed} issues in total.")

    if not issues_by_assignee:
        print("No issues found matching the criteria.")
        exit()
    

except Exception as e:
    print(f"An error occurred while fetching issues: {e}")
    if "401" in str(e):
        print("Hint: Check JIRA_EMAIL/API Token.")
    elif "400" in str(e) and "JQL" in str(e):
        print(f"Hint: Check if the JQL query is valid: {jql_query}")
    elif PROJECT_KEY and ("404" in str(e) or "project" in str(e).lower()):
        print(f"Hint: Check Project Key '{PROJECT_KEY}'.")
    exit()


print("\nScript finished.")
# Out:
# Fetching issues for project 'DEVOPS', EIT, CAR...
# Using JQL: project = "DEVOPS" OR project = "EIT" OR project = "CAR" ORDER BY assignee ASC, updated DESC
# Processed 2000 issues...
# Processed 4000 issues...
# Processed 6000 issues...
# Processed 8000 issues...
# Processed 10000 issues...
# Finished processing. Found 11695 issues in total.
#
# Script finished.

# %%
len(issues_iterator_all)
# Out:
# 11695

# %%
len(issues_by_assignee)
# Out:
# 199

# %%
#issues_iterator
'''
{'issues': [{'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations',
   'id': '61669',
   'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issue/61669',
   'key': 'DEVOPS-755',
   'fields': {'summary': 'Create Testing Script for Operations to test Destination URL 200s',
    'issuetype': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issuetype/3',
     'id': '3',
     'description': 'A task that needs to be done.',
     'iconUrl': 'https://entercomdigitalservices.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium',
     'name': 'Task',
     'subtask': False,
     'avatarId': 10318,
     'hierarchyLevel': 0},
    'creator': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/user?accountId=5c58835a70c88b3ac427b886',
     'accountId': '5c58835a70c88b3ac427b886',
     'emailAddress': 'john.kulovitz@audacy.com',
     'avatarUrls': {'48x48': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/48',
      '24x24': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/24',
      '16x16': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/16',
      '32x32': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/32'},
     'displayName': 'Johnathan Kulovitz',
     'active': True,
     'timeZone': 'America/Denver',
     'accountType': 'atlassian'},
    'created': '2020-08-13T13:51:21.817-0600',
    'project': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/project/13769',
    
    
    
.....

  {'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations',
   'id': '43895',
   'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issue/43895',
   'key': 'DEVOPS-35',
   'fields': {'summary': 'Destroy devRadioApi-env-test environment',
    'issuetype': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issuetype/10200',
     'id': '10200',
     'description': 'Created by JIRA Software - do not edit or delete. Issue type for a user story.',
     'iconUrl': 'https://entercomdigitalservices.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10315?size=medium',
     'name': 'Story',
     'subtask': False,
     'avatarId': 10315,
     'hierarchyLevel': 0},
    'creator': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/user?accountId=5b4f6754173f212c1f29e6fe',
     'accountId': '5b4f6754173f212c1f29e6fe',
     'emailAddress': 'jon.west@entercom.com',
     'avatarUrls': {'48x48': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/48',
      '24x24': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/24',
      '16x16': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/16',
      '32x32': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/32'},
     'displayName': 'Jon West',
     'active': True,
     'timeZone': 'America/Denver',
     'accountType': 'atlassian'},
    'created': '2019-02-13T11:55:09.920-0700',
    'project': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/project/13769',
     'id': '13769',
     'key': 'DEVOPS',
     'name': 'DevOps',
     'projectTypeKey': 'software',
     'simplified': False,
     'avatarUrls': {'48x48': 'https://entercomdigitalservices.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/14206',
      '24x24': 'https://entercomdigitalservices.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/14206?size=small',
      '16x16': 'https://entercomdigitalservices.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/14206?size=xsmall',
      '32x32': 'https://entercomdigitalservices.atlassian.net/rest/api/3/universal_avatar/view/type/project/avatar/14206?size=medium'},
     'projectCategory': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/projectCategory/10102',
      'id': '10102',
      'description': '',
      'name': 'Active'}},
    'customfield_11751': None,
    'priority': None,
    'customfield_11312': None,
    'customfield_11445': None,
    'duedate': None,
    'customfield_10947': None,
    'assignee': None,
    'updated': '2019-02-13T13:08:14.260-0700',
    'status': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/status/10001',
     'description': '',
     'iconUrl': 'https://entercomdigitalservices.atlassian.net/',
     'name': 'Done',
     'id': '10001',
     'statusCategory': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/statuscategory/3',
      'id': 3,
      'key': 'done',
      'colorName': 'green',
      'name': 'Done'}}}},
'''
# Out:
# "\n{'issues': [{'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations',\n   'id': '61669',\n   'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issue/61669',\n   'key': 'DEVOPS-755',\n   'fields': {'summary': 'Create Testing Script for Operations to test Destination URL 200s',\n    'issuetype': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issuetype/3',\n     'id': '3',\n     'description': 'A task that needs to be done.',\n     'iconUrl': 'https://entercomdigitalservices.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10318?size=medium',\n     'name': 'Task',\n     'subtask': False,\n     'avatarId': 10318,\n     'hierarchyLevel': 0},\n    'creator': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/user?accountId=5c58835a70c88b3ac427b886',\n     'accountId': '5c58835a70c88b3ac427b886',\n     'emailAddress': 'john.kulovitz@audacy.com',\n     'avatarUrls': {'48x48': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/48',\n      '24x24': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/24',\n      '16x16': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/16',\n      '32x32': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5c58835a70c88b3ac427b886/d0c382b6-f8c2-4618-b2f4-35aa23781f9a/32'},\n     'displayName': 'Johnathan Kulovitz',\n     'active': True,\n     'timeZone': 'America/Denver',\n     'accountType': 'atlassian'},\n    'created': '2020-08-13T13:51:21.817-0600',\n    'project': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/project/13769',\n\n\n\n.....\n\n  {'expand': 'renderedFields,names,schema,operations,editmeta,changelog,versionedRepresentations',\n   'id': '43895',\n   'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issue/43895',\n   'key': 'DEVOPS-35',\n   'fields': {'summary': 'Destroy devRadioApi-env-test environment',\n    'issuetype': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/issuetype/10200',\n     'id': '10200',\n     'description': 'Created by JIRA Software - do not edit or delete. Issue type for a user story.',\n     'iconUrl': 'https://entercomdigitalservices.atlassian.net/rest/api/2/universal_avatar/view/type/issuetype/avatar/10315?size=medium',\n     'name': 'Story',\n     'subtask': False,\n     'avatarId': 10315,\n     'hierarchyLevel': 0},\n    'creator': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/user?accountId=5b4f6754173f212c1f29e6fe',\n     'accountId': '5b4f6754173f212c1f29e6fe',\n     'emailAddress': 'jon.west@entercom.com',\n     'avatarUrls': {'48x48': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/48',\n      '24x24': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/24',\n      '16x16': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/16',\n      '32x32': 'https://avatar-management--avatars.us-west-2.prod.public.atl-paas.net/5b4f6754173f212c1f29e6fe/c7364343-946d-4605-adb3-2bf26cc0149c/32'},\n     'displayName': 'Jon West',\n     'active': True,\n     'timeZone': 'America/Denver',\n     'accountType': 'atlassian'},\n    'created': '2019-02-13T11:55:09.920-0700',\n    'project': {'self': 'https://entercomdigitalservices.atlassian.net/rest/api/3/project/13769',\n     'id': '13769',\n     'key': 'DEVOPS',\n     'name': 'DevOps',\n     'projectTypeKey': 'software',\n     'simplified': False,\n     'avatarUrls': {'48x48': 'https://entercomdigitalservices.atlassian.net/rest/api/3/u ...

# %% [markdown]
# ## Building a Pandas Dataframe

# %%
# --- Define JQL Query ---

CF_BUSINESS_LEAD    = "customfield_11751"
CF_PLANNING_RANK    = "customfield_11445"
CF_PORTFOLIO_RANK   = "customfield_11312"
CF_PARENT_LINK      = "customfield_10300"   # Legend link lives here
CF_EPIC_LINK        = "customfield_10009"   # Story  Epic
CF_EPIC_NAME        = "customfield_10008"   # Epic Name (text)
CF_REQUEST_TYPE     = "customfield_10977"
CF_TARGET_END       = "customfield_10947"
CF_TIME_IN_PROGRESS = "customfield_11261"


print(f"Start fetching: {PROJECT_KEY}, {PROJECT_KEY_2}, {PROJECT_KEY_3} issues...")
assignee_counts = Counter()
issue_creator_counts = Counter()
status_counts = Counter()
issue_type_counts = Counter()
topic_issues_counts = Counter()
topic_issues_counts_days = 0
processed_data = []
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
issues_iterator =issues_iterator_all

for issue in issues_iterator:
    fields = issue['fields']
    #print(f'created {fields["created"]}')
    if fields.get('creator'):
        creator_name = fields['creator']['displayName']
        #creator_email = fields['creator']['emailAddress']
    else:
        creator_name = 'Unknown'
        #creator_email = 'Unknown'

    if fields.get('assignee'):
        assignee_name = fields['assignee']['displayName']
        #assignee_email = fields['assignee']['emailAddress']
    else:
        assignee_name = 'Unassigned'
        #assignee_email = 'Unassigned'

    if fields.get('priority'):
        priority_name = fields['priority']['name']
        priority_id = fields['priority']['id']
    else:
        priority_name = 'No Priority'
        priority_id = 'No Priority'

    if fields.get('duedate'):
        due_date = fields['duedate']
    else:
        due_date = '2000-01-01T00:00:00.000+0000'  # Default date if not set
    try:
        if fields.get(CF_BUSINESS_LEAD):
            bussiness_lead = str(fields[CF_BUSINESS_LEAD]['displayName']).replace('.', ' ')
        else:
            bussiness_lead = 'Unknown'
    except Exception as e:
        bussiness_lead = 'Unknown'
    try:
        if fields.get(CF_PLANNING_RANK):
            planning_rank = fields[CF_PLANNING_RANK]
        else:
            planning_rank = 'Unknown'
    except Exception as e:
        planning_rank = 'Unknown'
    
    try:
        if fields.get(CF_PORTFOLIO_RANK):
            portfolio_rank = fields[CF_PORTFOLIO_RANK]
        else:
            portfolio_rank = pd.NaT  # Use NaT for missing dates
    except Exception as e:
        portfolio_rank = pd.NaT  # Use NaT for missing dates

    try:
        if fields.get(CF_PARENT_LINK):
            legend = fields[CF_PARENT_LINK]
        else:
            legend = pd.NA  # Use NaT for missing dates
    except Exception as e:
        legend = pd.NA  # Use NaT for missing dates

    try:
        if fields.get('parentProject'):
            parent_project = fields['parentProject']
        else:
            parent_project = pd.NA  # Use NaT for missing dates
    except Exception as e:
        parent_project = pd.NA  # Use NaT for missing dates

    try:
        if fields.get('parent'):
            parent = fields['parent']['key']
        else:
            parent = pd.NA  # Use NaT for missing dates
    except Exception as e:
        parent = pd.NA  # Use NaT for missing dates

    issue_data = {
        'key': issue['key'],
        'id': issue['id'],
        'summary': fields.get('summary', ''),
        'status': fields.get('status', {}).get('name', ''),
        'issuetype': fields.get('issuetype', {}).get('name', ''),
        'creator_name': creator_name,
        #'creator_email': creator_email,
        #'reporter_name': fields['reporter']['displayName'] if fields.get('reporter') else 'Unknown',
        #'reporter_email': fields['reporter']['emailAddress'] if fields.get('reporter') else 'Unknown',
        'assignee_name': assignee_name,
        #'assignee_email': assignee_email,
        'created': pd.to_datetime(fields.get('created', None), errors='coerce'),
        'updated': pd.to_datetime(fields.get('updated', None), errors='coerce'),
        'project_name': fields.get('project', {}).get('name', ''),
        'project_id': fields.get('project', {}).get('id', ''),
        'priority_name': priority_name,
        'priority_id': priority_id,
        'project_due_date' : pd.to_datetime(due_date, utc=True, errors='coerce').tz_convert('UTC-06:00'),
        'issue_url' : issue.get('permalink', lambda: None)(),
        'today' : pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00'),
        'days_old' : (pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00') - pd.to_datetime(fields.get('created', None), errors='coerce')).days,
        'year_updated' : pd.to_datetime(fields.get('updated', None), errors='coerce').year,
        'month_updated' : pd.to_datetime(fields.get('updated', None), errors='coerce').month,
        'year_created' : pd.to_datetime(fields.get('created', None), errors='coerce').year,
        'month_created' : pd.to_datetime(fields.get('created', None), errors='coerce').month,
        'last_updated_days' : (pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00') - pd.to_datetime(fields.get('updated', None), errors='coerce')).days,
        'project_due_date' : pd.to_datetime(due_date, utc=True, errors='coerce').tz_convert('UTC-06:00'),
        'project_due_date_days' : (pd.to_datetime(due_date, utc=True, errors='coerce').tz_convert('UTC-06:00') - pd.to_datetime(fields.get('updated', None), errors='coerce')).days,
        'velocity' : (pd.to_datetime(fields.get('updated', None), errors='coerce') - pd.to_datetime(fields.get('created', None), errors='coerce')).days,
        'velocity_hours' : (pd.to_datetime(fields.get('updated', None), errors='coerce') - pd.to_datetime(fields.get('created', None), errors='coerce')).total_seconds() / 3600,
        'velocity_days' : (pd.to_datetime(fields.get('updated', None), errors='coerce') - pd.to_datetime(fields.get('created', None), errors='coerce')).days,
        'target_end_date' : pd.to_datetime(fields.get('customfield_10947', None), utc=True, errors='coerce'),
        'bussiness_lead' : bussiness_lead,
        'planning_rank' : planning_rank,
        'portfolio_rank' : portfolio_rank,
        'legend' : legend,
        'parent_project' : parent_project,
        'parent' : parent,
        #'target_end_days' : (pd.to_datetime(fields.get('customfield_10947', None), utc=True, errors='coerce').tz_convert('UTC-06:00') - pd.to_datetime(fields.get('updated', None), errors='coerce')).days,

        # Add more fields as needed, including custom fields
        # 'customfield_xxxxx': fields.get('customfield_xxxxx')
    }
    processed_data.append(issue_data)

    # Use fields['assignee'] instead of issue['assignee']
    if fields.get('assignee'):
        assignee_counts[fields['assignee']['displayName']] += 1
    else:
        assignee_counts['Unassigned'] += 1

    if fields.get('issuetype'):
        issue_type_counts[fields['issuetype']['name']] += 1
    if fields.get('status'):
        status_counts[fields['status']['name']] += 1
    if fields.get('creator'):
        issue_creator_counts[fields['creator']['displayName']] += 1



df_issues = pd.DataFrame(processed_data)

# Calculate days until due date
df_issues.loc[(df_issues['last_updated_days'] < 0, 'last_updated_days')] = 0




print(f"Finished fetching. Found {total_issues_processed} issues in total.")
print("\nScript finished.")
# Out:
# Start fetching: DEVOPS, EIT, CAR issues...
# Finished fetching. Found 11695 issues in total.
#
# Script finished.

# %%
str(today.date())
# Out:
# '2025-10-28'

# %% [markdown]
# ## Save the CSV File

# %%
df_issues.to_csv('jira_issues_total_'+str(today.date())+'.csv', index=False)

# %%
len(processed_data)
# Out:
# 11695

# %% [markdown]
# ### --- Getting Record 0 to validate it ---

# %%
processed_data[0]
# Out:
# {'key': 'CAR-235',
#  'id': '63368',
#  'summary': 'Add user "Blair Askey" to all frequency Sites as Webmaster',
#  'status': 'Released Successfully to Production',
#  'issuetype': 'Change and Release',
#  'creator_name': 'Aaron Schultheis',
#  'assignee_name': 'Aaron Schultheis',
#  'created': Timestamp('2020-10-05 15:04:14.595000-0600', tz='UTC-06:00'),
#  'updated': Timestamp('2020-11-30 10:58:39.586000-0700', tz='UTC-07:00'),
#  'project_name': 'Release Management',
#  'project_id': '13836',
#  'priority_name': 'None',
#  'priority_id': '10004',
#  'project_due_date': Timestamp('1999-12-31 18:00:00-0600', tz='UTC-06:00'),
#  'issue_url': None,
#  'today': Timestamp('2025-10-28 02:49:12.155497-0600', tz='UTC-06:00'),
#  'days_old': 1848,
#  'year_updated': 2020,
#  'month_updated': 11,
#  'year_created': 2020,
#  'month_created': 10,
#  'last_updated_days': 1792,
#  'project_due_date_days': -7640,
#  'velocity': 55,
#  'velocity_hours': 1340.9069419444445,
#  'velocity_days': 55,
#  'target_end_date': None,
#  'bussiness_lead': 'Unknown',
#  'planning_rank': 'Unknown',
#  'portfolio_rank': NaT,
#  'legend': <NA>,
#  'parent_project': <NA>,
#  'parent': <NA>}

# %%
df_issues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11695 entries, 0 to 11694
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    11695 non-null  object
#  1   id                     11695 non-null  object
#  2   summary                11695 non-null  object
#  3   status                 11695 non-null  object
#  4   issuetype              11695 non-null  object
#  5   creator_name           11695 non-null  object
#  6   assignee_name          11695 non-null  object
#  7   created                11695 non-null  object
#  8   updated                11695 non-null  object
#  9   project_name           11695 non-null  object
#  10  project_id             11695 non-null  object
#  11  priority_name          11695 non-null  object
#  12  priority_id            11695 non-null  object
#  13  project_due_date       11695 non-null  datetime64[ns, UTC-06:00]
#  14  issue_url              0 non-null      object
#  15  today                  11695 non-null  datetime64[ns, UTC-06:00]
#  16  days_old               11695 non-null  int64
#  17  year_updated           11695 non-null  int64
#  18  month_updated          11695 non-null  int64
#  19  year_created           11695 non-null  int64
#  20  month_created          11695 non-null  int64
#  21  last_updated_days      11695 non-null  int64
#  22  project_due_date_days  11695 non-null  int64
#  23  velocity               11695 non-null  int64
#  24  velocity_hours         11695 non-null  float64
#  25  velocity_days          11695 non-null  int64
#  26  target_end_date        2633 non-null   datetime64[ns, UTC]
#  27  bussiness_lead         11695 non-null  object
#  28  planning_rank          11695 non-null  object
#  29  portfolio_rank         0 non-null      datetime64[ns]
#  30  legend                 0 non-null      object
#  31  parent_project         0 non-null      object
#  32  parent                 4236 non-null   object
# dtypes: datetime64[ns, UTC-06:00](2), datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(9), object(19)
# memory usage: 2.9+ MB

# %%
df_issues.iloc[0]
# Out:
# key                                                                CAR-235
# id                                                                   63368
# summary                  Add user "Blair Askey" to all frequency Sites ...
# status                                 Released Successfully to Production
# issuetype                                               Change and Release
# creator_name                                              Aaron Schultheis
# assignee_name                                             Aaron Schultheis
# created                                   2020-10-05 15:04:14.595000-06:00
# updated                                   2020-11-30 10:58:39.586000-07:00
# project_name                                            Release Management
# project_id                                                           13836
# priority_name                                                         None
# priority_id                                                          10004
# project_due_date                                 1999-12-31 18:00:00-06:00
# issue_url                                                             None
# today                                     2025-10-28 02:49:12.155497-06:00
# days_old                                                              1848
# year_updated                                                          2020
# month_updated                                                           11
# year_created                                                          2020
# month_created                                                           10
# last_updated_days                                                     1792
# project_due_date_days                                                -7640
# velocity                                                                55
# velocity_hours                                                 1340.906942
# velocity_days                                                           55
# target_end_date                                                        NaT
# bussiness_lead                                                     Unknown
# planning_rank                                                      Unknown
# portfolio_rank                                                         NaT
# legend                                                                <NA>
# parent_project                                                        <NA>
# parent                                                                <NA>
# Name: 0, dtype: object

# %%
# df_issues['status'].unique()

# %%
# df_issues['parent'].unique()

# %%
df_issues[(df_issues['status'] == 'In Progress') & (df_issues['days_old'] <= 300)]['days_old'].describe()
# Out:
# count     27.000000
# mean      65.333333
# std       51.781345
# min        4.000000
# 25%       30.500000
# 50%       60.000000
# 75%       86.000000
# max      242.000000
# Name: days_old, dtype: float64

# %% [markdown]
# ## Tickets that do NOT have a Created Date

# %%
#df_issues[(df_issues['days_old'] == df_issues['days_old'].max()) & (df_issues['status'] == 'In Progress')][['key','summary','status','assignee_name','created','days_old','creator_name','updated']]#

# %%
#df_issues[df_issues['project_name'] == 'DevOps']['assignee_name'].unique()

# %% [markdown]
# # -- Cleanig the Data to get ONLY CAR Tickets for the DevOps Team --

# %%
DEVOPS_TEAM = ['Adam Shero', 'Angel Cancio', 'Bolanle','Cullen Philippson','David Caballero','David Caballero Miranda','Juan Reyes','Mike Admire','Randall Puterbaugh','satish kumar marana','Simon Davison','Terry Dougal','Tom Terry']

# %%
df_issues_car = df_issues[((df_issues['assignee_name'].isin(DEVOPS_TEAM)) & (df_issues['project_name'] == 'Release Management')) | (df_issues['project_name'] == 'DevOps') | (df_issues['project_name'] == 'Enterprise IT')]

# %%
#len(df_issues_car)

# %%
#df_issues_car[df_issues_car['project_name'] == 'Release Management']['assignee_name'].unique()

# %%
df_issues = df_issues_car.copy()

# %%
# --- Create the Box Plot ---
# Set a nice theme
sns.set_theme(style="whitegrid")

# Create the figure and axes
# Adjust figsize for better aspect ratio for a single box plot
plt.figure(figsize=(12, 10))

# Generate the box plot
# We use the filtered DataFrame.
# y='last_updated_days' specifies the data for the plot.
# x='status' will use the 'status' column for the x-axis category label.
# Since we filtered for 'In Progress', it will show a single box for this category.
in_progress_issues_df = df_issues[df_issues['status'] != 'Done']
in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['project_name'] != 'Release Management']
in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Will Not Do']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Blocked']
in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Blocked For Development']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Resource Constrained']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Released Successfully to Production'] # CAR Tickets = Done
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != '❌ Rolled Back']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['days_old'] <= 365]
ax = sns.boxplot(
    data=in_progress_issues_df,
    y='days_old',  # This will plot the 'days_old' values
    x='status',  # This will label the x-axis category as 'In Progress'
    palette="coolwarm", # Optional: adds a bit of color
    width=0.4, # Optional: makes the box a bit narrower,
    hue='project_name',  # Optional: if you want to differentiate by project
)

# --- 4. Customize the Plot ---
plt.title("Distribution of the Ticket's Age ", fontsize=16)
plt.ylabel("Days", fontsize=12)
plt.xlabel("Status", fontsize=12) # Label for the x-axis
plt.xticks(rotation=90, ha='center') # Rotate x-axis labels for better readability

plt.ylim(0, 365)  # Set y-axis limit to 365 days
plt.yticks(np.arange(0, in_progress_issues_df['days_old'].max()+30, 30))  # Set y-ticks to every 30 days
plt.grid(axis='y', linestyle='--', alpha=0.7)
#plt.xticks(rotation=0, ha='center')
plt.hlines(y=90, xmin=-0.5, xmax=8.5, color='green', linestyle='--', label='Good Threshold')
plt.hlines(y=365, xmin=-0.5, xmax=8.5, color='red', linestyle='--', label='1 Year Threshold')
plt.hlines(y=550, xmin=-0.5, xmax=8.5, color='orange', linestyle='--', label='1.5 Year Threshold')
plt.hlines(y=730, xmin=-0.5, xmax=8.5, color='purple', linestyle='--', label='2 Year Threshold')

#plt.yticks(np.arange(0, 650, 20)) # Set y-ticks to increase by 20 for better readability
plt.legend(title='Department', bbox_to_anchor=(1.05, 1), loc='upper left') # Position legend outside the plot

# You can adjust y-axis limits if needed, e.g., to focus on a specific range
# ax.set_ylim(0, 20) # Example: if you want to cap the y-axis

# Ensure everything fits without overlapping
plt.tight_layout()

# --- 5. Display the Plot ---
plt.show()

# %%
df_issues[df_issues['status'] == 'In Progress']['last_updated_days'].describe()
# Out:
# count    27.000000
# mean      9.296296
# std       8.374939
# min       0.000000
# 25%       4.000000
# 50%       6.000000
# 75%      14.000000
# max      25.000000
# Name: last_updated_days, dtype: float64

# %%
# --- Create the Box Plot ---
# Set a nice theme
sns.set_theme(style="whitegrid")

# Create the figure and axes
# Adjust figsize for better aspect ratio for a single box plot
plt.figure(figsize=(12, 10))

# Generate the box plot
# We use the filtered DataFrame.
# y='last_updated_days' specifies the data for the plot.
# x='status' will use the 'status' column for the x-axis category label.
# Since we filtered for 'In Progress', it will show a single box for this category.
in_progress_issues_df = df_issues[df_issues['status'] != 'Done']
in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['project_name'] != 'Release Management']
in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Will Not Do']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Blocked']
in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Blocked For Development']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Resource Constrained']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != 'Released Successfully to Production'] # CAR Tickets = Done
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['status'] != '❌ Rolled Back']
#in_progress_issues_df = in_progress_issues_df[in_progress_issues_df['days_old'] <= 365]
ax = sns.boxplot(
    data=in_progress_issues_df,
    y='last_updated_days',
    x='status',  # This will label the x-axis category as 'In Progress'
    palette="coolwarm", # Optional: adds a bit of color
    width=0.4, # Optional: makes the box a bit narrower
    hue='project_name',  # Optional: if you want to differentiate by project
)

# --- 4. Customize the Plot ---
plt.title("Distribution of the Last time the Ticket was Updated ", fontsize=16)
plt.ylabel("Last time the Ticket was Updated in Days", fontsize=12)
plt.xlabel("Status", fontsize=12) # Label for the x-axis
plt.xticks(rotation=90) # Rotate x-axis labels for better readability
plt.yticks(np.arange(0, 130, 10)) # Set y-ticks to increase by 10 for better readability
plt.legend(title='Department', bbox_to_anchor=(1.05, 1), loc='upper left') # Position legend outside the plot

plt.ylim(0, 365)  # Set y-axis limit to 365 days
plt.yticks(np.arange(0, in_progress_issues_df['days_old'].max()+30, 30))  # Set y-ticks to every 30 days
plt.grid(axis='y', linestyle='--', alpha=0.7)
#plt.xticks(rotation=0, ha='center')
plt.hlines(y=90, xmin=-0.5, xmax=8.5, color='green', linestyle='--', label='Good Threshold')
plt.hlines(y=365, xmin=-0.5, xmax=8.5, color='red', linestyle='--', label='1 Year Threshold')
plt.hlines(y=550, xmin=-0.5, xmax=8.5, color='orange', linestyle='--', label='1.5 Year Threshold')
plt.hlines(y=730, xmin=-0.5, xmax=8.5, color='purple', linestyle='--', label='2 Year Threshold')

# You can adjust y-axis limits if needed, e.g., to focus on a specific range
# ax.set_ylim(0, 20) # Example: if you want to cap the y-axis

# Ensure everything fits without overlapping
plt.tight_layout()

# --- 5. Display the Plot ---
plt.show()

# %%
df_issues[(df_issues['status'] != 'Done') & (df_issues['status'] != 'Will Not Do')]['status'].value_counts()
# Out:
# status
# Released Successfully to Production    227
# To Do                                   52
# Triage                                  49
# Resource Constrained                    29
# In Progress                             27
# Tech Discovery Required                 10
# Backlog                                  9
# Blocked                                  7
# On Hold                                  7
# Technical Debt                           6
# Validating                               5
# ❌ Rolled Back                            5
# Prepare Release                          2
# Plan Release                             1
# Name: count, dtype: int64

# %%
#status_list = ['Tech Discovery Required']
#df_issues[df_issues['status'].isin(status_list)]

# %%
print("Generating countplot for Issue Status...")
plt.figure(figsize=(10, 6)) # Adjust figure size for readability
# Use 'y' axis for categories if names are long or many
sns.countplot(hue='project_name',data=df_issues[(df_issues['status'] != 'Done') & (df_issues['status'] != 'Will Not Do')], y='status', order=df_issues[(df_issues['status'] != 'Done') & (df_issues['status'] != 'Will Not Do')]['status'].value_counts(ascending=True).index)
plt.title('Number of Issues by Status')
plt.xlabel('Number of Issues')
plt.ylabel('Status')
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()
# Out:
# Generating countplot for Issue Status...
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/2785468643.py:8: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) Arial.
#   plt.tight_layout() # Adjust layout to prevent labels overlapping
# /Users/jorge.rodriguez/Library/Python/3.14/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Assuming df is your DataFrame and imports are done

print("Generating countplot for Issue Type...")
plt.figure(figsize=(10, 6))
sns.countplot(hue='project_name',data=df_issues[(df_issues['status'] != 'Done') & (df_issues['status'] != 'Will Not Do')], y='issuetype', order=df_issues['issuetype'].value_counts().sort_values(ascending=False).index)
plt.title('Number of Issues by Issue Type')
plt.xlabel('Number of Issues')
plt.ylabel('Issue Type')
plt.tight_layout()
plt.legend(title='Project', bbox_to_anchor=(1.05, 1), loc='upper left') # Adjust legend position
plt.show()
# Out:
# Generating countplot for Issue Type...

# %%
# Assuming df is your DataFrame and imports are done

print("Generating countplot for Status, colored by Issue Type...")
plt.figure(figsize=(12, 7))
# Using 'hue' adds the second category breakdown
sns.countplot(data=df_issues[(df_issues['status'] != 'Done') & (df_issues['status'] != 'Will Not Do')], y='status', hue='issuetype', order=df_issues[(df_issues['status'] != 'Done') & (df_issues['status'] != 'Will Not Do')]['status'].value_counts().index)
plt.title('Issues by Status and Type')
plt.xlabel('Number of Issues')
plt.ylabel('Status')
plt.legend(title='Issue Type') # Add a legend
plt.tight_layout()
plt.show()
# Out:
# Generating countplot for Status, colored by Issue Type...
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/45446298.py:11: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) Arial.
#   plt.tight_layout()
# /Users/jorge.rodriguez/Library/Python/3.14/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#df_issues.status.value_counts()

# %%
#df_issues.info()

# %% [markdown]
# # --- PDF Function / Template for the Reports ---

# %%
#import datetime
#from fpdf import FPDF # Using fpdf2 is recommended for more features (pip install fpdf2)
#                     # If using original fpdf (pip install fpdf), some advanced multi_cell args might not be available
#                     # but the core logic for table drawing will be similar.
#import pandas as pd # Assuming top_10_rows is a pandas DataFrame

# --- Configuration ---
REPORT_TITLE = "Jira Issues"
FILENAME_OUTPUT = "jira_in_progress.pdf"
LINE_HEIGHT_MULTIPLIER = 1.0 # Multiplier for cell height based on font size
FONT_FAMILY = "Arial"
FONT_SIZE_TITLE = 16
FONT_SIZE_DATE = 10
FONT_SIZE_HEADER = 6
FONT_SIZE_CELL = 5
FONT_SIZE_CELL_LARGE = 5

# Define column headers for the PDF table
PDF_TABLE_HEADERS = [
    'Ticket', 'Status', 'Priority', 'Business Lead', 'Assignee',
    'Target End', 'Last Updated', 'Days Old', 'Days Left', 'Summary'
]

# Define the corresponding DataFrame column keys in the order they should appear
# Ensure these keys exist in your top_10_rows DataFrame
DATAFRAME_COLUMN_KEYS = [
    'key', 'status', 'priority_name', 'bussiness_lead', 'assignee_name',
    'target_end_date', 'updated', 'days_old', 'days_left', 'summary'
]


class PDFReport(FPDF):
    def __init__(self, REPORT_TITLE, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.report_title = REPORT_TITLE

    def header(self):
        # Set font for the report title
        self.set_font(FONT_FAMILY, 'B', FONT_SIZE_TITLE)
        title_w = self.get_string_width(self.report_title) + 6
        self.set_x((self.w - title_w) / 2) # Center title
        self.cell(title_w, 10, self.report_title, 0, 1, 'C') # ln=1 for new line

        # Add generation date
        self.set_font(FONT_FAMILY, '', FONT_SIZE_DATE)
        date_str = f"Generated: {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"
        date_w = self.get_string_width(date_str) + 6
        self.set_x((self.w - date_w) / 2) # Center date
        self.cell(date_w, 10, date_str, 0, 1, 'C')
        self.ln(5) # Add a little space before table

    def footer(self):
        self.set_y(-15) # Position 1.5 cm from bottom
        self.set_font(FONT_FAMILY, 'I', 8)
        self.cell(0, 10, f'Page {self.page_no()}/{{nb}}', 0, 0, 'C')

    def create_table(self, table_data_df, headers, column_keys, col_widths):
        if table_data_df.empty:
            self.set_font(FONT_FAMILY, '', FONT_SIZE_CELL)
            self.cell(0, 10, "No data available for the report.", 0, 1, 'C')
            return

        # Calculate effective line height for cells
        # FPDF's multi_cell takes a line_height argument.
        # We use font_size as a base for this.
        effective_line_height = self.font_size * LINE_HEIGHT_MULTIPLIER

        # Table Header
        self.set_font(FONT_FAMILY, 'B', FONT_SIZE_HEADER)
        self.set_fill_color(200, 220, 255) # Light blue background for header
        self.set_text_color(0) # Black text
        self.set_draw_color(128) # Grey border
        self.set_line_width(0.3)

        for i, header_text in enumerate(headers):
            self.cell(col_widths[i], effective_line_height, header_text, border=1, ln=0, align='C', fill=True)
        self.ln(effective_line_height)

        # Table Data
        self.set_font(FONT_FAMILY, '', FONT_SIZE_CELL)
        self.set_fill_color(245, 245, 245) # Light grey for alternating rows
        fill = False

        for index, row in table_data_df.iterrows():
            # Determine the maximum height needed for this row
            # This involves checking how many lines each cell's content will take
            # For simplicity in this example, we'll use a robust method:
            # draw each cell and track the Y position.
            # print(f"Processing row {index + 1}/{len(table_data_df)}...") # Debugging output
            # print(f"Row data: {row.to_dict()}") # Print row data for debugging
            # print(row['days_left'])

            current_y_start_of_row = self.get_y()
            current_x_position = self.l_margin # Start at left margin
            max_y_after_this_row = current_y_start_of_row # Track the lowest point any cell in this row reaches

            for i, key in enumerate(column_keys):
                cell_value = str(row.get(key, '')) # Get value, default to empty string if key missing
                
                self.set_xy(current_x_position, current_y_start_of_row) # Key: Reset Y for each cell in the row

                # Draw the multi_cell
                # The `effective_line_height` here is the height of *each line* within the multi_cell
                # Draw the multi_cell with manual tracking for broader compatibility
                self.set_xy(current_x_position, current_y_start_of_row)
                # import numpy as np
                if ((row['days_left'] < 0) or (pd.isna(row['days_left'])) and (row['status'] == 'In Progress')):
                    # If days_left is negative or NaN, highlight the cell
                    cell_value_overdue = f"{cell_value} (Overdue)"
                    self.set_font(FONT_FAMILY, 'B', FONT_SIZE_CELL_LARGE)
                    self.set_fill_color(240, 240, 255) # Light grey for alternating rows
                    self.multi_cell(col_widths[i], self.font_size * 1.2 , cell_value, # Use font_size for line height in multi_cell
                                    border=1, align='L', fill=True)
                    self.set_font(FONT_FAMILY, '', FONT_SIZE_CELL)
                    self.set_fill_color(245, 245, 245) # Light grey for alternating rows
                else:
                    self.multi_cell(col_widths[i], self.font_size * 1.2 , cell_value, # Use font_size for line height in multi_cell
                                    border=1, align='L', fill=fill)
                
                if self.get_y() > max_y_after_this_row:
                    max_y_after_this_row = self.get_y()
                
                current_x_position += col_widths[i]


            # After all cells in the row are drawn, set Y to below the tallest cell
            self.set_y(max_y_after_this_row)
            fill = not fill # Alternate fill color for next row
        
        # Add a final line break if there was data, to ensure footer doesn't overlap
        if not table_data_df.empty:
            self.ln(max(effective_line_height / 2, 2)) # Add a small space after the table


def generate_enhanced_report(top_10_rows_df, REPORT_TITLE = "Jira Issues In Progress", FILENAME_OUTPUT="jira_in_progress.pdf"):
    """
    Generates an enhanced PDF report from the DataFrame.
    Args:
        top_10_rows_df (pd.DataFrame): DataFrame containing the data.
                                       Expected to have columns specified in DATAFRAME_COLUMN_KEYS.
    """
  
    pdf = PDFReport(REPORT_TITLE, format='Letter', unit='mm') # Letter: 215.9 x 279.4 mm
    pdf.alias_nb_pages() # Enable page numbering alias '{nb}'
    pdf.add_page()

    # Define column widths (total should be around self.w - margins)
    # Effective page width for content: pdf.w - pdf.l_margin - pdf.r_margin
    # Default margins are 10mm. So, 215.9 - 20 = 195.9 mm for Letter.
    # Adjust these widths based on your content and preferences.
    # Sum of these should ideally be <= (pdf.w - pdf.l_margin - pdf.r_margin)
    page_content_width = pdf.w - pdf.l_margin - pdf.r_margin
    
    # Proportional widths or fixed widths
    col_widths = [
        page_content_width * 0.08, # Ticket
        page_content_width * 0.06, # Status 0.08
        page_content_width * 0.06, # Priority 0.08
        page_content_width * 0.12, # Business Lead
        page_content_width * 0.12, # Assignee
        page_content_width * 0.10, # Target End
        page_content_width * 0.10, # Last Updated
        page_content_width * 0.07, # Days Old
        page_content_width * 0.07, # Days Left
        page_content_width * 0.22  # Summary (largest) 0.18
    ]
    # Ensure sum of col_widths does not exceed page_content_width
    # This can be done by normalizing or adjusting the last column
    current_total_width = sum(col_widths)
    if current_total_width > page_content_width:
        # Simple adjustment: shrink the last column if oversized
        # A more sophisticated approach might scale all columns proportionally
        diff = current_total_width - page_content_width
        col_widths[-1] -= diff
    elif current_total_width < page_content_width:
        # Optionally, expand the last column to fill width
        diff = page_content_width - current_total_width
        col_widths[-1] += diff


    # Ensure the DataFrame has the necessary columns before passing
    try:
        data_for_table = top_10_rows_df[DATAFRAME_COLUMN_KEYS]
    except KeyError as e:
        print(f"Error: DataFrame is missing one or more required columns: {e}")
        print(f"Expected columns: {DATAFRAME_COLUMN_KEYS}")
        print(f"Available columns: {top_10_rows_df.columns.tolist()}")
        # Optionally, create an empty PDF with an error message or raise exception
        pdf.set_font(FONT_FAMILY, 'B', 12)
        pdf.multi_cell(0,10, f"Report generation failed: Missing column(s) - {e}. Check console.", 1, "C")
        pdf.output(FILENAME_OUTPUT, 'F')
        return

    #print(data_for_table)
    
    pdf.create_table(data_for_table, PDF_TABLE_HEADERS, DATAFRAME_COLUMN_KEYS, col_widths)
    
    try:
        pdf.output(FILENAME_OUTPUT, 'F') # 'F' to save to local file
        print(f"Report '{FILENAME_OUTPUT}' generated successfully.")
    except Exception as e:
        print(f"Error saving PDF: {e}")

# %% [markdown]
# ## --- Top 25 Oldes Tickets ---

# %% [markdown]
# ## Generate the Report

# %%
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
today_date = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
status = df_issues['status'].unique()
status = [s for s in status if s not in ['Backlog','Done', 'Plan Release', 'Prepare Release','Will Not Do', 'Blocked For Development', 'Resource Constrained', 'Released Successfully to Production', '❌ Rolled Back']]
status
df1 = df_issues[df_issues['status'].isin(status)].copy()  # Use .copy() to avoid SettingWithCopyWarning
df1['days_old'].sort_values(ascending=False).head(25)
df1['due_date_date'] = df1['project_due_date'].dt.date
df1['target_end_date'] = pd.to_datetime(df1['target_end_date'], errors='coerce').dt.date
df1['updated'] = pd.to_datetime(df1['updated'], errors='coerce').dt.date

# Ensure 'today' is a single date (not a column)
today_date = today.date() if hasattr(today, 'date') else pd.to_datetime(today).date()
df1['days_left'] = (df1['target_end_date'] - today_date).apply(lambda x: x.days if pd.notnull(x) else None)

# Get the top 20 rows with the highest days_old
top_10_indices = df1[['bussiness_lead','status','project_name','priority_id','target_end_date','days_old']].sort_values(by=['project_name','status','bussiness_lead','priority_id','days_old', 'target_end_date'], ascending=True).index
top_10_rows = df1.loc[top_10_indices].sort_values(by=['days_old'], ascending=False).head(25).copy()  # Select rows using the indices
top_10_rows.sort_values(by=['bussiness_lead','status'], ascending=False, inplace=True)  # Sort by days_old descending
# Print results for verification
print(f"All {len(top_10_rows)} Tickets as: {today_date} at {today.hour + 6}:{today.minute} CST")
#print(top_10_rows[['key','status','velocity_days','assignee_name','updated','summary']].to_string(index=False))
#print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
#               headers=['Ticket', 'Status', 'Priority','Business Lead','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','creator_name','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
               headers=['Ticket', 'Status', 'Priority','Business Lead','Creator Name','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
# Out:
# All 25 Tickets as: 2025-10-28 at 8:51 CST
# +-------------+-------------------------+------------+------------------+---------------------+---------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------------------------------------------+
# | Ticket      | Status                  | Priority   | Business Lead    | Creator Name        | Assignee Name       | Target End Date   | Last Updated   |   Days Old |   Days Left | Summary                                                                                                                   |
# |-------------+-------------------------+------------+------------------+---------------------+---------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------------------------------------------|
# | DEVOPS-7856 | On Hold                 | High       | sabrina szymczak | Kerri Walker        | Adam Shero          | 2025-09-26        | 2025-10-22     |        137 |         -32 | [DEVOPS] Deploy lambda function as a viewer request handler on CloudFront                                                 |
# | DEVOPS-7594 | In Progress             | High       | sabrina szymczak | Jeff Slutz          | Andriy Petryshyn    | 2025-11-07        | 2025-10-28     |        173 |          10 | Reduce castfire DB master node from db.m5.2xlarge to db.r8g.xlarge                                                        |
# | DEVOPS-7784 | On Hold                 | Medium     | eric duell       | eric.duell          | Unassigned          | 2025-10-31        | 2025-10-21     |        137 |           3 | [DAC | Audio Licensing | Storage Migration ] Transfer contents of AWS bucket aud-filedatagov-veritone-dropoff-prod to GCP |
# | DEVOPS-7917 | On Hold                 | High       | eric duell       | Alejandro Ponce     | Juan Reyes          | 2025-10-31        | 2025-10-17     |        111 |           3 | [Nonprod] Add Cogs Report Cron Job                                                                                        |
# | DEVOPS-6507 | Validating              | Low        | Zach Hahn        | Jonathan Duck       | Andriy Petryshyn    | 2025-09-11        | 2025-10-22     |        368 |         -47 | [Nonprod] Amperwave: Deploy "Boop" EKS Service                                                                            |
# | DEVOPS-7707 | Technical Debt          | Medium     | Zach Hahn        | Cullen Philippson   | Cullen Philippson   | NaT               | 2025-10-09     |        151 |         nan | AWS Maintenance Elastic Beanstalk in Legacy AWS accounts                                                                  |
# | DEVOPS-7939 | To Do                   | Low        | Victoria Benecke | Johnathan Kulovitz  | Bolanle             | 2025-10-31        | 2025-10-22     |        109 |           3 | [podcasts] delete stg-podcast-url-cache table (STG)                                                                       |
# | DEVOPS-7941 | To Do                   | Low        | Victoria Benecke | Johnathan Kulovitz  | Bolanle             | 2025-10-31        | 2025-10-22     |        109 |           3 | [podcasts] delete pre-existing s3 bucket for fetched rss feeds (STG)                                                      |
# | DEVOPS-7984 | To Do                   | Low        | Victoria Benecke | Johnathan Kulovitz  | Bolanle             | 2025-11-18        | 2025-10-15     |        104 |          21 | [podcasts] delete pre-existing s3 bucket for fetched rss feeds (PROD)                                                     |
# | DEVOPS-7979 | To Do                   | Low        | Victoria Benecke | Johnathan Kulovitz  | Bolanle             | 2025-10-30        | 2025-10-22     |        104 |           2 | [podcasts] merge MR for new versions of internal podcast topics (PROD)                                                    |
# | DEVOPS-7982 | To Do                   | Low        | Victoria Benecke | Johnathan Kulovitz  | Bolanle             | 2025-11-18        | 2025-10-15     |        104 |          21 | [podcasts] delete prod-podcast-url-cache table (PROD)                                                                     |
# | DEVOPS-7980 | To Do                   | Low        | Victoria Benecke | Johnathan Kulovitz  | Bolanle             | 2025-10-30        | 2025-10-22     |        104 |           2 | [content-publisher-podcast] merge MR for new content.podcast.update topic (PROD)                                          |
# | DEVOPS-7966 | Technical Debt          | Medium     | Victoria Benecke | Ben Bonora          | Randall Puterbaugh  | NaT               | 2025-10-09     |        105 |         nan | [Unity] [NonProd] Update Redis to Valkey                                                                                  |
# | DEVOPS-7967 | Technical Debt          | Medium     | Victoria Benecke | Ben Bonora          | Randall Puterbaugh  | NaT               | 2025-10-09     |        105 |         nan | [Unity] [Prod] Update Redis to Valkey                                                                                     |
# | DEVOPS-7082 | In Progress             | Low        | Victoria Benecke | MeLissa Elwell      | Tom Terry           | 2025-12-31        | 2025-10-23     |        242 |          64 | Radio.com Moves                                                                                                           |
# | DEVOPS-7901 | In Progress             | Medium     | Victoria Benecke | Amanda Hankel       | sabrina.szymczak    | 2025-10-31        | 2025-10-09     |        116 |           3 | PE/PodSquad work to Deprecate SuperHiFi & I Like Music                                                                    |
# | DEVOPS-8226 | In Progress             | Medium     | Victoria Benecke | Jeff Slutz          | Tom Terry           | 2025-10-31        | 2025-10-21     |         88 |           3 | Remove Exclusive Stations Infrastructure                                                                                  |
# | DEVOPS-6908 | Blocked                 | High       | Victoria Benecke | stephen.smith       | simon.davison       | NaT               | 2025-10-21     |        265 |         nan | Create New OpenSearch Domain in NonProd                                                                                   |
# | DEVOPS-8009 | To Do                   | Medium     | Jorge Rodriguez  | Don.Furline         | Tom Terry           | 2025-08-29        | 2025-10-15     |         97 |         -60 | Remediation of Lambda Functions (Entercom Production)                                                                     |
# | DEVOPS-7733 | Technical Debt          | Low        | Jorge Rodriguez  | Simon Davison       | Tom Terry           | 2025-12-31        | 2025-10-16     |        146 |          64 | Review and clean infra still configured for radio.com                                                                     |
# | DEVOPS-7925 | Technical Debt          | Medium     | Jorge Rodriguez  | Cullen Philippson   | Randall Puterbaugh  | NaT               | 2025-09-26     |        110 |         nan | Upgrade OpenSearch Service domain to a more recent engine version [AWS Account: 673312057223]                             |
# | DEVOPS-7660 | Tech Discovery Required | Medium     | Jorge Rodriguez  | Randall Puterbaugh  | Randall Puterbaugh  | NaT               | 2025-10-23     |        160 |         nan | Migration of Recommendation Services to A2 Environment                                                                    |
# | DEVOPS-8030 | In Progress             | High       | Jorge Rodriguez  | Grace Martorano     | Bolanle             | 2025-10-31        | 2025-10-02     |         96 |           3 | GitLab Migration from Self-Managed to Gitlab.com                                                                          |
# | DEVOPS-8067 | In Progress             | High       | Jorge Rodriguez  | Angel Cancio        | Bolanle             | 2025-10-31        | 2025-10-23     |         88 |           3 | Gitlab Pre-Migration                                                                                                      |
# | DEVOPS-7964 | Blocked                 | Medium     | Jorge Rodriguez  | satish kumar marana | satish kumar marana | NaT               | 2025-10-23     |        105 |         nan | Delete all un used topics from nonprod cluster and also old versioned kstream topics.                                     |
# +-------------+-------------------------+------------+------------------+---------------------+---------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------------------------------------------+

# %%
for x in range(len(top_10_rows)):
    print(f"Creator: {top_10_rows['creator_name'].iloc[x]} is {top_10_rows['days_old'].iloc[x]} days old")
    print(f"Summary: {top_10_rows.iloc[x]['summary'] }")
    print(f"https://entercomdigitalservices.atlassian.net/browse/{top_10_rows['key'].iloc[x]}")
    print("")
# Out:
# Creator: Kerri Walker is 137 days old
# Summary: [DEVOPS] Deploy lambda function as a viewer request handler on CloudFront
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7856
#
# Creator: Jeff Slutz is 173 days old
# Summary: Reduce castfire DB master node from db.m5.2xlarge to db.r8g.xlarge
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7594
#
# Creator: eric.duell is 137 days old
# Summary: [DAC | Audio Licensing | Storage Migration ] Transfer contents of AWS bucket aud-filedatagov-veritone-dropoff-prod to GCP
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7784
#
# Creator: Alejandro Ponce is 111 days old
# Summary: [Nonprod] Add Cogs Report Cron Job
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7917
#
# Creator: Jonathan Duck is 368 days old
# Summary: [Nonprod] Amperwave: Deploy "Boop" EKS Service
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-6507
#
# Creator: Cullen Philippson is 151 days old
# Summary: AWS Maintenance Elastic Beanstalk in Legacy AWS accounts
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7707
#
# Creator: Johnathan Kulovitz is 109 days old
# Summary: [podcasts] delete stg-podcast-url-cache table (STG)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7939
#
# Creator: Johnathan Kulovitz is 109 days old
# Summary: [podcasts] delete pre-existing s3 bucket for fetched rss feeds (STG)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7941
#
# Creator: Johnathan Kulovitz is 104 days old
# Summary: [podcasts] delete pre-existing s3 bucket for fetched rss feeds (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7984
#
# Creator: Johnathan Kulovitz is 104 days old
# Summary: [podcasts] merge MR for new versions of internal podcast topics (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7979
#
# Creator: Johnathan Kulovitz is 104 days old
# Summary: [podcasts] delete prod-podcast-url-cache table (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7982
#
# Creator: Johnathan Kulovitz is 104 days old
# Summary: [content-publisher-podcast] merge MR for new content.podcast.update topic (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7980
#
# Creator: Ben Bonora is 105 days old
# Summary: [Unity] [NonProd] Update Redis to Valkey
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7966
#
# Creator: Ben Bonora is 105 days old
# Summary: [Unity] [Prod] Update Redis to Valkey
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7967
#
# Creator: MeLissa Elwell is 242 days old
# Summary: Radio.com Moves
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7082
#
# Creator: Amanda Hankel is 116 days old
# Summary: PE/PodSquad work to Deprecate SuperHiFi & I Like Music
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7901
#
# Creator: Jeff Slutz is 88 days old
# Summary: Remove Exclusive Stations Infrastructure
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8226
#
# Creator: stephen.smith is 265 days old
# Summary: Create New OpenSearch Domain in NonProd
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-6908
#
# Creator: Don.Furline is 97 days old
# Summary: Remediation of Lambda Functions (Entercom Production)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8009
#
# Creator: Simon Davison is 146 days old
# Summary: Review and clean infra still configured for radio.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7733
#
# Creator: Cullen Philippson is 110 days old
# Summary: Upgrade OpenSearch Service domain to a more recent engine version [AWS Account: 673312057223]
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7925
#
# Creator: Randall Puterbaugh is 160 days old
# Summary: Migration of Recommendation Services to A2 Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7660
#
# Creator: Grace Martorano is 96 days old
# Summary: GitLab Migration from Self-Managed to Gitlab.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8030
#
# Creator: Angel Cancio is 88 days old
# Summary: Gitlab Pre-Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8067
#
# Creator: satish kumar marana is 105 days old
# Summary: Delete all un used topics from nonprod cluster and also old versioned kstream topics.
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7964

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(
    data=top_10_rows[df_issues['status'].isin(status)],
    x='status',
    y='days_old',
    hue='bussiness_lead',
    palette='tab20',
    showfliers=False
)
plt.title("TOP 25 OLDEST Ticket Age (Days Old) by Status and Business Lead")
plt.xlabel("Status")
plt.ylabel("Days Old")
plt.ylim(0, 365)  # Set y-axis limit to 365 days
plt.yticks(np.arange(0, top_10_rows['days_old'].max()+30, 30))  # Set y-ticks to every 30 days
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0, ha='center')
plt.hlines(y=90, xmin=-0.5, xmax=5.5, color='green', linestyle='--', label='Good Threshold')
plt.hlines(y=365, xmin=-0.5, xmax=5.5, color='red', linestyle='--', label='1 Year Threshold')
plt.hlines(y=550, xmin=-0.5, xmax=5.5, color='orange', linestyle='--', label='1.5 Year Threshold')
plt.hlines(y=730, xmin=-0.5, xmax=5.5, color='purple', linestyle='--', label='2 Year Threshold')
plt.legend(title='Business Lead', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/1771541277.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data=top_10_rows[df_issues['status'].isin(status)],

# %% [markdown]
# ## --- Tickets in Progress Status ---

# %% [markdown]
# ## Generate the Report

# %%
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
today_date = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
df1 = df_issues[df_issues['status'] == 'In Progress'].copy()  # Use .copy() to avoid SettingWithCopyWarning
df1['due_date_date'] = df1['project_due_date'].dt.date
df1['target_end_date'] = pd.to_datetime(df1['target_end_date'], errors='coerce').dt.date
df1['updated'] = pd.to_datetime(df1['updated'], errors='coerce').dt.date

# Ensure 'today' is a single date (not a column)
today_date = today.date() if hasattr(today, 'date') else pd.to_datetime(today).date()
df1['days_left'] = (df1['target_end_date'] - today_date).apply(lambda x: x.days if pd.notnull(x) else None)

# Get the top 20 rows with the highest days_old
top_10_indices = df1[['bussiness_lead','project_name','priority_id','target_end_date','days_old']].sort_values(by=['project_name','bussiness_lead','priority_id','days_old', 'target_end_date'], ascending=True).index
top_10_rows = df1.loc[top_10_indices]  # Select rows using the indices

# Print results for verification
print(f"All {len(top_10_rows)} Tickets as: {today_date} at {today.hour + 6}:{today.minute} CST")
#print(top_10_rows[['key','status','velocity_days','assignee_name','updated','summary']].to_string(index=False))
#print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
#               headers=['Ticket', 'Status', 'Priority','Business Lead','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','creator_name','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
               headers=['Ticket', 'Status', 'Priority','Business Lead','Creator Name','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))

# --- Save to CSV ---
# Save the DataFrame to a CSV file
output_file = 'jira_in_progress.csv'
#top_10_rows.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
# --- Save to JSON ---
# Save the DataFrame to a JSON file
#output_file_json = 'jira_issues.json'
#top_10_rows.to_json(output_file_json, orient='records', lines=True)
#print(f"Data saved to {output_file_json}")
# --- Save to CSV ---
# Save the DataFrame to a CSV file
#output_file = 'jira_issues_total.csv'
#df_issues.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
#print("Generating PDF report...")
#generate_enhanced_report(top_10_rows,"Jira Issues In Progress","jira_in_progress.pdf")
# Out:
# All 27 Tickets as: 2025-10-28 at 8:51 CST
# +-------------+-------------+------------+------------------+--------------------+---------------------+-------------------+----------------+------------+-------------+--------------------------------------------------------------------+
# | Ticket      | Status      | Priority   | Business Lead    | Creator Name       | Assignee Name       | Target End Date   | Last Updated   |   Days Old |   Days Left | Summary                                                            |
# |-------------+-------------+------------+------------------+--------------------+---------------------+-------------------+----------------+------------+-------------+--------------------------------------------------------------------|
# | DEVOPS-8448 | In Progress | High       | Chris Ulmer      | Ali Mir            | Cullen Philippson   | NaT               | 2025-10-23     |         11 |         nan | AWS Airflow (MWAA) issue connecting to MySQL Clarity               |
# | DEVOPS-8371 | In Progress | High       | Chris Ulmer      | Chris Ulmer        | satish kumar marana | 2025-10-31        | 2025-10-21     |         29 |           3 | Build Kafka to GCS Connectors for the EDP DEV Environment          |
# | DEVOPS-8370 | In Progress | High       | Chris Ulmer      | Chris Ulmer        | satish kumar marana | 2025-10-21        | 2025-10-23     |         30 |          -7 | Build Kafka to GCS Confluent Connectors for (4) EDP Environments   |
# | DEVOPS-8247 | In Progress | High       | Chris Ulmer      | Mrinal Kaustuv     | Bolanle             | 2025-10-31        | 2025-10-13     |         55 |           3 | Add datasync for Placement IO file                                 |
# | DEVOPS-8276 | In Progress | Urgent     | Jorge Rodriguez  | Angel Cancio       | Bolanle             | 2025-10-31        | 2025-10-02     |         49 |           3 | Register new 52 runners for the POC on gitlab.com                  |
# | DEVOPS-8275 | In Progress | Urgent     | Jorge Rodriguez  | Angel Cancio       | Bolanle             | 2025-10-31        | 2025-10-02     |         49 |           3 | Setup new runners for the POC                                      |
# | DEVOPS-8154 | In Progress | Urgent     | Jorge Rodriguez  | Adam Shero         | Adam Shero          | 2025-10-31        | 2025-10-09     |         69 |           3 | Migrate From DataDog to Grafana Cloud                              |
# | DEVOPS-8078 | In Progress | Urgent     | Jorge Rodriguez  | Angel Cancio       | Bolanle             | 2025-10-31        | 2025-10-02     |         88 |           3 | Setup and Configure POC migration                                  |
# | DEVOPS-8427 | In Progress | High       | Jorge Rodriguez  | Adam Shero         | Tom Terry           | 2025-10-24        | 2025-10-17     |         16 |          -4 | [Grafana Migration] Validate Migrated Dashboards                   |
# | DEVOPS-8233 | In Progress | High       | Jorge Rodriguez  | simon.davison      | Dmytro Oliinyk      | 2025-10-24        | 2025-10-27     |         60 |          -4 | Scrub references to radio.com from all Cognito instances           |
# | DEVOPS-8168 | In Progress | High       | Jorge Rodriguez  | Adam Shero         | Adam Shero          | 2025-10-24        | 2025-10-21     |         69 |          -4 | Google Cloud: Add Grafana Google Cloud Monitoring Scrape Jobs      |
# | DEVOPS-8167 | In Progress | High       | Jorge Rodriguez  | Adam Shero         | Adam Shero          | 2025-10-24        | 2025-10-21     |         69 |          -4 | Google Cloud: Add Grafana Google Cloud Logging Jobs                |
# | DEVOPS-8082 | In Progress | High       | Jorge Rodriguez  | Simon Davison      | simon.davison       | 2025-11-06        | 2025-10-27     |         84 |           9 | Unity prod EKS: move workloads to spot instances / Karpenter       |
# | DEVOPS-8067 | In Progress | High       | Jorge Rodriguez  | Angel Cancio       | Bolanle             | 2025-10-31        | 2025-10-23     |         88 |           3 | Gitlab Pre-Migration                                               |
# | DEVOPS-8030 | In Progress | High       | Jorge Rodriguez  | Grace Martorano    | Bolanle             | 2025-10-31        | 2025-10-02     |         96 |           3 | GitLab Migration from Self-Managed to Gitlab.com                   |
# | DEVOPS-8420 | In Progress | Medium     | Jorge Rodriguez  | simon.davison      | Adam Shero          | 2025-10-31        | 2025-10-24     |         17 |           3 | Upgrade Grafana helm chart in all clusters                         |
# | DEVOPS-8477 | In Progress | High       | Unknown          | Randall Puterbaugh | Dmytro Oliinyk      | NaT               | 2025-10-27     |          4 |         nan | Define USE Alert Standard                                          |
# | DEVOPS-8363 | In Progress | High       | Unknown          | Adam Shero         | Adam Shero          | 2025-10-31        | 2025-10-13     |         31 |           3 | Update Stakater Reloader Kubernetes Controller                     |
# | DEVOPS-8361 | In Progress | High       | Victoria Benecke | Joe Parlett        | Tom Terry           | 2025-10-24        | 2025-10-21     |         31 |          -4 | Migrate data-events-api to A2 Helm chart                           |
# | DEVOPS-8226 | In Progress | Medium     | Victoria Benecke | Jeff Slutz         | Tom Terry           | 2025-10-31        | 2025-10-21     |         88 |           3 | Remove Exclusive Stations Infrastructure                           |
# | DEVOPS-7901 | In Progress | Medium     | Victoria Benecke | Amanda Hankel      | sabrina.szymczak    | 2025-10-31        | 2025-10-09     |        116 |           3 | PE/PodSquad work to Deprecate SuperHiFi & I Like Music             |
# | DEVOPS-7082 | In Progress | Low        | Victoria Benecke | MeLissa Elwell     | Tom Terry           | 2025-12-31        | 2025-10-23     |        242 |          64 | Radio.com Moves                                                    |
# | DEVOPS-8488 | In Progress | Medium     | Zach Hahn        | Cullen Philippson  | Cullen Philippson   | 2025-10-24        | 2025-10-23     |          4 |          -4 | Create a scylla-cqlsh pod in Prod and QA                           |
# | DEVOPS-8094 | In Progress | High       | eric duell       | Juan Reyes         | Terry Dougal        | 2025-12-30        | 2025-10-23     |         81 |          63 | [EDP] Snowflake to BQ Migration                                    |
# | DEVOPS-7594 | In Progress | High       | sabrina szymczak | Jeff Slutz         | Andriy Petryshyn    | 2025-11-07        | 2025-10-28     |        173 |          10 | Reduce castfire DB master node from db.m5.2xlarge to db.r8g.xlarge |
# | DEVOPS-8153 | In Progress | Medium     | sabrina szymczak | Jeff Slutz         | Dmytro Oliinyk      | 2025-10-17        | 2025-10-21     |         69 |         -11 | [Prod] Amperwave: Podcast Feeds Service                            |
# | EIT-555     | In Progress | Medium     | scott ennover    | Jeff Stuewe        | Jorge.Rodriguez     | 2025-10-31        | 2025-10-13     |         46 |           3 | Acrnois - New 1y Contract (S09)                                    |
# +-------------+-------------+------------+------------------+--------------------+---------------------+-------------------+----------------+------------+-------------+--------------------------------------------------------------------+

# %%
print("="*60)
print("Tickets In Progress with no target end date or negative days left:")
print("="*60)
for x in range(len(top_10_rows)):
    if top_10_rows.iloc[x]['days_left'] < 0:
        print(top_10_rows.iloc[x]['creator_name']+": "+str(top_10_rows.iloc[x]['days_left'])+" days left")
        print(f"Summary: {top_10_rows.iloc[x]['summary'] }")
        print(f"https://entercomdigitalservices.atlassian.net/browse/{top_10_rows.iloc[x]['key']}")
        print("")
    if pd.isna(top_10_rows.iloc[x]['days_left']):
        print(top_10_rows.iloc[x]['creator_name']+": No target end date")
        print(f"Summary: {top_10_rows.iloc[x]['summary'] }")
        print(f"https://entercomdigitalservices.atlassian.net/browse/{top_10_rows.iloc[x]['key']}")
        print("")
# Out:
# ============================================================
# Tickets In Progress with no target end date or negative days left:
# ============================================================
# Ali Mir: No target end date
# Summary: AWS Airflow (MWAA) issue connecting to MySQL Clarity
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8448
#
# Chris Ulmer: -7.0 days left
# Summary: Build Kafka to GCS Confluent Connectors for (4) EDP Environments
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8370
#
# Adam Shero: -4.0 days left
# Summary: [Grafana Migration] Validate Migrated Dashboards
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8427
#
# simon.davison: -4.0 days left
# Summary: Scrub references to radio.com from all Cognito instances
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8233
#
# Adam Shero: -4.0 days left
# Summary: Google Cloud: Add Grafana Google Cloud Monitoring Scrape Jobs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8168
#
# Adam Shero: -4.0 days left
# Summary: Google Cloud: Add Grafana Google Cloud Logging Jobs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8167
#
# Randall Puterbaugh: No target end date
# Summary: Define USE Alert Standard
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8477
#
# Joe Parlett: -4.0 days left
# Summary: Migrate data-events-api to A2 Helm chart
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8361
#
# Cullen Philippson: -4.0 days left
# Summary: Create a scylla-cqlsh pod in Prod and QA
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8488
#
# Jeff Slutz: -11.0 days left
# Summary: [Prod] Amperwave: Podcast Feeds Service
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8153

# %%
# Build a report grouped by Business Lead
print("="*60)
print("Tickets grouped by Business Lead:")
print("="*60)
print("In Progress:")
print("="*60)
for business_lead, group in top_10_rows.groupby('bussiness_lead', sort=True):
    print("\n" + "="*80)
    print(f"Business Lead: {business_lead}")
    print("="*80)
    for _, row in group.iterrows():
        print(f"Creator:  {row['creator_name']}: {row['days_old']} days Ago")
        print(f"Assignee: {row['assignee_name']}")
        print(f"Summary: {row['summary']}")
        print(f"https://entercomdigitalservices.atlassian.net/browse/{row['key']}")
        print("")
# Out:
# ============================================================
# Tickets grouped by Business Lead:
# ============================================================
# In Progress:
# ============================================================
#
# ================================================================================
# Business Lead: Chris Ulmer
# ================================================================================
# Creator:  Ali Mir: 11 days Ago
# Assignee: Cullen Philippson
# Summary: AWS Airflow (MWAA) issue connecting to MySQL Clarity
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8448
#
# Creator:  Chris Ulmer: 29 days Ago
# Assignee: satish kumar marana
# Summary: Build Kafka to GCS Connectors for the EDP DEV Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8371
#
# Creator:  Chris Ulmer: 30 days Ago
# Assignee: satish kumar marana
# Summary: Build Kafka to GCS Confluent Connectors for (4) EDP Environments
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8370
#
# Creator:  Mrinal Kaustuv: 55 days Ago
# Assignee: Bolanle
# Summary: Add datasync for Placement IO file
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8247
#
#
# ================================================================================
# Business Lead: Jorge Rodriguez
# ================================================================================
# Creator:  Angel Cancio: 49 days Ago
# Assignee: Bolanle
# Summary: Register new 52 runners for the POC on gitlab.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8276
#
# Creator:  Angel Cancio: 49 days Ago
# Assignee: Bolanle
# Summary: Setup new runners for the POC
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8275
#
# Creator:  Adam Shero: 69 days Ago
# Assignee: Adam Shero
# Summary: Migrate From DataDog to Grafana Cloud
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8154
#
# Creator:  Angel Cancio: 88 days Ago
# Assignee: Bolanle
# Summary: Setup and Configure POC migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8078
#
# Creator:  Adam Shero: 16 days Ago
# Assignee: Tom Terry
# Summary: [Grafana Migration] Validate Migrated Dashboards
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8427
#
# Creator:  simon.davison: 60 days Ago
# Assignee: Dmytro Oliinyk
# Summary: Scrub references to radio.com from all Cognito instances
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8233
#
# Creator:  Adam Shero: 69 days Ago
# Assignee: Adam Shero
# Summary: Google Cloud: Add Grafana Google Cloud Monitoring Scrape Jobs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8168
#
# Creator:  Adam Shero: 69 days Ago
# Assignee: Adam Shero
# Summary: Google Cloud: Add Grafana Google Cloud Logging Jobs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8167
#
# Creator:  Simon Davison: 84 days Ago
# Assignee: simon.davison
# Summary: Unity prod EKS: move workloads to spot instances / Karpenter
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8082
#
# Creator:  Angel Cancio: 88 days Ago
# Assignee: Bolanle
# Summary: Gitlab Pre-Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8067
#
# Creator:  Grace Martorano: 96 days Ago
# Assignee: Bolanle
# Summary: GitLab Migration from Self-Managed to Gitlab.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8030
#
# Creator:  simon.davison: 17 days Ago
# Assignee: Adam Shero
# Summary: Upgrade Grafana helm chart in all clusters
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8420
#
#
# ================================================================================
# Business Lead: Unknown
# ================================================================================
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Dmytro Oliinyk
# Summary: Define USE Alert Standard
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8477
#
# Creator:  Adam Shero: 31 days Ago
# Assignee: Adam Shero
# Summary: Update Stakater Reloader Kubernetes Controller
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8363
#
#
# ================================================================================
# Business Lead: Victoria Benecke
# ================================================================================
# Creator:  Joe Parlett: 31 days Ago
# Assignee: Tom Terry
# Summary: Migrate data-events-api to A2 Helm chart
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8361
#
# Creator:  Jeff Slutz: 88 days Ago
# Assignee: Tom Terry
# Summary: Remove Exclusive Stations Infrastructure
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8226
#
# Creator:  Amanda Hankel: 116 days Ago
# Assignee: sabrina.szymczak
# Summary: PE/PodSquad work to Deprecate SuperHiFi & I Like Music
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7901
#
# Creator:  MeLissa Elwell: 242 days Ago
# Assignee: Tom Terry
# Summary: Radio.com Moves
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7082
#
#
# ================================================================================
# Business Lead: Zach Hahn
# ================================================================================
# Creator:  Cullen Philippson: 4 days Ago
# Assignee: Cullen Philippson
# Summary: Create a scylla-cqlsh pod in Prod and QA
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8488
#
#
# ================================================================================
# Business Lead: eric duell
# ================================================================================
# Creator:  Juan Reyes: 81 days Ago
# Assignee: Terry Dougal
# Summary: [EDP] Snowflake to BQ Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8094
#
#
# ================================================================================
# Business Lead: sabrina szymczak
# ================================================================================
# Creator:  Jeff Slutz: 173 days Ago
# Assignee: Andriy Petryshyn
# Summary: Reduce castfire DB master node from db.m5.2xlarge to db.r8g.xlarge
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7594
#
# Creator:  Jeff Slutz: 69 days Ago
# Assignee: Dmytro Oliinyk
# Summary: [Prod] Amperwave: Podcast Feeds Service
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8153
#
#
# ================================================================================
# Business Lead: scott ennover
# ================================================================================
# Creator:  Jeff Stuewe: 46 days Ago
# Assignee: Jorge.Rodriguez
# Summary: Acrnois - New 1y Contract (S09)
# https://entercomdigitalservices.atlassian.net/browse/EIT-555

# %% [markdown]
# ## --- Tickets in To Do Status ---

# %% [markdown]
# ## Generate the Report

# %%
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
today_date = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
df1 = df_issues[df_issues['status'] == 'To Do'].copy()  # Use .copy() to avoid SettingWithCopyWarning
df1['due_date_date'] = df1['project_due_date'].dt.date
df1['target_end_date'] = pd.to_datetime(df1['target_end_date'], errors='coerce').dt.date
df1['updated'] = pd.to_datetime(df1['updated'], errors='coerce').dt.date

# Ensure 'today' is a single date (not a column)
today_date = today.date() if hasattr(today, 'date') else pd.to_datetime(today).date()
df1['days_left'] = (df1['target_end_date'] - today_date).apply(lambda x: x.days if pd.notnull(x) else None)

# Get the top 20 rows with the highest days_old
top_10_indices = df1[['bussiness_lead','project_name','priority_id','target_end_date','days_old']].sort_values(by=['project_name','bussiness_lead','priority_id','days_old', 'target_end_date'], ascending=True).index
top_10_rows = df1.loc[top_10_indices]  # Select rows using the indices

# Print results for verification
print(f"All {len(top_10_rows)} Tickets as: {today_date} at {today.hour + 6}:{today.minute} CST")
#print(top_10_rows[['key','status','velocity_days','assignee_name','updated','summary']].to_string(index=False))
#print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
#               headers=['Ticket', 'Status', 'Priority','Business Lead','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','creator_name','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
               headers=['Ticket', 'Status', 'Priority','Business Lead','Creator Name','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))

# --- Save to CSV ---
# Save the DataFrame to a CSV file
output_file = 'jira_in_to_do.csv'
#top_10_rows.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
# --- Save to JSON ---
# Save the DataFrame to a JSON file
#output_file_json = 'jira_issues.json'
#top_10_rows.to_json(output_file_json, orient='records', lines=True)
#print(f"Data saved to {output_file_json}")
# --- Save to CSV ---
# Save the DataFrame to a CSV file
#output_file = 'jira_issues_total.csv'
#df_issues.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
#print("Generating PDF report...")
#generate_enhanced_report(top_10_rows,"Jira Issues In To Do","jira_in_to_do.pdf")
# Out:
# All 52 Tickets as: 2025-10-28 at 8:51 CST
# +-------------+----------+------------+------------------+--------------------------+---------------------+-------------------+----------------+------------+-------------+-------------------------------------------------------------------------------------------------------------------------+
# | Ticket      | Status   | Priority   | Business Lead    | Creator Name             | Assignee Name       | Target End Date   | Last Updated   |   Days Old |   Days Left | Summary                                                                                                                 |
# |-------------+----------+------------+------------------+--------------------------+---------------------+-------------------+----------------+------------+-------------+-------------------------------------------------------------------------------------------------------------------------|
# | DEVOPS-8486 | To Do    | High       | Chris Ulmer      | Gil Orellana             | Unassigned          | NaT               | 2025-10-27     |          4 |         nan | Gitlab release pipeline failing due to AssumeRoleWithWebIdentity error                                                  |
# | DEVOPS-8372 | To Do    | High       | Chris Ulmer      | Chris Ulmer              | satish kumar marana | NaT               | 2025-10-09     |         29 |         nan | Build Kafka to GCS Connectors for the EDP QA Environment                                                                |
# | DEVOPS-8386 | To Do    | Medium     | Chris Ulmer      | Chris Ulmer              | Juan Reyes          | NaT               | 2025-10-27     |         27 |         nan | Create GCS bucket for Kafka Data in the EDP PROD Environment                                                            |
# | DEVOPS-8377 | To Do    | Medium     | Chris Ulmer      | Mrinal Kaustuv           | Nazarii Sheremet    | NaT               | 2025-10-27     |         28 |         nan | Request to create new bucket  for braze currents project                                                                |
# | DEVOPS-8374 | To Do    | Medium     | Chris Ulmer      | Chris Ulmer              | satish kumar marana | NaT               | 2025-10-15     |         29 |         nan | Build Kafka to GCS Connectors for the EDP PROD Environment                                                              |
# | DEVOPS-8373 | To Do    | Medium     | Chris Ulmer      | Chris Ulmer              | satish kumar marana | NaT               | 2025-10-15     |         29 |         nan | Build Kafka to GCS Connectors for the EDP UAT Environment                                                               |
# | DEVOPS-8345 | To Do    | Low        | Chris Ulmer      | Gil Orellana             | Nazarii Sheremet    | NaT               | 2025-10-03     |         38 |         nan | Create S3 Bucket Lifecycle Policy                                                                                       |
# | DEVOPS-8253 | To Do    | Low        | Chris Ulmer      | Ryan Balsick             | Tom Terry           | NaT               | 2025-10-09     |         55 |         nan | Update groups to AW MySQL from Airflow AWS                                                                              |
# | DEVOPS-8476 | To Do    | High       | Jorge Rodriguez  | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-23     |          4 |         nan | Create Grafana USE Method Alerts                                                                                        |
# | DEVOPS-8423 | To Do    | High       | Jorge Rodriguez  | simon.davison            | Unassigned          | 2025-10-20        | 2025-10-22     |         17 |          -8 | Upgrade Grafana helm chart - amperwave prod                                                                             |
# | DEVOPS-8138 | To Do    | High       | Jorge Rodriguez  | Simon Davison            | Tom Terry           | 2025-10-09        | 2025-10-21     |         74 |         -19 | Fastly: clean up TLS certs                                                                                              |
# | DEVOPS-8425 | To Do    | Medium     | Jorge Rodriguez  | Adam Shero               | Tom Terry           | NaT               | 2025-10-15     |         16 |         nan | [AWS Org] Enable Enterprise Support for AWS Accounts                                                                    |
# | DEVOPS-8210 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-22     |         63 |         nan | Manually add|map|review users access to each project and group within Gitlab.com                                        |
# | DEVOPS-8202 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-22     |         63 |         nan | Re-register Gitlab Runners                                                                                              |
# | DEVOPS-8207 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-15     |         63 |         nan | GitLab Professional Support Executes the Migration Process                                                              |
# | DEVOPS-8205 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-07     |         63 |         nan | Manually Import Packages for all projects using package registry.                                                       |
# | DEVOPS-8204 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-07     |         63 |         nan | Review RBAC permissions under Corservice EKS Cluster                                                                    |
# | DEVOPS-8203 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-07     |         63 |         nan | Re-configure IAM roles and OIDC for gitlab runners - Corservice EKS Cluster                                             |
# | DEVOPS-8201 | To Do    | Medium     | Jorge Rodriguez  | Angel Cancio             | Bolanle             | NaT               | 2025-10-07     |         63 |         nan | Update | Reconfigure All Gitlab Pipelines                                                                               |
# | DEVOPS-8009 | To Do    | Medium     | Jorge Rodriguez  | Don.Furline              | Tom Terry           | 2025-08-29        | 2025-10-15     |         97 |         -60 | Remediation of Lambda Functions (Entercom Production)                                                                   |
# | DEVOPS-8459 | To Do    | Low        | Jorge Rodriguez  | Terry Dougal             | Andriy Petryshyn    | 2025-11-14        | 2025-10-27     |         10 |          17 | Build a runbook to change instance sizes in WO castfire                                                                 |
# | DEVOPS-8258 | To Do    | Low        | Jorge Rodriguez  | Juan Reyes               | Juan Reyes          | NaT               | 2025-09-22     |         53 |         nan | Create subnet for DS sandbox gcp project                                                                                |
# | DEVOPS-8238 | To Do    | Low        | Jorge Rodriguez  | simon.davison            | Dmytro Oliinyk      | NaT               | 2025-09-22     |         60 |         nan | Add HSTS policy to audacy.com                                                                                           |
# | DEVOPS-8472 | To Do    | Medium     | Josh Currier     | Brian Bosworth           | Cullen Philippson   | NaT               | 2025-10-23     |          5 |         nan | AW - Streaming Canary Cluster Creation                                                                                  |
# | DEVOPS-8461 | To Do    | Low        | Josh Currier     | Alec Sands               | Cullen Philippson   | NaT               | 2025-10-22     |         10 |         nan | Expose Server Logs from WO On Demand Account in Grafana                                                                 |
# | DEVOPS-8360 | To Do    | Low        | Josh Currier     | Jason Cox                | Cullen Philippson   | NaT               | 2025-10-22     |         31 |         nan | AW [Spike] Determine cost and feasibility of Canary deployment for Stand Alone Vader                                    |
# | DEVOPS-8471 | To Do    | High       | Tony Senes       | Zendesk Support for Jira | Unassigned          | NaT               | 2025-10-22     |          6 |         nan | stateofaudio.com redirect update                                                                                        |
# | DEVOPS-8478 | To Do    | High       | Unknown          | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-27     |          4 |         nan | Compile Name-Only USE Catalog & Metric Sources                                                                          |
# | DEVOPS-8485 | To Do    | Medium     | Unknown          | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-27     |          4 |         nan | Label & Scope Verification Sweep of USE Alerts                                                                          |
# | DEVOPS-8484 | To Do    | Medium     | Unknown          | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-27     |          4 |         nan | Create Edge USE Alerts (Fastly) in Grafana                                                                              |
# | DEVOPS-8482 | To Do    | Medium     | Unknown          | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-27     |          4 |         nan | Create Data-Plane USE Alerts (Redis + Confluent Kafka) in Grafana                                                       |
# | DEVOPS-8481 | To Do    | Medium     | Unknown          | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-27     |          4 |         nan | Create AWS Infra USE Alerts (EC2/EBS + RDS) in Grafana                                                                  |
# | DEVOPS-8480 | To Do    | Medium     | Unknown          | Randall Puterbaugh       | Denys Loboda        | NaT               | 2025-10-27     |          4 |         nan | Create Kubernetes USE Alerts (U/S/E) in Grafana                                                                         |
# | DEVOPS-8124 | To Do    | Low        | Victoria Benecke | Dewayne Korth            | satish kumar marana | NaT               | 2025-10-22     |         76 |         nan | [DevOps] [station tools] Station Tools Developers need access to https://conduktor-console.audacy2-prod.int.audacy.com/ |
# | DEVOPS-7979 | To Do    | Low        | Victoria Benecke | Johnathan Kulovitz       | Bolanle             | 2025-10-30        | 2025-10-22     |        104 |           2 | [podcasts] merge MR for new versions of internal podcast topics (PROD)                                                  |
# | DEVOPS-7980 | To Do    | Low        | Victoria Benecke | Johnathan Kulovitz       | Bolanle             | 2025-10-30        | 2025-10-22     |        104 |           2 | [content-publisher-podcast] merge MR for new content.podcast.update topic (PROD)                                        |
# | DEVOPS-7982 | To Do    | Low        | Victoria Benecke | Johnathan Kulovitz       | Bolanle             | 2025-11-18        | 2025-10-15     |        104 |          21 | [podcasts] delete prod-podcast-url-cache table (PROD)                                                                   |
# | DEVOPS-7984 | To Do    | Low        | Victoria Benecke | Johnathan Kulovitz       | Bolanle             | 2025-11-18        | 2025-10-15     |        104 |          21 | [podcasts] delete pre-existing s3 bucket for fetched rss feeds (PROD)                                                   |
# | DEVOPS-7941 | To Do    | Low        | Victoria Benecke | Johnathan Kulovitz       | Bolanle             | 2025-10-31        | 2025-10-22     |        109 |           3 | [podcasts] delete pre-existing s3 bucket for fetched rss feeds (STG)                                                    |
# | DEVOPS-7939 | To Do    | Low        | Victoria Benecke | Johnathan Kulovitz       | Bolanle             | 2025-10-31        | 2025-10-22     |        109 |           3 | [podcasts] delete stg-podcast-url-cache table (STG)                                                                     |
# | DEVOPS-8356 | To Do    | Urgent     | Zach Hahn        | Jason Cox                | Cullen Philippson   | NaT               | 2025-10-23     |         33 |         nan | Every service in AmperWave-Prod needs a memory alarm to catch OOM container cycles                                      |
# | DEVOPS-8350 | To Do    | High       | Zach Hahn        | Jonathan Duck            | Tom Terry           | NaT               | 2025-10-21     |         35 |         nan | [Vader] Permission Error Writing to S3                                                                                  |
# | DEVOPS-8252 | To Do    | Medium     | Zach Hahn        | Daniel.Newell            | Andriy Petryshyn    | NaT               | 2025-10-28     |         55 |         nan | Scylla: Update gc_grace_seconds on adcap tables                                                                         |
# | DEVOPS-8131 | To Do    | Low        | Zach Hahn        | Daniel.Newell            | Unassigned          | NaT               | 2025-10-22     |         75 |         nan | Add an Experian Direct Bucket for QA to test experian direct uploads                                                    |
# | DEVOPS-8445 | To Do    | High       | eric duell       | Christopher Dixon        | Terry Dougal        | 2025-10-30        | 2025-10-27     |         11 |           2 | Enable APIs in Google Cloud Project: prj-initiatives-prod                                                               |
# | DEVOPS-8283 | To Do    | High       | eric duell       | Juan Reyes               | Juan Reyes          | NaT               | 2025-10-09     |         48 |         nan | [NONPROD] Create serviceAccounts for prj-edp-prod-io-svc                                                                |
# | DEVOPS-8282 | To Do    | High       | eric duell       | Juan Reyes               | Juan Reyes          | NaT               | 2025-10-09     |         48 |         nan | [NONPROD] Create serviceAccounts for prj-edp-uat-io-svc                                                                 |
# | DEVOPS-8274 | To Do    | High       | eric duell       | Terry Dougal             | Terry Dougal        | NaT               | 2025-10-09     |         49 |         nan | [PROD] Enable apis for prj-edp-prod-edw                                                                                 |
# | DEVOPS-8449 | To Do    | Medium     | eric duell       | Christopher Dixon        | Terry Dougal        | 2025-10-31        | 2025-10-27     |         11 |           3 | Provision Resources, Groups, and Roles to prj-enterprise-ops for DAC Team                                               |
# | DEVOPS-8179 | To Do    | Medium     | eric duell       | Juan Reyes               | Terry Dougal        | 2025-09-11        | 2025-09-26     |         68 |         -47 | [PROD] Create subnets for PROD projects in the LZ                                                                       |
# | DEVOPS-8097 | To Do    | Low        | eric duell       | Juan Reyes               | Terry Dougal        | 2025-10-09        | 2025-10-22     |         81 |         -19 | [PROD] Create folder structure for EDP                                                                                  |
# | DEVOPS-8224 | To Do    | Low        | sabrina szymczak | Jeff Slutz               | Jeff Naparstek      | NaT               | 2025-10-22     |         61 |         nan | Gitops Prod Write Access for Podcast Team                                                                               |
# +-------------+----------+------------+------------------+--------------------------+---------------------+-------------------+----------------+------------+-------------+-------------------------------------------------------------------------------------------------------------------------+

# %%
print("="*60)
print("Tickets older than 50 days and Urgent priority:")
print("="*60)
# Use a set to track which tickets have already been printed
printed_keys = set()
for idx, row in top_10_rows.iterrows():
    is_old = row['days_old'] > 50
    is_urgent = row['priority_name'] == "Urgent"
    if is_old or is_urgent:
        if row['key'] not in printed_keys:
            msg = f"Creator: {row['creator_name']} - "
            if is_old and is_urgent:
                msg += f"{row['days_old']} days old, Urgent priority"
            elif is_old:
                msg += f"{row['days_old']} days old"
            else:
                msg += "Urgent priority"
            print(msg)
            #print(f"Summary: {top_10_rows.iloc[idx]['summary'] }")
            print(f"Summary: {row['summary'] }")
            print(f"https://entercomdigitalservices.atlassian.net/browse/{row['key']}")
            print("")
            printed_keys.add(row['key'])
# Out:
# ============================================================
# Tickets older than 50 days and Urgent priority:
# ============================================================
# Creator: Ryan Balsick - 55 days old
# Summary: Update groups to AW MySQL from Airflow AWS
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8253
#
# Creator: Simon Davison - 74 days old
# Summary: Fastly: clean up TLS certs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8138
#
# Creator: Angel Cancio - 63 days old
# Summary: Manually add|map|review users access to each project and group within Gitlab.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8210
#
# Creator: Angel Cancio - 63 days old
# Summary: Re-register Gitlab Runners
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8202
#
# Creator: Angel Cancio - 63 days old
# Summary: GitLab Professional Support Executes the Migration Process
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8207
#
# Creator: Angel Cancio - 63 days old
# Summary: Manually Import Packages for all projects using package registry.
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8205
#
# Creator: Angel Cancio - 63 days old
# Summary: Review RBAC permissions under Corservice EKS Cluster
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8204
#
# Creator: Angel Cancio - 63 days old
# Summary: Re-configure IAM roles and OIDC for gitlab runners - Corservice EKS Cluster
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8203
#
# Creator: Angel Cancio - 63 days old
# Summary: Update | Reconfigure All Gitlab Pipelines
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8201
#
# Creator: Don.Furline - 97 days old
# Summary: Remediation of Lambda Functions (Entercom Production)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8009
#
# Creator: Juan Reyes - 53 days old
# Summary: Create subnet for DS sandbox gcp project
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8258
#
# Creator: simon.davison - 60 days old
# Summary: Add HSTS policy to audacy.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8238
#
# Creator: Dewayne Korth - 76 days old
# Summary: [DevOps] [station tools] Station Tools Developers need access to https://conduktor-console.audacy2-prod.int.audacy.com/
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8124
#
# Creator: Johnathan Kulovitz - 104 days old
# Summary: [podcasts] merge MR for new versions of internal podcast topics (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7979
#
# Creator: Johnathan Kulovitz - 104 days old
# Summary: [content-publisher-podcast] merge MR for new content.podcast.update topic (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7980
#
# Creator: Johnathan Kulovitz - 104 days old
# Summary: [podcasts] delete prod-podcast-url-cache table (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7982
#
# Creator: Johnathan Kulovitz - 104 days old
# Summary: [podcasts] delete pre-existing s3 bucket for fetched rss feeds (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7984
#
# Creator: Johnathan Kulovitz - 109 days old
# Summary: [podcasts] delete pre-existing s3 bucket for fetched rss feeds (STG)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7941
#
# Creator: Johnathan Kulovitz - 109 days old
# Summary: [podcasts] delete stg-podcast-url-cache table (STG)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7939
#
# Creator: Jason Cox - Urgent priority
# Summary: Every service in AmperWave-Prod needs a memory alarm to catch OOM container cycles
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8356
#
# Creator: Daniel.Newell - 55 days old
# Summary: Scylla: Update gc_grace_seconds on adcap tables
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8252
#
# Creator: Daniel.Newell - 75 days old
# Summary: Add an Experian Direct Bucket for QA to test experian direct uploads
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8131
#
# Creator: Juan Reyes - 68 days old
# Summary: [PROD] Create subnets for PROD projects in the LZ
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8179
#
# Creator: Juan Reyes - 81 days old
# Summary: [PROD] Create folder structure for EDP
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8097
#
# Creator: Jeff Slutz - 61 days old
# Summary: Gitops Prod Write Access for Podcast Team
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8224

# %%
for (owner, priority), group in top_10_rows.groupby(['bussiness_lead', 'priority_name'], sort=True):
    print("")
    print("="*80)
    print(f"Tickets for Business Lead: {owner} - Priority: {priority}")
    print("="*80)
    for _, row in group.iterrows():
        print(f"Creator:  {row['creator_name']}: {row['days_old']} days Ago")
        print(f"Assignee: {row['assignee_name']}")
        print(f"Summary: {row['summary'] }")
        print(f"https://entercomdigitalservices.atlassian.net/browse/{row['key']}")
        print("")
# Out:
# ================================================================================
# Tickets for Business Lead: Chris Ulmer - Priority: High
# ================================================================================
# Creator:  Gil Orellana: 4 days Ago
# Assignee: Unassigned
# Summary: Gitlab release pipeline failing due to AssumeRoleWithWebIdentity error
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8486
#
# Creator:  Chris Ulmer: 29 days Ago
# Assignee: satish kumar marana
# Summary: Build Kafka to GCS Connectors for the EDP QA Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8372
#
#
# ================================================================================
# Tickets for Business Lead: Chris Ulmer - Priority: Low
# ================================================================================
# Creator:  Gil Orellana: 38 days Ago
# Assignee: Nazarii Sheremet
# Summary: Create S3 Bucket Lifecycle Policy
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8345
#
# Creator:  Ryan Balsick: 55 days Ago
# Assignee: Tom Terry
# Summary: Update groups to AW MySQL from Airflow AWS
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8253
#
#
# ================================================================================
# Tickets for Business Lead: Chris Ulmer - Priority: Medium
# ================================================================================
# Creator:  Chris Ulmer: 27 days Ago
# Assignee: Juan Reyes
# Summary: Create GCS bucket for Kafka Data in the EDP PROD Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8386
#
# Creator:  Mrinal Kaustuv: 28 days Ago
# Assignee: Nazarii Sheremet
# Summary: Request to create new bucket  for braze currents project
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8377
#
# Creator:  Chris Ulmer: 29 days Ago
# Assignee: satish kumar marana
# Summary: Build Kafka to GCS Connectors for the EDP PROD Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8374
#
# Creator:  Chris Ulmer: 29 days Ago
# Assignee: satish kumar marana
# Summary: Build Kafka to GCS Connectors for the EDP UAT Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8373
#
#
# ================================================================================
# Tickets for Business Lead: Jorge Rodriguez - Priority: High
# ================================================================================
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Create Grafana USE Method Alerts
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8476
#
# Creator:  simon.davison: 17 days Ago
# Assignee: Unassigned
# Summary: Upgrade Grafana helm chart - amperwave prod
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8423
#
# Creator:  Simon Davison: 74 days Ago
# Assignee: Tom Terry
# Summary: Fastly: clean up TLS certs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8138
#
#
# ================================================================================
# Tickets for Business Lead: Jorge Rodriguez - Priority: Low
# ================================================================================
# Creator:  Terry Dougal: 10 days Ago
# Assignee: Andriy Petryshyn
# Summary: Build a runbook to change instance sizes in WO castfire
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8459
#
# Creator:  Juan Reyes: 53 days Ago
# Assignee: Juan Reyes
# Summary: Create subnet for DS sandbox gcp project
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8258
#
# Creator:  simon.davison: 60 days Ago
# Assignee: Dmytro Oliinyk
# Summary: Add HSTS policy to audacy.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8238
#
#
# ================================================================================
# Tickets for Business Lead: Jorge Rodriguez - Priority: Medium
# ================================================================================
# Creator:  Adam Shero: 16 days Ago
# Assignee: Tom Terry
# Summary: [AWS Org] Enable Enterprise Support for AWS Accounts
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8425
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: Manually add|map|review users access to each project and group within Gitlab.com
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8210
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: Re-register Gitlab Runners
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8202
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: GitLab Professional Support Executes the Migration Process
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8207
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: Manually Import Packages for all projects using package registry.
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8205
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: Review RBAC permissions under Corservice EKS Cluster
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8204
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: Re-configure IAM roles and OIDC for gitlab runners - Corservice EKS Cluster
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8203
#
# Creator:  Angel Cancio: 63 days Ago
# Assignee: Bolanle
# Summary: Update | Reconfigure All Gitlab Pipelines
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8201
#
# Creator:  Don.Furline: 97 days Ago
# Assignee: Tom Terry
# Summary: Remediation of Lambda Functions (Entercom Production)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8009
#
#
# ================================================================================
# Tickets for Business Lead: Josh Currier - Priority: Low
# ================================================================================
# Creator:  Alec Sands: 10 days Ago
# Assignee: Cullen Philippson
# Summary: Expose Server Logs from WO On Demand Account in Grafana
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8461
#
# Creator:  Jason Cox: 31 days Ago
# Assignee: Cullen Philippson
# Summary: AW [Spike] Determine cost and feasibility of Canary deployment for Stand Alone Vader
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8360
#
#
# ================================================================================
# Tickets for Business Lead: Josh Currier - Priority: Medium
# ================================================================================
# Creator:  Brian Bosworth: 5 days Ago
# Assignee: Cullen Philippson
# Summary: AW - Streaming Canary Cluster Creation
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8472
#
#
# ================================================================================
# Tickets for Business Lead: Tony Senes - Priority: High
# ================================================================================
# Creator:  Zendesk Support for Jira: 6 days Ago
# Assignee: Unassigned
# Summary: stateofaudio.com redirect update
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8471
#
#
# ================================================================================
# Tickets for Business Lead: Unknown - Priority: High
# ================================================================================
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Compile Name-Only USE Catalog & Metric Sources
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8478
#
#
# ================================================================================
# Tickets for Business Lead: Unknown - Priority: Medium
# ================================================================================
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Label & Scope Verification Sweep of USE Alerts
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8485
#
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Create Edge USE Alerts (Fastly) in Grafana
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8484
#
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Create Data-Plane USE Alerts (Redis + Confluent Kafka) in Grafana
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8482
#
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Create AWS Infra USE Alerts (EC2/EBS + RDS) in Grafana
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8481
#
# Creator:  Randall Puterbaugh: 4 days Ago
# Assignee: Denys Loboda
# Summary: Create Kubernetes USE Alerts (U/S/E) in Grafana
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8480
#
#
# ================================================================================
# Tickets for Business Lead: Victoria Benecke - Priority: Low
# ================================================================================
# Creator:  Dewayne Korth: 76 days Ago
# Assignee: satish kumar marana
# Summary: [DevOps] [station tools] Station Tools Developers need access to https://conduktor-console.audacy2-prod.int.audacy.com/
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8124
#
# Creator:  Johnathan Kulovitz: 104 days Ago
# Assignee: Bolanle
# Summary: [podcasts] merge MR for new versions of internal podcast topics (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7979
#
# Creator:  Johnathan Kulovitz: 104 days Ago
# Assignee: Bolanle
# Summary: [content-publisher-podcast] merge MR for new content.podcast.update topic (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7980
#
# Creator:  Johnathan Kulovitz: 104 days Ago
# Assignee: Bolanle
# Summary: [podcasts] delete prod-podcast-url-cache table (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7982
#
# Creator:  Johnathan Kulovitz: 104 days Ago
# Assignee: Bolanle
# Summary: [podcasts] delete pre-existing s3 bucket for fetched rss feeds (PROD)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7984
#
# Creator:  Johnathan Kulovitz: 109 days Ago
# Assignee: Bolanle
# Summary: [podcasts] delete pre-existing s3 bucket for fetched rss feeds (STG)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7941
#
# Creator:  Johnathan Kulovitz: 109 days Ago
# Assignee: Bolanle
# Summary: [podcasts] delete stg-podcast-url-cache table (STG)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7939
#
#
# ================================================================================
# Tickets for Business Lead: Zach Hahn - Priority: High
# ================================================================================
# Creator:  Jonathan Duck: 35 days Ago
# Assignee: Tom Terry
# Summary: [Vader] Permission Error Writing to S3
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8350
#
#
# ================================================================================
# Tickets for Business Lead: Zach Hahn - Priority: Low
# ================================================================================
# Creator:  Daniel.Newell: 75 days Ago
# Assignee: Unassigned
# Summary: Add an Experian Direct Bucket for QA to test experian direct uploads
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8131
#
#
# ================================================================================
# Tickets for Business Lead: Zach Hahn - Priority: Medium
# ================================================================================
# Creator:  Daniel.Newell: 55 days Ago
# Assignee: Andriy Petryshyn
# Summary: Scylla: Update gc_grace_seconds on adcap tables
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8252
#
#
# ================================================================================
# Tickets for Business Lead: Zach Hahn - Priority: Urgent
# ================================================================================
# Creator:  Jason Cox: 33 days Ago
# Assignee: Cullen Philippson
# Summary: Every service in AmperWave-Prod needs a memory alarm to catch OOM container cycles
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8356
#
#
# ================================================================================
# Tickets for Business Lead: eric duell - Priority: High
# ================================================================================
# Creator:  Christopher Dixon: 11 days Ago
# Assignee: Terry Dougal
# Summary: Enable APIs in Google Cloud Project: prj-initiatives-prod
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8445
#
# Creator:  Juan Reyes: 48 days Ago
# Assignee: Juan Reyes
# Summary: [NONPROD] Create serviceAccounts for prj-edp-prod-io-svc
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8283
#
# Creator:  Juan Reyes: 48 days Ago
# Assignee: Juan Reyes
# Summary: [NONPROD] Create serviceAccounts for prj-edp-uat-io-svc
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8282
#
# Creator:  Terry Dougal: 49 days Ago
# Assignee: Terry Dougal
# Summary: [PROD] Enable apis for prj-edp-prod-edw
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8274
#
#
# ================================================================================
# Tickets for Business Lead: eric duell - Priority: Low
# ================================================================================
# Creator:  Juan Reyes: 81 days Ago
# Assignee: Terry Dougal
# Summary: [PROD] Create folder structure for EDP
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8097
#
#
# ================================================================================
# Tickets for Business Lead: eric duell - Priority: Medium
# ================================================================================
# Creator:  Christopher Dixon: 11 days Ago
# Assignee: Terry Dougal
# Summary: Provision Resources, Groups, and Roles to prj-enterprise-ops for DAC Team
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8449
#
# Creator:  Juan Reyes: 68 days Ago
# Assignee: Terry Dougal
# Summary: [PROD] Create subnets for PROD projects in the LZ
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8179
#
#
# ================================================================================
# Tickets for Business Lead: sabrina szymczak - Priority: Low
# ================================================================================
# Creator:  Jeff Slutz: 61 days Ago
# Assignee: Jeff Naparstek
# Summary: Gitops Prod Write Access for Podcast Team
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8224

# %% [markdown]
# ## --- Tickets in Validating Status ---

# %% [markdown]
# ## Generate the Report

# %%
#df_issues['status'].unique()

# %%
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
today_date = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
df1 = df_issues[df_issues['status'] == 'Validating'].copy()  # Use .copy() to avoid SettingWithCopyWarning
df1['due_date_date'] = df1['project_due_date'].dt.date
df1['target_end_date'] = pd.to_datetime(df1['target_end_date'], errors='coerce').dt.date
df1['updated'] = pd.to_datetime(df1['updated'], errors='coerce').dt.date

# Ensure 'today' is a single date (not a column)
today_date = today.date() if hasattr(today, 'date') else pd.to_datetime(today).date()
df1['days_left'] = (df1['target_end_date'] - today_date).apply(lambda x: x.days if pd.notnull(x) else None)

# Get the top 20 rows with the highest days_old
top_10_indices = df1[['bussiness_lead','project_name','priority_id','target_end_date','days_old']].sort_values(by=['bussiness_lead','project_name','priority_id','days_old', 'target_end_date'], ascending=True).index
top_10_rows = df1.loc[top_10_indices]  # Select rows using the indices

# Print results for verification
print(f"All {len(top_10_rows)} Tickets as: {today_date} at {today.hour + 6}:{today.minute} CST")
#print(top_10_rows[['key','status','velocity_days','assignee_name','updated','summary']].to_string(index=False))
print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','creator_name','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
            headers=['Ticket', 'Status', 'Priority','Business Lead','Creator Name','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
# --- Save to CSV ---
# Save the DataFrame to a CSV file
output_file = 'jira_in_validatig.csv'
#top_10_rows.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
# --- Save to JSON ---
# Save the DataFrame to a JSON file
#output_file_json = 'jira_issues.json'
#top_10_rows.to_json(output_file_json, orient='records', lines=True)
#print(f"Data saved to {output_file_json}")
# --- Save to CSV ---
# Save the DataFrame to a CSV file
#output_file = 'jira_issues_total.csv'
#df_issues.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
#print("Generating PDF report...")
#generate_enhanced_report(top_10_rows,"Jira Issues In Validatig Status","jira_in_validatig.pdf")
# Out:
# All 5 Tickets as: 2025-10-28 at 8:51 CST
# +-------------+------------+------------+------------------+----------------+-------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------------------------------+
# | Ticket      | Status     | Priority   | Business Lead    | Creator Name   | Assignee Name     | Target End Date   | Last Updated   |   Days Old |   Days Left | Summary                                                                                                       |
# |-------------+------------+------------+------------------+----------------+-------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------------------------------|
# | DEVOPS-8384 | Validating | High       | Chris Ulmer      | Chris Ulmer    | Juan Reyes        | NaT               | 2025-10-24     |         27 |         nan | Create GCS bucket for Kafka Data in the EDP QA Environment                                                    |
# | DEVOPS-8410 | Validating | None       | Jorge Rodriguez  | Terry Dougal   | Terry Dougal      | 2025-10-28        | 2025-10-22     |         19 |           0 | Architect a GCP bucket design                                                                                 |
# | DEVOPS-8409 | Validating | High       | Josh Currier     | Bryan Harris   | Cullen Philippson | 2025-10-22        | 2025-10-22     |         19 |          -6 | CoreV2 - Cloud front distribution is geo blocking outside the US                                              |
# | DEVOPS-8462 | Validating | High       | Victoria Benecke | Ben Bonora     | simon.davison     | NaT               | 2025-10-23     |         10 |         nan | [Station Tools][RebelMouse] Create External Read-Only Replica of Production Elasticsearch Domain (unity-prod) |
# | DEVOPS-6507 | Validating | Low        | Zach Hahn        | Jonathan Duck  | Andriy Petryshyn  | 2025-09-11        | 2025-10-22     |        368 |         -47 | [Nonprod] Amperwave: Deploy "Boop" EKS Service                                                                |
# +-------------+------------+------------+------------------+----------------+-------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------------------------------+

# %%
print("="*60)
print("Tickets Validating:")
print("="*60)
for x in range(len(top_10_rows)):
    print("-"*100)
    print("Business Lead: "+top_10_rows['bussiness_lead'].iloc[x])
    print("Creator: "+top_10_rows['creator_name'].iloc[x],"-> "+str(top_10_rows.iloc[x]['days_old'])+" days old")
    print(f"Summary: {top_10_rows.iloc[x]['summary'] }")
    print(f"https://entercomdigitalservices.atlassian.net/browse/{top_10_rows['key'].iloc[x]}")
# Out:
# ============================================================
# Tickets Validating:
# ============================================================
# ----------------------------------------------------------------------------------------------------
# Business Lead: Chris Ulmer
# Creator: Chris Ulmer -> 27 days old
# Summary: Create GCS bucket for Kafka Data in the EDP QA Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8384
# ----------------------------------------------------------------------------------------------------
# Business Lead: Jorge Rodriguez
# Creator: Terry Dougal -> 19 days old
# Summary: Architect a GCP bucket design
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8410
# ----------------------------------------------------------------------------------------------------
# Business Lead: Josh Currier
# Creator: Bryan Harris -> 19 days old
# Summary: CoreV2 - Cloud front distribution is geo blocking outside the US
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8409
# ----------------------------------------------------------------------------------------------------
# Business Lead: Victoria Benecke
# Creator: Ben Bonora -> 10 days old
# Summary: [Station Tools][RebelMouse] Create External Read-Only Replica of Production Elasticsearch Domain (unity-prod)
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8462
# ----------------------------------------------------------------------------------------------------
# Business Lead: Zach Hahn
# Creator: Jonathan Duck -> 368 days old
# Summary: [Nonprod] Amperwave: Deploy "Boop" EKS Service
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-6507

# %% [markdown]
# ## --- Tickets in Blocked Status ---

# %% [markdown]
# ## Generate the Report

# %%
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
today_date = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
df1 = df_issues[df_issues['status'] == 'Blocked'].copy()  # Use .copy() to avoid SettingWithCopyWarning
df1['due_date_date'] = df1['project_due_date'].dt.date
df1['target_end_date'] = pd.to_datetime(df1['target_end_date'], errors='coerce').dt.date
df1['updated'] = pd.to_datetime(df1['updated'], errors='coerce').dt.date

# Ensure 'today' is a single date (not a column)
today_date = today.date() if hasattr(today, 'date') else pd.to_datetime(today).date()
df1['days_left'] = (df1['target_end_date'] - today_date).apply(lambda x: x.days if pd.notnull(x) else None)

# Get the top 20 rows with the highest days_old
top_10_indices = df1[['bussiness_lead','project_name','priority_id','target_end_date','days_old']].sort_values(by=['bussiness_lead','project_name','priority_id','days_old', 'target_end_date'], ascending=True).index
top_10_rows = df1.loc[top_10_indices]  # Select rows using the indices

# Print results for verification
print(f"All {len(top_10_rows)} Tickets as: {today_date} at {today.hour + 6}:{today.minute} CST")
#print(top_10_rows[['key','status','velocity_days','assignee_name','updated','summary']].to_string(index=False))
#print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
#               headers=['Ticket', 'Status', 'Priority','Business Lead','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','creator_name','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
               headers=['Ticket', 'Status', 'Priority','Business Lead','Creator Name','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))

# --- Save to CSV ---
# Save the DataFrame to a CSV file
output_file = 'jira_in_Blocked.csv'
#top_10_rows.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
# --- Save to JSON ---
# Save the DataFrame to a JSON file
#output_file_json = 'jira_issues.json'
#top_10_rows.to_json(output_file_json, orient='records', lines=True)
#print(f"Data saved to {output_file_json}")
# --- Save to CSV ---
# Save the DataFrame to a CSV file
#output_file = 'jira_issues_total.csv'
#df_issues.to_csv(output_file, index=False)
#print(f"Data saved to {output_file}")
#print("Generating PDF report...")
#generate_enhanced_report(top_10_rows,"Jira Issues In Blocked Status","jira_in_blocked.pdf")
# Out:
# All 7 Tickets as: 2025-10-28 at 8:51 CST
# +-------------+----------+------------+------------------+---------------------+---------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------+
# | Ticket      | Status   | Priority   | Business Lead    | Creator Name        | Assignee Name       | Target End Date   | Last Updated   |   Days Old |   Days Left | Summary                                                                               |
# |-------------+----------+------------+------------------+---------------------+---------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------|
# | DEVOPS-8454 | Blocked  | Medium     | Chris Ulmer      | Fazila Ashraf       | Terry Dougal        | NaT               | 2025-10-22     |         10 |         nan | Request to create new bucket for Google sheets                                        |
# | DEVOPS-8385 | Blocked  | Medium     | Chris Ulmer      | Chris Ulmer         | Juan Reyes          | NaT               | 2025-10-27     |         27 |         nan | Create GCS bucket for Kafka Data in the EDP UAT Environment                           |
# | DEVOPS-8408 | Blocked  | High       | Jorge Rodriguez  | Adam Shero          | Adam Shero          | 2025-10-10        | 2025-10-15     |         19 |         -18 | [Team A2 Prod] Flux Not Pushing Image Tags                                            |
# | DEVOPS-7964 | Blocked  | Medium     | Jorge Rodriguez  | satish kumar marana | satish kumar marana | NaT               | 2025-10-23     |        105 |         nan | Delete all un used topics from nonprod cluster and also old versioned kstream topics. |
# | DEVOPS-8287 | Blocked  | High       | Victoria Benecke | Kenny Lanza         | Unassigned          | NaT               | 2025-10-10     |         47 |         nan | [DevOps] [ROC] Re-enable podcast generation cron job                                  |
# | DEVOPS-6908 | Blocked  | High       | Victoria Benecke | stephen.smith       | simon.davison       | NaT               | 2025-10-21     |        265 |         nan | Create New OpenSearch Domain in NonProd                                               |
# | DEVOPS-8086 | Blocked  | Urgent     | Zach Hahn        | Alec Sands          | Cullen Philippson   | 2025-08-06        | 2025-10-10     |         84 |         -83 | New Gitops Encrypted Env Vars for Clarity                                             |
# +-------------+----------+------------+------------------+---------------------+---------------------+-------------------+----------------+------------+-------------+---------------------------------------------------------------------------------------+

# %%
print("="*60)
print("Tickets BLOCKED:")
print("="*60)
for x in range(len(top_10_rows)):
    print("-"*100)
    print("Business Lead: "+top_10_rows['bussiness_lead'].iloc[x])
    print(top_10_rows['creator_name'].iloc[x],"-> "+str(top_10_rows.iloc[x]['days_old'])+" days old")
    print(f"Summary: {top_10_rows.iloc[x]['summary'] }")
    print(f"https://entercomdigitalservices.atlassian.net/browse/{top_10_rows['key'].iloc[x]}")
# Out:
# ============================================================
# Tickets BLOCKED:
# ============================================================
# ----------------------------------------------------------------------------------------------------
# Business Lead: Chris Ulmer
# Fazila Ashraf -> 10 days old
# Summary: Request to create new bucket for Google sheets
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8454
# ----------------------------------------------------------------------------------------------------
# Business Lead: Chris Ulmer
# Chris Ulmer -> 27 days old
# Summary: Create GCS bucket for Kafka Data in the EDP UAT Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8385
# ----------------------------------------------------------------------------------------------------
# Business Lead: Jorge Rodriguez
# Adam Shero -> 19 days old
# Summary: [Team A2 Prod] Flux Not Pushing Image Tags
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8408
# ----------------------------------------------------------------------------------------------------
# Business Lead: Jorge Rodriguez
# satish kumar marana -> 105 days old
# Summary: Delete all un used topics from nonprod cluster and also old versioned kstream topics.
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7964
# ----------------------------------------------------------------------------------------------------
# Business Lead: Victoria Benecke
# Kenny Lanza -> 47 days old
# Summary: [DevOps] [ROC] Re-enable podcast generation cron job
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8287
# ----------------------------------------------------------------------------------------------------
# Business Lead: Victoria Benecke
# stephen.smith -> 265 days old
# Summary: Create New OpenSearch Domain in NonProd
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-6908
# ----------------------------------------------------------------------------------------------------
# Business Lead: Zach Hahn
# Alec Sands -> 84 days old
# Summary: New Gitops Encrypted Env Vars for Clarity
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8086

# %% [markdown]
# ## --- Tickets in Tech Discovery Status ---

# %% [markdown]
# ## Generate the Report

# %%
today = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
today_date = pd.to_datetime('today', utc=True, errors='coerce').tz_convert('UTC-06:00')
df1 = df_issues[df_issues['status'] == 'Tech Discovery Required'].copy()  # Use .copy() to avoid SettingWithCopyWarning
df1['due_date_date'] = df1['project_due_date'].dt.date
df1['target_end_date'] = pd.to_datetime(df1['target_end_date'], errors='coerce').dt.date
df1['updated'] = pd.to_datetime(df1['updated'], errors='coerce').dt.date

# Ensure 'today' is a single date (not a column)
today_date = today.date() if hasattr(today, 'date') else pd.to_datetime(today).date()
# Ensure both are datetime64[ns] for subtraction
df1['days_left'] = (pd.to_datetime(df1['target_end_date']) - pd.to_datetime(today_date)).dt.days

# Get the top 20 rows with the highest days_old
top_10_indices = df1[['bussiness_lead','project_name','priority_id','target_end_date','days_old']].sort_values(by=['bussiness_lead','project_name','priority_id','days_old', 'target_end_date'], ascending=True).index
top_10_rows = df1.loc[top_10_indices]  # Select rows using the indices

# Print results for verification
print(f"All {len(top_10_rows)} Tickets as: {today_date} at {today.hour + 6}:{today.minute} CST")
#print(top_10_rows[['key','status','velocity_days','assignee_name','updated','summary']].to_string(index=False))
#print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
#               headers=['Ticket', 'Status', 'Priority','Business Lead','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
print(tabulate(top_10_rows[['key','status','priority_name','bussiness_lead','creator_name','assignee_name','target_end_date','updated','days_old','days_left','summary']].values, 
               headers=['Ticket', 'Status', 'Priority','Business Lead','Creator Name','Assignee Name','Target End Date','Last Updated', 'Days Old', 'Days Left','Summary'], tablefmt='psql', showindex=False))
# Out:
# All 10 Tickets as: 2025-10-28 at 8:51 CST
# +-------------+-------------------------+------------+------------------+--------------------+--------------------+-------------------+----------------+------------+-------------+-----------------------------------------------------------------------------------+
# | Ticket      | Status                  | Priority   | Business Lead    | Creator Name       | Assignee Name      | Target End Date   | Last Updated   |   Days Old |   Days Left | Summary                                                                           |
# |-------------+-------------------------+------------+------------------+--------------------+--------------------+-------------------+----------------+------------+-------------+-----------------------------------------------------------------------------------|
# | DEVOPS-8489 | Tech Discovery Required | High       | Jorge Rodriguez  | Cullen Philippson  | Cullen Philippson  | NaT               | 2025-10-24     |          4 |         nan | Create a CIDR range for FileDataGov_Prod account for accessing WO Prod 01 account |
# | DEVOPS-8068 | Tech Discovery Required | High       | Jorge Rodriguez  | Angel Cancio       | Bolanle            | NaT               | 2025-10-15     |         88 |         nan | Gitlab Migration                                                                  |
# | DEVOPS-8069 | Tech Discovery Required | High       | Jorge Rodriguez  | Angel Cancio       | Bolanle            | NaT               | 2025-10-15     |         88 |         nan | Gitlab Post-Migration                                                             |
# | DEVOPS-8128 | Tech Discovery Required | Medium     | Jorge Rodriguez  | Angel Cancio       | Bolanle            | NaT               | 2025-10-16     |         75 |         nan | POC - Import NPM packages                                                         |
# | DEVOPS-7660 | Tech Discovery Required | Medium     | Jorge Rodriguez  | Randall Puterbaugh | Randall Puterbaugh | NaT               | 2025-10-23     |        160 |         nan | Migration of Recommendation Services to A2 Environment                            |
# | DEVOPS-8404 | Tech Discovery Required | Medium     | Josh Currier     | Josh Currier       | Unassigned         | NaT               | 2025-10-23     |         20 |         nan | Chaos Monkey Testing Plan                                                         |
# | DEVOPS-8255 | Tech Discovery Required | Medium     | Victoria Benecke | Joe Parlett        | Randall Puterbaugh | NaT               | 2025-10-23     |         54 |         nan | [Apigee/Fastly] Log actual client IP of requests in Apigee logs                   |
# | DEVOPS-8483 | Tech Discovery Required | Medium     | eric duell       | Christopher Dixon  | Randall Puterbaugh | NaT               | 2025-10-23     |          4 |         nan | Create Nonprod and Prod GC Projects for Techolution AI Initiative                 |
# | DEVOPS-8487 | Tech Discovery Required | Medium     | eric duell       | Christopher Dixon  | Randall Puterbaugh | NaT               | 2025-10-23     |          4 |         nan | Create Nonprod GC Project for DAC AI Labs                                         |
# | DEVOPS-8277 | Tech Discovery Required | Medium     | eric duell       | Christopher Dixon  | Denys Loboda       | NaT               | 2025-10-01     |         48 |         nan | Enable DAC team to restart K8s workloads in prj-initiatives-nonprod project       |
# +-------------+-------------------------+------------+------------------+--------------------+--------------------+-------------------+----------------+------------+-------------+-----------------------------------------------------------------------------------+

# %%
print("="*60)
print("Tickets older than 50 days in Tech Discovery Required:")
print("="*60)
for x in range(len(top_10_rows)):
    if top_10_rows.iloc[x]['days_old'] > 50:
        print("-"*100)
        print("Creator: "+top_10_rows.iloc[x]['creator_name']+" -> "+str(top_10_rows.iloc[x]['days_old'])+" days old")
        print(f"Summary: {top_10_rows.iloc[x]['summary'] }")
        print(f"https://entercomdigitalservices.atlassian.net/browse/{top_10_rows.iloc[x]['key']}")
# Out:
# ============================================================
# Tickets older than 50 days in Tech Discovery Required:
# ============================================================
# ----------------------------------------------------------------------------------------------------
# Creator: Angel Cancio -> 88 days old
# Summary: Gitlab Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8068
# ----------------------------------------------------------------------------------------------------
# Creator: Angel Cancio -> 88 days old
# Summary: Gitlab Post-Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8069
# ----------------------------------------------------------------------------------------------------
# Creator: Angel Cancio -> 75 days old
# Summary: POC - Import NPM packages
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8128
# ----------------------------------------------------------------------------------------------------
# Creator: Randall Puterbaugh -> 160 days old
# Summary: Migration of Recommendation Services to A2 Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7660
# ----------------------------------------------------------------------------------------------------
# Creator: Joe Parlett -> 54 days old
# Summary: [Apigee/Fastly] Log actual client IP of requests in Apigee logs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8255

# %%
# Build a report grouped by Business Lead
print("="*60)
print("Tickets grouped by Business Lead:")
print("="*60)
print("Technical Discovery:")
print("="*60)
for business_lead, group in top_10_rows.groupby('bussiness_lead', sort=True):
    print("\n" + "="*80)
    print(f"Business Lead: {business_lead}")
    print("="*80)
    for _, row in group.iterrows():
        print(f"Creator:  {row['creator_name']}: {row['days_old']} days Ago")
        print(f"Assignee: {row['assignee_name']}")
        print(f"Summary: {row['summary']}")
        print(f"https://entercomdigitalservices.atlassian.net/browse/{row['key']}")
        print("")
# Out:
# ============================================================
# Tickets grouped by Business Lead:
# ============================================================
# Technical Discovery:
# ============================================================
#
# ================================================================================
# Business Lead: Jorge Rodriguez
# ================================================================================
# Creator:  Cullen Philippson: 4 days Ago
# Assignee: Cullen Philippson
# Summary: Create a CIDR range for FileDataGov_Prod account for accessing WO Prod 01 account
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8489
#
# Creator:  Angel Cancio: 88 days Ago
# Assignee: Bolanle
# Summary: Gitlab Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8068
#
# Creator:  Angel Cancio: 88 days Ago
# Assignee: Bolanle
# Summary: Gitlab Post-Migration
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8069
#
# Creator:  Angel Cancio: 75 days Ago
# Assignee: Bolanle
# Summary: POC - Import NPM packages
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8128
#
# Creator:  Randall Puterbaugh: 160 days Ago
# Assignee: Randall Puterbaugh
# Summary: Migration of Recommendation Services to A2 Environment
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-7660
#
#
# ================================================================================
# Business Lead: Josh Currier
# ================================================================================
# Creator:  Josh Currier: 20 days Ago
# Assignee: Unassigned
# Summary: Chaos Monkey Testing Plan
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8404
#
#
# ================================================================================
# Business Lead: Victoria Benecke
# ================================================================================
# Creator:  Joe Parlett: 54 days Ago
# Assignee: Randall Puterbaugh
# Summary: [Apigee/Fastly] Log actual client IP of requests in Apigee logs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8255
#
#
# ================================================================================
# Business Lead: eric duell
# ================================================================================
# Creator:  Christopher Dixon: 4 days Ago
# Assignee: Randall Puterbaugh
# Summary: Create Nonprod and Prod GC Projects for Techolution AI Initiative
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8483
#
# Creator:  Christopher Dixon: 4 days Ago
# Assignee: Randall Puterbaugh
# Summary: Create Nonprod GC Project for DAC AI Labs
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8487
#
# Creator:  Christopher Dixon: 48 days Ago
# Assignee: Denys Loboda
# Summary: Enable DAC team to restart K8s workloads in prj-initiatives-nonprod project
# https://entercomdigitalservices.atlassian.net/browse/DEVOPS-8277

# %% [markdown]
# # Build a report based on assigne name and parent tickets

# %%
# Define your time range (inclusive)
start_month = '2025-10-01'
end_month = '2025-11-01'

# Prepare week column
df_issues['week'] = pd.to_datetime(df_issues['updated'], utc=True).dt.to_period('W').astype(str)

# Ensure 'parent' is a string or a comparable type
df_issues['parent_str'] = df_issues['parent'].astype(str)

# Filter by time range
mask = (df_issues['week'] >= start_month) & (df_issues['week'] <= end_month) & df_issues['status'].isin(['In Progress','Done', 'Validating'])
filtered = df_issues[mask]

# Group and pivot for stacked bar
grouped = filtered.groupby(['parent_str', 'week', 'assignee_name']).size().reset_index(name='ticket_count')
pivot_df = grouped.pivot_table(index=['parent_str', 'week'], columns='assignee_name', values='ticket_count', fill_value=0)
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/4026178792.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_issues['week'] = pd.to_datetime(df_issues['updated'], utc=True).dt.to_period('W').astype(str)

# %%
#filtered.head(10)  # Display the first 10 rows of the filtered DataFrame

# %%
pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title(f'Tickets by Legend and Assignee from week {start_month} to {end_month}')
plt.xlabel('Legend per Week')
plt.ylabel('Number of Tickets')
#plt.ylim(0, pivot_df.values.max())  # Set y-axis limit to max tickets
#plt.yticks(np.arange(0, pivot_df.values.max()+35, 1))  # Set y-ticks to every 2 tickets
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=90, ha='center')
plt.legend(title='Assignee', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# To get the ticket counts for 'Aaron Wolfrom' by parent_str and week:
# print(pivot_df.columns)  # Show available columns (assignee names)
for col in pivot_df.columns:
    print(f"\n---------- {col} ----------")  # Print the assignee name
    print(f"Assignee: {col}, Total Tickets: {pivot_df[col].sum()}")  # Print total tickets per assignee
    person_df = pivot_df[col].reset_index()  # brings 'parent_str' and 'week' as columns
    person_df['sum'] = person_df[col].sum()  # Add a sum column for clarity
    person_df['Percent'] = person_df[col] / person_df[col].sum() * 100  # Add a percent column for clarity
    person_df['Hours'] = person_df['Percent'] * 40 / 100  # Assuming 40 hours per week, calculate hours
    person_df['Hours'] = person_df['Hours'].round(0)  # Round hours to 2 decimal places
    # print(person_df.info())  # Show DataFrame info
    if (len(person_df[(person_df[col] > 0) & (person_df['parent_str'] != '<NA>')]) > 0):
        #print(person_df[(person_df[col] > 0) & (person_df['parent_str'] != '<NA>')][['parent_str', 'week', col, 'sum', 'Percent', 'Hours']])
        print(person_df[(person_df[col] > 0) & (person_df['parent_str'] != '<NA>')][['parent_str', 'week', 'Hours']])  # Filter to show only weeks where assignee has tickets
        total_hours = person_df.loc[(person_df[col] > 0) & (person_df['parent_str'] != '<NA>'), 'Hours'].sum()
        print(f"Total Opex Hours: {40 - total_hours}")
    else:
        print(f"Total Opex Hours: {40}")  # If no tickets, assume full 40 hours available
# Out:
# ---------- Aaron Wolfrom ----------
# Assignee: Aaron Wolfrom, Total Tickets: 1.0
#    parent_str                   week  Hours
# 32     EIT-96  2025-10-20/2025-10-26   40.0
# Total Opex Hours: 0.0
#
# ---------- Adam Shero ----------
# Assignee: Adam Shero, Total Tickets: 13.0
#      parent_str                   week  Hours
# 8        APP-94  2025-10-06/2025-10-12    3.0
# 12  DEVOPS-7784  2025-10-13/2025-10-19    3.0
# 21  DEVOPS-8154  2025-10-20/2025-10-26    9.0
# Total Opex Hours: 25.0
#
# ---------- Andriy Petryshyn ----------
# Assignee: Andriy Petryshyn, Total Tickets: 2.0
#    parent_str                   week  Hours
# 9  AWPOD-2218  2025-10-27/2025-11-02   20.0
# Total Opex Hours: 20.0
#
# ---------- Bolanle ----------
# Assignee: Bolanle, Total Tickets: 8.0
#      parent_str                   week  Hours
# 14  DEVOPS-8030  2025-10-20/2025-10-26    5.0
# 33       ST-227  2025-10-13/2025-10-19   10.0
# 34       ST-235  2025-10-20/2025-10-26   10.0
# Total Opex Hours: 15.0
#
# ---------- Cullen Philippson ----------
# Assignee: Cullen Philippson, Total Tickets: 16.0
#      parent_str                   week  Hours
# 20  DEVOPS-8154  2025-10-13/2025-10-19    2.0
# Total Opex Hours: 38.0
#
# ---------- Dmytro Oliinyk ----------
# Assignee: Dmytro Oliinyk, Total Tickets: 5.0
#      parent_str                   week  Hours
# 11  DEVOPS-7082  2025-10-27/2025-11-02    8.0
# 19  DEVOPS-8154  2025-10-06/2025-10-12    8.0
# 23  DEVOPS-8363  2025-10-20/2025-10-26    8.0
# 28  DEVOPS-8476  2025-10-27/2025-11-02    8.0
# Total Opex Hours: 8.0
#
# ---------- Grace Martorano ----------
# Assignee: Grace Martorano, Total Tickets: 1.0
#    parent_str                   week  Hours
# 29    EIT-240  2025-10-06/2025-10-12   40.0
# Total Opex Hours: 0.0
#
# ---------- Jeff Stuewe ----------
# Assignee: Jeff Stuewe, Total Tickets: 3.0
#    parent_str                   week  Hours
# 30     EIT-95  2025-10-06/2025-10-12   27.0
# 31     EIT-96  2025-10-06/2025-10-12   13.0
# Total Opex Hours: 0.0
#
# ---------- Jorge.Rodriguez ----------
# Assignee: Jorge.Rodriguez, Total Tickets: 1.0
# Total Opex Hours: 40
#
# ---------- Juan Reyes ----------
# Assignee: Juan Reyes, Total Tickets: 15.0
#      parent_str                   week  Hours
# 16  DEVOPS-8094  2025-10-13/2025-10-19   11.0
# 17  DEVOPS-8094  2025-10-20/2025-10-26   16.0
# 18  DEVOPS-8094  2025-10-27/2025-11-02    3.0
# 24  DEVOPS-8370  2025-10-06/2025-10-12    3.0
# 25  DEVOPS-8370  2025-10-20/2025-10-26    3.0
# Total Opex Hours: 4.0
#
# ---------- Mark Buchanan ----------
# Assignee: Mark Buchanan, Total Tickets: 1.0
# Total Opex Hours: 40
#
# ---------- Randall Puterbaugh ----------
# Assignee: Randall Puterbaugh, Total Tickets: 3.0
#      parent_str                   week  Hours
# 17  DEVOPS-8094  2025-10-20/2025-10-26   13.0
# Total Opex Hours: 27.0
#
# ---------- Terry Dougal ----------
# Assignee: Terry Dougal, Total Tickets: 11.0
#      parent_str                   week  Hours
# 7        APP-88  2025-10-20/2025-10-26    4.0
# 15  DEVOPS-8094  2025-10-06/2025-10-12    4.0
# 16  DEVOPS-8094  2025-10-13/2025-10-19   11.0
# 17  DEVOPS-8094  2025-10-20/2025-10-26   15.0
# Total Opex Hours: 6.0
#
# ---------- Tom Terry ----------
# Assignee: Tom Terry, Total Tickets: 9.0
#      parent_str                   week  Hours
# 6         APP-7  2025-10-20/2025-10-26    4.0
# 10     DAT-3736  2025-10-13/2025-10-19    4.0
# 13  DEVOPS-7901  2025-10-20/2025-10-26    4.0
# 20  DEVOPS-8154  2025-10-13/2025-10-19    4.0
# Total Opex Hours: 24.0
#
# ---------- Unassigned ----------
# Assignee: Unassigned, Total Tickets: 4.0
#   parent_str                   week  Hours
# 5     APP-39  2025-10-06/2025-10-12   10.0
# Total Opex Hours: 30.0
#
# ---------- sabrina.szymczak ----------
# Assignee: sabrina.szymczak, Total Tickets: 1.0
#   parent_str                   week  Hours
# 4     APP-24  2025-10-06/2025-10-12   40.0
# Total Opex Hours: 0.0
#
# ---------- satish kumar marana ----------
# Assignee: satish kumar marana, Total Tickets: 2.0
#      parent_str                   week  Hours
# 7        APP-88  2025-10-20/2025-10-26   20.0
# 25  DEVOPS-8370  2025-10-20/2025-10-26   20.0
# Total Opex Hours: 0.0
#
# ---------- simon.davison ----------
# Assignee: simon.davison, Total Tickets: 9.0
#      parent_str                   week  Hours
# 22  DEVOPS-8234  2025-10-27/2025-11-02    4.0
# 26  DEVOPS-8420  2025-10-13/2025-10-19    4.0
# 27  DEVOPS-8420  2025-10-20/2025-10-26    9.0
# 35       ST-240  2025-10-20/2025-10-26    9.0
# 36       ST-381  2025-10-20/2025-10-26    4.0
# Total Opex Hours: 10.0

# %% [markdown]
# # Work by Bussines Lead and Priority

# %%
# Define your time range (inclusive)
start_month = '2025-10'
end_month = '2025-10'

# Prepare month column
df_issues['month'] = pd.to_datetime(df_issues['created'], errors='coerce').dt.to_period('M').astype(str)

# Filter by time range
mask = (df_issues['month'] >= start_month) & (df_issues['month'] <= end_month)
filtered = df_issues[mask]

# Group and pivot for stacked bar
grouped = filtered.groupby(['bussiness_lead', 'month', 'priority_name']).size().reset_index(name='ticket_count')
pivot_df = grouped.pivot_table(index=['bussiness_lead', 'month'], columns='priority_name', values='ticket_count', fill_value=0)
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/586555324.py:6: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_issues['month'] = pd.to_datetime(df_issues['created'], errors='coerce').dt.to_period('M').astype(str)

# %%
filtered.loc[filtered['key'].str.contains('CAR-'), 'bussiness_lead'] = 'Jorge Rodriguez'

# %%
#filtered[filtered['key'].str.contains('CAR-')]

# %%
filtered[filtered['bussiness_lead'] == 'Unknown'][['key']]
# Out:
#                key
# 79     DEVOPS-8441
# 2249   DEVOPS-8474
# 2255   DEVOPS-8458
# 4066   DEVOPS-8485
# 4067   DEVOPS-8484
# 4068   DEVOPS-8482
# 4069   DEVOPS-8481
# 4070   DEVOPS-8480
# 4071   DEVOPS-8478
# 4137   DEVOPS-8477
# 6761   DEVOPS-8494
# 6762   DEVOPS-8493
# 6763   DEVOPS-8492
# 6765   DEVOPS-8490
# 6771   DEVOPS-8475
# 6773   DEVOPS-8470
# 6776   DEVOPS-8464
# 6780   DEVOPS-8439
# 6782   DEVOPS-8447
# 8116   DEVOPS-8469
# 8533   DEVOPS-8403
# 8535   DEVOPS-8393
# 10071      EIT-609
# 10078      EIT-608
# 10080  DEVOPS-8468
# 10082      EIT-607
# 10083      EIT-606
# 10089      EIT-605
# 10090      EIT-604
# 10091      EIT-603
# 10092      EIT-602
# 10093      EIT-601
# 10094      EIT-600
# 10095      EIT-599
# 10096      EIT-598
# 10097      EIT-597
# 10098      EIT-596
# 10099      EIT-595
# 10100      EIT-594
# 10101      EIT-593
# 10102      EIT-592
# 10104      EIT-591
# 10105      EIT-590
# 10106      EIT-589

# %%
#filtered

# %%
pivot_df.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title(f'Tickets by Bussiness Lead and Priority from {start_month} to {end_month}')
plt.xlabel('Bussiness Lead and Month')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=90, ha='center')
plt.legend(title='Priority', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Sum across all business leads and months for each priority
priority_totals = pivot_df.sum(axis=0)

# Plot as a pie chart
plt.figure(figsize=(8, 8))
priority_totals.plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3', legend=False)
plt.title(f'Ticket Distribution by Priority from {start_month} to {end_month}')
plt.ylabel('')  # Hide y-label for better appearance
plt.tight_layout()
plt.show()

# %%
# Sum across all priorities and months for each business lead
business_lead_totals = filtered.groupby('bussiness_lead').size()

# Plot as a pie chart
plt.figure(figsize=(8, 8))
business_lead_totals.plot.pie(autopct='%1.1f%%', startangle=90, cmap='Set3', legend=False)
plt.title(f'Ticket Distribution by Business Lead from {start_month} to {end_month}')
plt.ylabel('')  # Hide y-label for better appearance
plt.tight_layout()
plt.show()

# %%
# business_lead_totals > 10

# %% [markdown]
# ## --- CAPACITY ---

# %% [markdown]
# ## CAPACITY for DevOps

# %%
#df_issues.query()

# %%
#tickets_created = df_issues.groupby(['year_created', 'month_created']).size().reset_index(name='count')

# %%
#tickets_updated = df_issues[df_issues['status'] == 'Done'].groupby(['year_updated', 'month_updated']).size().reset_index(name='count')

# %%
df_issues_tmp = df_issues[(df_issues['project_name'] == 'DevOps') | (df_issues['project_name'] == 'Release Management')].copy()
#df_issues_tmp = df_issues[(df_issues['project_name'] == 'Release Management')].copy()
tickets_created = df_issues_tmp.groupby(['year_created', 'month_created']).size().reset_index(name='count')
capacity = []
for index, row in tickets_created .iterrows():
    year = row['year_created']
    month = row['month_created']
    count = row['count']
    #project_name = row['project_name']
    #print(f"Year: {year}, Month: {month}, Count: {count}")
    data = {
        'year': year,
        'month': month,
        'created': count
        #'project_name' : project_name
    }
    capacity.append(data)
    #print(f"Year: {year}, Month: {month}, Count: {count}")
# Convert to DataFrame
capacity_df = pd.DataFrame(capacity)
# Convert 'year' and 'month' to datetime
capacity_df['date'] = pd.to_datetime(capacity_df[['year', 'month']].assign(day=1))
capacity_df['date'] = pd.to_datetime(capacity_df['date'], format='%Y-%m-%d')
capacity_df['date'] = capacity_df['date'].dt.date
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
# Drop the original 'year' and 'month' columns
capacity_df = capacity_df[capacity_df['year'] > 2022].copy()
capacity_df.drop(columns=['year', 'month'], inplace=True)
#capacity_df.index = pd.to_datetime(capacity_df['date'])
capacity_created = capacity_df.copy()
# Rename 'count' to 'capacity'
#capacity_df.rename(columns={'count': 'updated'}, inplace=True)
# Print the DataFrame
#print(capacity_created)

# %%
#df_issues_tmp = df_issues[(df_issues['project_name'] == 'DevOps')].copy()
df_issues_tmp = df_issues[(df_issues['project_name'] == 'DevOps') | (df_issues['project_name'] == 'Release Management')].copy()
tickets_updated = df_issues_tmp[(df_issues['status'] == 'Done') | (df_issues['status'] == 'Released Successfully to Production')].groupby(['year_updated', 'month_updated']).size().reset_index(name='count')
capacity = []
for index, row in tickets_updated.iterrows():
    year = row['year_updated']
    month = row['month_updated']
    count = row['count']
    #project_name = row['project_name']
    #print(f"Year: {year}, Month: {month}, Count: {count}")
    data = {
        'year': year,
        'month': month,
        'completed': count
        #'project_name' : project_name
    }
    capacity.append(data)
    #print(f"Year: {year}, Month: {month}, Count: {count}")
# Convert to DataFrame
capacity_df = pd.DataFrame(capacity)
# Convert 'year' and 'month' to datetime
capacity_df['date'] = pd.to_datetime(capacity_df[['year', 'month']].assign(day=1))
capacity_df['date'] = pd.to_datetime(capacity_df['date'], format='%Y-%m-%d')
capacity_df['date'] = capacity_df['date'].dt.date
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
# Drop the original 'year' and 'month' columns
capacity_df = capacity_df[capacity_df['year'] > 2022].copy()
capacity_df.drop(columns=['year', 'month'], inplace=True)
#capacity_df.index = pd.to_datetime(capacity_df['date'])
capacity_updated = capacity_df.copy()
#capacity_updated['complited'] = capacity_created['created']
# Rename 'count' to 'capacity'
#capacity_df.rename(columns={'count': 'updated'}, inplace=True)
# Print the DataFrame
#print(capacity_updated)
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/3733887669.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tickets_updated = df_issues_tmp[(df_issues['status'] == 'Done') | (df_issues['status'] == 'Released Successfully to Production')].groupby(['year_updated', 'month_updated']).size().reset_index(name='count')

# %%
velocity_updated = df_issues_tmp[df_issues_tmp['status'] == 'Done'].groupby(['year_updated', 'month_updated'])['velocity_days'].mean().reset_index(name='average_velocity')

# %%
#velocity_updated

# %%
total_capacity = pd.merge(capacity_created, capacity_updated, on='date', how='outer')
total_capacity['created'] = total_capacity['created'].fillna(0)
#total_capacity

# %%
#all_data = pd.melt(total_capacity, id_vars=['date'], value_vars=['created', 'updated'], var_name='type', value_name='count')
#all_data['date'] = pd.to_datetime(all_data['date'])
#all_data['date'] = all_data['date'].dt.to_period('M').dt.to_timestamp()

# %%
# Reshape the DataFrame for plotting
all_data = pd.melt(total_capacity, id_vars=['date'], value_vars=['created', 'completed'], var_name='type', value_name='count')
all_data['display_date'] = all_data['date'].apply(
    lambda x: x.strftime('%Y-%m') if pd.notnull(x) else 'N/A' # Or None, or ""
)
# Plot grouped bar chart
plt.figure(figsize=(14, 8)) # Adjusted figure size for potentially more bars
# capacity_updated.plot(kind='bar', x='date', y='updated', color='orange', label='Updated', ax=plt.gca())
#capacity_created.plot(kind='bar', x='date', y='created', color='blue', label='Created', ax=plt.gca())
#plt.figure(figsize=(14, 7)) # Adjusted figure size for potentially more bars
fig = plt.figure(figsize=(16, 8))
sns.barplot(data=all_data, x='display_date', y='count', hue='type', palette=['blue', 'orange'])
# Set the title and labels

plt.title('Created vs Completed Tickets and CARs per Month in DevOps', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Number of Tickets')
plt.legend(title='Type of Ticket', loc='upper left')

plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.legend(loc='upper left', title='Type of Ticket', fontsize='small', title_fontsize='medium')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 8))
# Sort by date to ensure proper area plot
all_data_sorted = all_data.sort_values('date')

# Pivot for area plot: index=date, columns=type, values=count
area_df = all_data_sorted.pivot(index='date', columns='type', values='count').fillna(0)

# Plot area chart
area_df.plot.area(alpha=0.6, figsize=(14, 8), cmap='Set2')
plt.title('Created vs Completed Tickets Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=45)
plt.legend(title='Type of Ticket', loc='upper left')
plt.tight_layout()
plt.show()

# %%
#len(all_data)

# %% [markdown]
# ## Create a Trend on Backlog

# %%
'''
backlog_data = {
    'date': [],
    'backlog': []
}
backlog_df = pd.DataFrame(backlog_data)
backlog_df['date'] = pd.to_datetime(backlog_df['date'])
backlog_df.set_index('date', inplace=True)
backlog_df.to_csv('backlog_data.csv')
'''
# Out:
# "\nbacklog_data = {\n    'date': [],\n    'backlog': []\n}\nbacklog_df = pd.DataFrame(backlog_data)\nbacklog_df['date'] = pd.to_datetime(backlog_df['date'])\nbacklog_df.set_index('date', inplace=True)\nbacklog_df.to_csv('backlog_data.csv')\n"

# %%
backlog_df = pd.read_csv('backlog_data.csv', parse_dates=['date'], index_col='date')

# %%
WND = len(df_issues[(df_issues['status'] == 'Will Not Do') & (df_issues['year_created'] > 2022)])
backlog = all_data[all_data['type']=='created']['count'].sum() - all_data[all_data['type']=='completed']['count'].sum()
print("Backlog:", backlog)
backlog_df = pd.concat([backlog_df, pd.DataFrame([{'date': today, 'backlog': backlog}])], ignore_index=True)
backlog_df.to_csv('backlog_data.csv')
# Out:
# Backlog: 480

# %%
#backlog_df

# %%
# For a histogram of backlog values:
backlog_df['backlog'].plot(kind='bar', figsize=(14, 8))
plt.title('Histogram of Backlog')
plt.xlabel('Backlog')
plt.ylabel('No of Tickets')
plt.show()

# %% [markdown]
# # Doing Time Series ML to see if I can predict the workload for next month

# %%
data_time_series = all_data.copy()
data_time_series.set_index('date', inplace=True)

# %%
data_time_series
lagged_data_completed = data_time_series[data_time_series['type']=='completed'].copy()
lagged_data_created = data_time_series[data_time_series['type']=='created'].copy()

# %%
def create_lagged_features(data, lags=3):
    df = data.copy()
    for lag in range(1, lags + 1):
        df[f'lag_{lag}'] = df['count'].shift(lag)
    # Drop rows with NaN values
    df.dropna(inplace=True)
    return df

lagged_data_completed = create_lagged_features(lagged_data_completed, lags=3)
lagged_data_created = create_lagged_features(lagged_data_created, lags=3)

# %%
def add_date_features(df):
    # Ensure the index is a DatetimeIndex
    df = df.copy()
    if not isinstance(df.index, pd.DatetimeIndex):
        df.index = pd.to_datetime(df.index)
    df['month'] = df.index.month
    df['day_of_week'] = df.index.dayofweek
    df['is_weekend'] = df['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)
    #df['3_month_mean'] = df['count'].rolling(window = 3).mean()
    #df['3_month_std'] = df['count'].rolling(window = 3).std()
    df['3_month_max'] = df['count'].rolling(window = 3).max()
    df['3_month_min'] = df['count'].rolling(window = 3).min()
    #df['6_month_mean'] = df['count'].rolling(window = 6).mean()
    #df['6_month_std'] = df['count'].rolling(window = 6).std()
    #df['6_month_max'] = df['count'].rolling(window = 6).max()
    #df['6_month_min'] = df['count'].rolling(window = 6).min()
    return df

lagged_data_completed = add_date_features(lagged_data_completed)
lagged_data_created = add_date_features(lagged_data_created)

# %%
def add_rolling_features(df, window=3):
    df['rolling_mean'] = df['count'].rolling(
        window=window).mean().shift(1)
    df['rolling_std'] = df['count'].rolling(
        window=window).std().shift(1)
    df.dropna(inplace=True)
    # Drop rows with NaN values
    return df

lagged_data_completed = add_rolling_features(lagged_data_completed,window=3)
#lagged_data_completed.head()

lagged_data_created = add_rolling_features(lagged_data_created,window=3)
#lagged_data_created.head()

# %%
#lagged_data_completed.plot(y='count', figsize=(12, 6))
#lagged_data_created.plot(y='count', figsize=(12, 6))

# %%
#lagged_data_completed

# %%
#lagged_data_created

# %%
# Align the indices to ensure correct matching by date
lagged_data_completed['created'] = lagged_data_created['count'].reindex(lagged_data_completed.index)

# %%
#lagged_data_completed

# %%
train_size = int(len(lagged_data_completed) * 0.8)
train_data = lagged_data_completed[:train_size]
test_data = lagged_data_completed[train_size:]

# %%
X_train = train_data.drop('count', axis=1)
y_train = train_data['count']
X_test = test_data.drop('count', axis=1)
y_test = test_data['count']

# %%
#X_train.head()

# %%
#y_train.head()

# %%
#!pip3 install xgboost
#!pip3 install scikit-learn
#!pip3 install scikit-learn xgboost
#!pip3 install scikit-learn

# %%
from xgboost import XGBRegressor

# Drop non-numeric columns before fitting
X_train_num = X_train.select_dtypes(include=['int', 'float', 'bool', 'category'])
X_test_num = X_test.select_dtypes(include=['int', 'float', 'bool', 'category'])

model = XGBRegressor(objective='reg:squarederror', n_estimators=5000, max_depth=3, learning_rate=0.01)

model.fit(X_train_num, y_train)

y_pred = model.predict(X_test_num)


'''
# regresion model
reg = XGBRegressor(n_estimators = 12000,
                   early_stopping_rounds = 40,
                   learning_rate=0.01,
                   max_depth=2,
                   random_state=42
                   )
'''
# Out:
# '\n# regresion model\nreg = XGBRegressor(n_estimators = 12000,\n                   early_stopping_rounds = 40,\n                   learning_rate=0.01,\n                   max_depth=2,\n                   random_state=42\n                   )\n'

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Squared Error: 6970.33935546875
# Mean Absolute Error: 56.696685791015625

# %%
import matplotlib.pyplot as plt
# Generate the dates for the future predictions (extend the original date range)
future_dates = pd.date_range(start=X_test.index[-1],periods=11, freq='M')[1:]
# Skip the first date to match steps
# Convert the forecast to a DataFrame for easy plotting
#future_df = pd.DataFrame({'Date': future_dates,'Predicted_Value': future_forecast})
#future_df.set_index('Date', inplace=True)
# Plot the actual and predicted values
plt.figure(figsize=(10, 6))
# Plot actual values from the test set
plt.plot(X_test.index, y_test, label='Actual')
plt.plot(X_test.index, y_pred, label='Predicted')
# Plot the future predictions
#plt.plot(future_df.index,future_df['Predicted_Value'],label='Predicted', linestyle='--')
# Add labels and legend
plt.title('Future Time Series Forecasting with XGBoost')
plt.xlabel('Date')
plt.ylabel('Values')
plt.xticks(rotation=45)
# Rotate X-axis labels by 45 degrees
plt.legend()
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/295012755.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=X_test.index[-1],periods=11, freq='M')[1:]

# %%
PERIODS = 4

# %%
def forecast_future(model, initial_data, steps=PERIODS):
    future_values = []
    input_data = initial_data[-1:]
    for _ in range(steps):
        # Predict the next value
        prediction = model.predict(input_data)
        # Append the predicted value to the list
        future_values.append(prediction[0])
        input_data = np.roll(input_data, -1)
        input_data[0, -1] = prediction[0]
        #print(input_data[0, 8])
        #print(f"Step {_ + 1}: Predicted value is {prediction[0]}")

    return future_values

# %%
def forecast_future_original(model, initial_data, steps=PERIODS):
    future_values = []
    input_data = initial_data[-1:].count.reshape(1, -1)
    for _ in range(steps):
        # Predict the next value
        prediction = model.predict(input_data)
        # Append the predicted value to the list
        future_values.append(prediction[0])
        input_data = np.roll(input_data, -1)
        input_data[0, -1] = prediction[0]
        print(input_data.head())

    return future_values

# %%
latest_data = X_test.tail(1)
# Select only numeric columns for prediction
latest_data_num = latest_data.select_dtypes(include=['int', 'float', 'bool', 'category'])
#model.predict(latest_data_num)

# %%
#latest_data_num

# %%
future_forecast = forecast_future(model, latest_data_num, steps=PERIODS)

# %%
#future_forecast

# %%
import matplotlib.pyplot as plt
import numpy as np

future_dates = pd.date_range(start=X_test.index[-1]+pd.DateOffset(months=1), periods=PERIODS, freq='MS')[0:]
future_df = pd.DataFrame({'Date': future_dates, 'Predicted_Value': future_forecast})
future_df.set_index('Date', inplace=True)
future_df['yhat_lower'] = future_df['Predicted_Value'] - mae
future_df['yhat_upper'] = future_df['Predicted_Value'] + mae

past_dates = pd.date_range(start=X_test.index[0], periods=len(y_pred), freq='MS')[0:]
past_df = pd.DataFrame({'Date': past_dates, 'Predicted_Value': y_pred})
past_df.set_index('Date', inplace=True)
past_df['yhat_lower'] = past_df['Predicted_Value'] - mae
past_df['yhat_upper'] = past_df['Predicted_Value'] + mae

all_dates_df = pd.concat([past_df, future_df])

#y_pred1 = np.append(y_pred.copy(), future_df[0:1]['Predicted_Value'])
#X_test1 = np.concatenate((X_test.copy(), future_df[0:1]))
#y_pred = np.concatenate([y_pred, future_forecast])

plt.figure(figsize=(15, 5))
plt.plot(X_test.index, y_test, label='Actual',color='blue')
plt.plot(all_dates_df.index, all_dates_df['Predicted_Value'], label=f'Forecast [ {future_df["yhat_lower"].values.sum():,.0f} , {future_df["Predicted_Value"].values.sum():,.0f} , {future_df["yhat_upper"].values.sum():,.0f}]', linestyle='-', color='green')
#plt.plot(past_df.index, past_df['Predicted_Value'], label='', color='green')
#plt.fill_between(future_df.index, future_df['yhat_lower'], future_df['yhat_upper'], color='green', alpha=0.2)
#plt.fill_between(past_df.index, past_df['yhat_lower'], past_df['yhat_upper'], color='green', alpha=0.2)

plt.fill_between(all_dates_df.index, all_dates_df['yhat_lower'], all_dates_df['yhat_upper'], color='green', alpha=0.2)

plt.title(f'Truth Data and Forecast for the next {PERIODS} Months using XGBoost Model')
plt.xlabel(f"Dates in Blocks of {PERIODS} Months", fontsize=14)
plt.ylabel('Tickets')
#plt.ylim(50, max(y_test.max(), future_df['Predicted_Value'].max()) + 45)
plt.xticks(rotation=0)
# If you want to set y-tick increments, use plt.yticks()
# For example, to set y-ticks every 100 units:
plt.yticks(np.arange(0, max(y_test.max(), future_df['Predicted_Value'].max()) + 100, 50))
plt.legend()
plt.show()

# %% [markdown]
# ## using Prophet

# %%
import matplotlib.ticker as ticker

# %pip install prophet

from prophet import Prophet

df_p = pd.DataFrame()

df_p['ds'] = lagged_data_completed.index
df_p['y'] = lagged_data_completed['count'].values
df_p = df_p.reset_index(drop=True)

model = Prophet()
model.fit(df_p)

PERIODS = 4  # Number of periods to forecast
# Python
future = model.make_future_dataframe(periods=PERIODS, freq='M', include_history = True)   # Create a future DataFrame for PERIODS months
forecast = model.predict(future)                             # Generate the forecast

periods = PERIODS  # Number of periods to forecast
yhat_low = forecast.iloc[-periods:,:]['yhat_lower'].values
yhat = forecast.iloc[-periods:,:]['yhat'].values
yhat_high = forecast.iloc[-periods:,:]['yhat_upper'].values


yhat = forecast.iloc[-periods:,:]['yhat'].values
fig, ax = plt.subplots(figsize=(15,5))
# Only plot data from April 2025 onwards
mask = df_p['ds'] >= pd.Timestamp('2025-05-01')
mask1 = forecast['ds'] >= pd.Timestamp('2025-05-01')
#plt.figure(figsize=(15, 6))
plt.plot(df_p.loc[mask, 'ds'], df_p.loc[mask, 'y'], label='Actual', color='blue')
#plt.plot(forecast.loc[mask1, 'ds'], forecast.loc[mask1, 'trend'], label='Trend',color='orange')
plt.plot(forecast.loc[mask1, 'ds'], forecast.loc[mask1, 'yhat'], label='Forecast: [ ' + str("{:,.0f}".format(yhat_low.sum())) + " - " + str("{:,.0f}".format(yhat.sum())) + 
                                                                    " - " + str("{:,.0f}".format(yhat_high.sum()))+ ']',color='green')
plt.fill_between(forecast.loc[mask1, 'ds'], forecast.loc[mask1, 'yhat_lower'], forecast.loc[mask1, 'yhat_upper'], color='green', alpha=0.2)
#plt.plot(forecast['ds'], forecast['yhat_lower'], label='Forecast',color='green', linestyle='--')
#plt.plot(forecast['ds'], forecast['yhat_upper'], label='Forecast',color='green', linestyle='--')
#model.plot(forecast, ax=ax)       # Plot the forecast
#plot(model, forecast)               # Plot the forecast
#plot_components(model, forecast)    # Plot the forecast components
formatter = ticker.ScalarFormatter()
formatter.set_scientific(False)
ax.yaxis.set_major_formatter(formatter)
#current_values = plt.gca().get_yticks()
ax.set_yticks(np.arange(0, df_p.loc[mask, 'y'].max() + 100, 50))
#plt.gca().set_yticklabels(['{:,.0f}'.format(val) for val in current_values])
ax.set_title(f'Truth Data and Forecast for the next {PERIODS} Months using Prophet Model')
#ax.legend(['Truth Data', 'Prediction','Forecast'], loc='upper left', title='Datesets')
ax.legend(loc='upper right', title='')
ax.set_xlabel(f"Dates in Blocks of {PERIODS} Months", fontsize=14)
ax.set_ylabel("Tickets", fontsize=14)

#ax.set_ylim(bottom=000000,top=2000000)
plt.show()
# Out:
# Python(31810) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: prophet in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.1.7)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (2.3.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (3.10.6)
# Requirement already satisfied: pandas>=1.0.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (2.3.3)
# Requirement already satisfied: holidays<1,>=0.25 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (0.82)
# Requirement already satisfied: tqdm>=4.36.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from prophet) (6.5.2)
# Requirement already satisfied: python-dateutil in /Users/jorge.rodriguez/Library/Python/3.14/lib/python/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/jorge.rodriguez/Library/Python/3.14/lib/python/site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/jorge.rodriguez/Library/Python/3.14/lib/python/site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# 08:51:46 - cmdstanpy - INFO - Chain [1] start processing
# Python(31813) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# 08:51:47 - cmdstanpy - INFO - Chain [1] done processing
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/prophet/forecaster.py:1872: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(

# %% [markdown]
# # ------ END of Time Series Testing ----

# %%
# Define your time interval
start_date = '2024-01-01'
end_date = '2026-09-01'

# Ensure 'date' is datetime
total_capacity['date'] = pd.to_datetime(total_capacity['date'])

# Filter by interval
mask = (total_capacity['date'] >= start_date) & (total_capacity['date'] <= end_date)
filtered_capacity = total_capacity[mask]

plt.figure(figsize=(16, 8))

# Plot original data
#plt.plot(filtered_capacity['date'], filtered_capacity['created'], marker='o', label='Created', color='blue', alpha=0.5)
#plt.plot(filtered_capacity['date'], filtered_capacity['completed'], marker='o', label='Completed', color='orange', alpha=0.5)

# Calculate and plot 3-month moving averages
plt.plot(filtered_capacity['date'], filtered_capacity['created'].rolling(window=3, min_periods=1).mean(), 
         label='Created (3-mo MA)', color='blue', linewidth=2)
plt.plot(filtered_capacity['date'], filtered_capacity['completed'].rolling(window=3, min_periods=1).mean(), 
         label='Completed (3-mo MA)', color='orange', linewidth=2)
plt.axhline(y=233, color='green', linestyle='--', linewidth=2, label='100% Available Capacity')
plt.axhline(y=210, color='orange', linestyle='--', linewidth=2, label='90% Available Capacity')
plt.axhline(y=150, color='purple', linestyle='--', linewidth=2, label='60% Available Capacity')
plt.axhline(y=100, color='red', linestyle='--', linewidth=2, label='30% Available Capacity')


plt.title('Tickets Created vs Completed per Month (with Trend) in DevOps', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=0)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Create a 'date' column from 'year_updated' and 'month_updated'
velocity_updated['date'] = pd.to_datetime(
	dict(year=velocity_updated['year_updated'], month=velocity_updated['month_updated'], day=1)
)
velocity_updated['date'] = pd.to_datetime(velocity_updated['date'], format='%Y-%m-%d')
velocity_updated['date'] = velocity_updated['date'].dt.date
total_velocity = velocity_updated.copy()

# Define your time interval
start_date = '2024-01-01'
end_date = '2026-09-01'

# Ensure 'date' is datetime
total_velocity['date'] = pd.to_datetime(total_velocity['date'])

# Filter by interval
mask = (total_velocity['date'] >= start_date) & (total_velocity['date'] <= end_date)
filtered_velocity = total_velocity[mask]

plt.figure(figsize=(16, 8))

# Plot original data
#plt.plot(filtered_capacity['date'], filtered_capacity['created'], marker='o', label='Created', color='blue', alpha=0.5)
#plt.plot(filtered_capacity['date'], filtered_capacity['completed'], marker='o', label='Completed', color='orange', alpha=0.5)

# Calculate and plot 3-month moving averages
plt.plot(filtered_velocity['date'], filtered_velocity['average_velocity'].rolling(window=3, min_periods=1).mean(), 
        label='Average Velocity (3-mo MA)', color='blue', linewidth=2)
plt.axhline(y=90, color='red', linestyle='--', linewidth=2,    label='Maximum SLA Level')
plt.axhline(y=60, color='orange', linestyle='--', linewidth=2, label='Medium    SLA Level')
plt.axhline(y=30, color='green', linestyle='--', linewidth=2,  label='Minimum  SLA Level')
#plt.axhline(y=150, color='purple', linestyle='--', linewidth=2, label='60% Available Capacity')
plt.title('Velocity in Days per Month on Completed Tickets (with Trend) in DevOps', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Number of Days')
plt.xticks(rotation=0)
plt.ylim(0, 200)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CAPACITY for EIT

# %%
df_issues_tmp = df_issues[(df_issues['project_name'] == 'Enterprise IT')].copy()
tickets_created = df_issues_tmp.groupby(['year_created', 'month_created']).size().reset_index(name='count')
capacity = []
for index, row in tickets_created .iterrows():
    year = row['year_created']
    month = row['month_created']
    count = row['count']
    #project_name = row['project_name']
    #print(f"Year: {year}, Month: {month}, Count: {count}")
    data = {
        'year': year,
        'month': month,
        'created': count
        #'project_name' : project_name
    }
    capacity.append(data)
    #print(f"Year: {year}, Month: {month}, Count: {count}")
# Convert to DataFrame
capacity_df = pd.DataFrame(capacity)
# Convert 'year' and 'month' to datetime
capacity_df['date'] = pd.to_datetime(capacity_df[['year', 'month']].assign(day=1))
capacity_df['date'] = pd.to_datetime(capacity_df['date'], format='%Y-%m-%d')
capacity_df['date'] = capacity_df['date'].dt.date
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
# Drop the original 'year' and 'month' columns
capacity_df = capacity_df[capacity_df['year'] > 2022].copy()
capacity_df.drop(columns=['year', 'month'], inplace=True)
#capacity_df.index = pd.to_datetime(capacity_df['date'])
capacity_created = capacity_df.copy()
# Rename 'count' to 'capacity'
#capacity_df.rename(columns={'count': 'updated'}, inplace=True)
# Print the DataFrame
#print(capacity_created)

# %%
df_issues_tmp = df_issues[(df_issues['project_name'] == 'Enterprise IT')].copy()
tickets_updated = df_issues_tmp[df_issues['status'] == 'Done'].groupby(['project_name','year_updated', 'month_updated']).size().reset_index(name='count')
capacity = []
for index, row in tickets_updated.iterrows():
    year = row['year_updated']
    month = row['month_updated']
    count = row['count']
    project_name = row['project_name']
    #print(f"Year: {year}, Month: {month}, Count: {count}")
    data = {
        'year': year,
        'month': month,
        'complited': count,
        'project_name' : project_name
    }
    capacity.append(data)
    #print(f"Year: {year}, Month: {month}, Count: {count}")
# Convert to DataFrame
capacity_df = pd.DataFrame(capacity)
# Convert 'year' and 'month' to datetime
capacity_df['date'] = pd.to_datetime(capacity_df[['year', 'month']].assign(day=1))
capacity_df['date'] = pd.to_datetime(capacity_df['date'], format='%Y-%m-%d')
capacity_df['date'] = capacity_df['date'].dt.date
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
#capacity_df['date'] = capacity_df['date'].dt.to_period('M').dt.to_timestamp()
# Drop the original 'year' and 'month' columns
capacity_df = capacity_df[capacity_df['year'] > 2022].copy()
capacity_df.drop(columns=['year', 'month'], inplace=True)
#capacity_df.index = pd.to_datetime(capacity_df['date'])
capacity_updated = capacity_df.copy()
#capacity_updated['complited'] = capacity_created['created']
# Rename 'count' to 'capacity'
#capacity_df.rename(columns={'count': 'updated'}, inplace=True)
# Print the DataFrame
#print(capacity_updated)
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/173076131.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tickets_updated = df_issues_tmp[df_issues['status'] == 'Done'].groupby(['project_name','year_updated', 'month_updated']).size().reset_index(name='count')

# %%
total_capacity = pd.merge(capacity_created, capacity_updated, on='date', how='outer')
total_capacity['created'] = total_capacity['created'].fillna(0)

# %%
# Reshape the DataFrame for plotting
all_data = pd.melt(total_capacity, id_vars=['date'], value_vars=['created', 'complited'], var_name='type', value_name='count')
all_data['display_date'] = all_data['date'].apply(
    lambda x: x.strftime('%Y-%m') if pd.notnull(x) else 'N/A' # Or None, or ""
)
# Plot grouped bar chart
plt.figure(figsize=(14, 8)) # Adjusted figure size for potentially more bars
# capacity_updated.plot(kind='bar', x='date', y='updated', color='orange', label='Updated', ax=plt.gca())
#capacity_created.plot(kind='bar', x='date', y='created', color='blue', label='Created', ax=plt.gca())
#plt.figure(figsize=(14, 7)) # Adjusted figure size for potentially more bars
fig = plt.figure(figsize=(16, 8))
sns.barplot(data=all_data, x='display_date', y='count', hue='type', palette=['blue', 'orange'])
# Set the title and labels

plt.title('Created vs Completed Tickets per Month in Enterprise IT', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Number of Tickets')
plt.legend(title='Type of Ticket', loc='upper left')

plt.xticks(rotation=45)
plt.tight_layout()
plt.grid()
plt.legend()
plt.show()

# %%
# Create a 'date' column from 'year_updated' and 'month_updated'
velocity_updated = df_issues_tmp[df_issues_tmp['status'] == 'Done'].groupby(['year_updated', 'month_updated'])['velocity_days'].mean().reset_index(name='average_velocity')
velocity_updated['date'] = pd.to_datetime(
	dict(year=velocity_updated['year_updated'], month=velocity_updated['month_updated'], day=1)
)
velocity_updated['date'] = pd.to_datetime(velocity_updated['date'], format='%Y-%m-%d')
velocity_updated['date'] = velocity_updated['date'].dt.date
total_velocity = velocity_updated.copy()

# Define your time interval
start_date = '2024-01-01'
end_date = '2026-09-01'

# Ensure 'date' is datetime
total_velocity['date'] = pd.to_datetime(total_velocity['date'])

# Filter by interval
mask = (total_velocity['date'] >= start_date) & (total_velocity['date'] <= end_date)
filtered_velocity = total_velocity[mask]

plt.figure(figsize=(16, 8))

# Plot original data
#plt.plot(filtered_capacity['date'], filtered_capacity['created'], marker='o', label='Created', color='blue', alpha=0.5)
#plt.plot(filtered_capacity['date'], filtered_capacity['completed'], marker='o', label='Completed', color='orange', alpha=0.5)

# Calculate and plot 3-month moving averages
plt.plot(filtered_velocity['date'], filtered_velocity['average_velocity'].rolling(window=3, min_periods=1).mean(), 
        label='Average Velocity (3-mo MA)', color='blue', linewidth=2)
plt.axhline(y=90, color='red', linestyle='--', linewidth=2,    label='Maximum SLA Level')
plt.axhline(y=60, color='orange', linestyle='--', linewidth=2, label='Medium    SLA Level')
plt.axhline(y=30, color='green', linestyle='--', linewidth=2,  label='Minimum  SLA Level')
plt.title('Velocity in Days per Month on Completed Tickets (with Trend) in EIT', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Number of Days')
plt.xticks(rotation=0)
plt.ylim(0, 200)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
from matplotlib.ticker import MultipleLocator
start_year = 2020
total_per_year_df = df_issues[df_issues['year_updated'] >= start_year ].groupby(['year_updated']).agg(Total=('year_updated', 'count')).sort_values(['year_updated'])
# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(15, 10))

sns.barplot(x="year_updated", y="Total", data=total_per_year_df,
            hue='year_updated', legend=True, color='green',palette='bright')


# Add a legend and informative axis label
#ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set_xlabel("Calendar Year")
ax.set_ylabel("No. of Tickets")
#ax.set_title("AWS Total Accumulated Cost by Services over " + "${:,.2f}".format(int(anual_cost)) + "\n")
ax.set_title("Total Tickets Worked per Year \n")
#plt.xticks(rotation=90) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, ha='center')
#ax.set_xticklabels(labels=services_df['Service'],rotation=45)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.set_major_locator(MultipleLocator(100))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.0f}".format(int(x))))
ax.legend(title='Year', loc='upper left')
#plt.savefig("AWS Yearly Cost by Service")
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/2635963177.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=0, ha='center')

# %%
from datetime import datetime

# --- Parameters ---
# Define your time period (example: tickets DONE between 2025-08-01 and 2025-09-01)
start_date = "2025-10-01"
end_date = "2025-11-01"

# Fetch issues, including assignee, key, and summary fields
PROJECT_KEY = "DEVOPS"  # Replace with your project key
PROJECT_KEY_2 = "EIT"  # Replace with your project key
PROJECT_KEY_3 = "CAR"  # Replace with your project key

# JQL to filter issues with status DONE in the time period
jql_query = (
    f'status = "Done" AND statusCategoryChangedDate >= "{start_date}" AND statusCategoryChangedDate < "{end_date}" AND (project = "{PROJECT_KEY}" OR project = "{PROJECT_KEY_2}" OR project = "{PROJECT_KEY_3}")'
)

# Fetch issues (adjust maxResults as needed)
search_params = {
    "jql": jql_query,
    "maxResults": 5000,
    "fields": ["summary", "description", "comment", "status"],
    "expand": 'changelog',
    }

# Correct API endpoint
url = f"{jira_server}/rest/api/3/search/jql"
next_token = None
total_issues_processed = 0
done_issues = []
done_iterator_all = []
# Collect comments and descriptions
issues_comments = []
while True:
    if next_token:
        search_params["nextPageToken"] = next_token
    response = jira._session.get(url,params=search_params)

    issues_iterator = response.json()
    done_iterator = issues_iterator['issues']
    done_iterator_all = done_iterator_all + done_iterator

    for issue in done_iterator:
        issue_data = {
            "key": issue['key'],
            "summary": issue['fields']['summary'],
            "description": issue['fields'].get("description", ""),
            "comments": []
        }
        # Get all comments for the issue using the issue key (not the dict)
        try:
            comments = jira.comments(issue['key'])
            print(f"Processing issue: {issue['key']} with {len(comments)} comments with Status {issue['fields']['status']['name']}")
            for comment in comments:
                issue_data["comments"].append({
                    "author": comment.author.displayName,
                    "created": comment.created,
                    "body": comment.body
                })
        except Exception as e:
            print(f"Failed to fetch comments for {issue['key']}: {e}")
        issues_comments.append(issue_data)
                
    next_token = issues_iterator.get("nextPageToken")
    if not next_token:
        break
# Out:
# Processing issue: EIT-556 with 0 comments with Status Done
# Processing issue: EIT-554 with 0 comments with Status Done
# Processing issue: EIT-538 with 18 comments with Status Done
# Processing issue: EIT-537 with 0 comments with Status Done
# Processing issue: EIT-462 with 1 comments with Status Done
# Processing issue: EIT-457 with 2 comments with Status Done
# Processing issue: EIT-454 with 0 comments with Status Done
# Processing issue: EIT-367 with 4 comments with Status Done
# Processing issue: EIT-353 with 1 comments with Status Done
# Processing issue: DEVOPS-8479 with 1 comments with Status Done
# Processing issue: DEVOPS-8473 with 3 comments with Status Done
# Processing issue: DEVOPS-8469 with 0 comments with Status Done
# Processing issue: DEVOPS-8468 with 0 comments with Status Done
# Processing issue: DEVOPS-8466 with 0 comments with Status Done
# Processing issue: DEVOPS-8465 with 0 comments with Status Done
# Processing issue: DEVOPS-8463 with 4 comments with Status Done
# Processing issue: DEVOPS-8460 with 3 comments with Status Done
# Processing issue: DEVOPS-8458 with 2 comments with Status Done
# Processing issue: DEVOPS-8457 with 1 comments with Status Done
# Processing issue: DEVOPS-8456 with 0 comments with Status Done
# Processing issue: DEVOPS-8455 with 0 comments with Status Done
# Processing issue: DEVOPS-8453 with 0 comments with Status Done
# Processing issue: DEVOPS-8452 with 0 comments with Status Done
# Processing issue: DEVOPS-8444 with 0 comments with Status Done
# Processing issue: DEVOPS-8441 with 0 comments with Status Done
# Processing issue: DEVOPS-8438 with 4 comments with Status Done
# Processing issue: DEVOPS-8437 with 3 comments with Status Done
# Processing issue: DEVOPS-8434 with 1 comments with Status Done
# Processing issue: DEVOPS-8433 with 1 comments with Status Done
# Processing issue: DEVOPS-8432 with 1 comments with Status Done
# Processing issue: DEVOPS-8431 with 1 comments with Status Done
# Processing issue: DEVOPS-8424 with 0 comments with Status Done
# Processing issue: DEVOPS-8422 with 2 comments with Status Done
# Processing issue: DEVOPS-8421 with 1 comments with Status Done
# Processing issue: DEVOPS-8419 with 1 comments with Status Done
# Processing issue: DEVOPS-8418 with 4 comments with Status Done
# Processing issue: DEVOPS-8417 with 7 comments with Status Done
# Processing issue: DEVOPS-8415 with 1 comments with Status Done
# Processing issue: DEVOPS-8414 with 2 comments with Status Done
# Processing issue: DEVOPS-8413 with 6 comments with Status Done
# Processing issue: DEVOPS-8411 with 4 comments with Status Done
# Processing issue: DEVOPS-8405 with 2 comments with Status Done
# Processing issue: DEVOPS-8403 with 0 comments with Status Done
# Processing issue: DEVOPS-8400 with 5 comments with Status Done
# Processing issue: DEVOPS-8399 with 4 comments with Status Done
# Processing issue: DEVOPS-8398 with 1 comments with Status Done
# Processing issue: DEVOPS-8397 with 1 comments with Status Done
# Processing issue: DEVOPS-8396 with 0 comments with Status Done
# Processing issue: DEVOPS-8395 with 6 comments with Status Done
# Processing issue: DEVOPS-8394 with 3 comments with Status Done
# Processing issue: DEVOPS-8393 with 0 comments with Status Done
# Processing issue: DEVOPS-8391 with 1 comments with Status Done
# Processing issue: DEVOPS-8390 with 3 comments with Status Done
# Processing issue: DEVOPS-8389 with 2 comments with Status Done
# Processing issue: DEVOPS-8388 with 2 comments with Status Done
# Processing issue: DEVOPS-8387 with 1 comments with Status Done
# Processing issue: DEVOPS-8383 with 1 comments with Status Done
# Processing issue: DEVOPS-8381 with 1 comments with Status Done
# Processing issue: DEVOPS-8380 with 2 comments with Status Done
# Processing issue: DEVOPS-8378 with 1 comments with Status Done
# Processing issue: DEVOPS-8364 with 4 comments with Status Done
# Processing issue: DEVOPS-8346 with 0 comments with Status Done
# Processing issue: DEVOPS-8334 with 11 comments with Status Done
# Processing issue: DEVOPS-8304 with 5 comments with Status Done
# Processing issue: DEVOPS-8291 with 1 comments with Status Done
# Processing issue: DEVOPS-8290 with 0 comments with Status Done
# Processing issue: DEVOPS-8289 with 0 comments with Status Done
# Processing issue: DEVOPS-8281 with 1 comments with Status Done
# Processing issue: DEVOPS-8235 with 5 comments with Status Done
# Processing issue: DEVOPS-8234 with 6 comments with Status Done
# Processing issue: DEVOPS-8212 with 3 comments with Status Done
# Processing issue: DEVOPS-8182 with 5 comments with Status Done
# Processing issue: DEVOPS-8180 with 22 comments with Status Done
# Processing issue: DEVOPS-8162 with 6 comments with Status Done
# Processing issue: DEVOPS-8119 with 37 comments with Status Done
# Processing issue: DEVOPS-8055 with 12 comments with Status Done
# Processing issue: DEVOPS-8053 with 4 comments with Status Done
# Processing issue: DEVOPS-7983 with 6 comments with Status Done
# Processing issue: DEVOPS-7981 with 4 comments with Status Done
# Processing issue: DEVOPS-7961 with 3 comments with Status Done
# Processing issue: DEVOPS-7959 with 3 comments with Status Done
# Processing issue: DEVOPS-7761 with 4 comments with Status Done

# %%
#issues_comments[0]['description']['content'][0]['content'][0]['text']

# %%
#done_iterator

# %%
#done_iterator[100].changelog  # Access the changelog (history) of the first issue
'''
  'fields': {'summary': 'Edit Docusign Templates',
   'description': {'type': 'doc',
    'version': 1,
    'content': [{'type': 'paragraph',
      'content': [{'type': 'text',
        'text
'''
# Out:
# "\n  'fields': {'summary': 'Edit Docusign Templates',\n   'description': {'type': 'doc',\n    'version': 1,\n    'content': [{'type': 'paragraph',\n      'content': [{'type': 'text',\n        'text\n"

# %%
'''
len(issues_comments)
for i in range(len(issues_comments)):
    try:
        text = issues_comments[i]['description']['content'][0]['content'][0]['text']
        key = issues_comments[i].get('key')
        print(key, text)
    except (KeyError, IndexError, TypeError):
        print("No text found in description for issue:", key)
'''
# Out:
# '\nlen(issues_comments)\nfor i in range(len(issues_comments)):\n    try:\n        text = issues_comments[i][\'description\'][\'content\'][0][\'content\'][0][\'text\']\n        key = issues_comments[i].get(\'key\')\n        print(key, text)\n    except (KeyError, IndexError, TypeError):\n        print("No text found in description for issue:", key)\n'

# %%
# Convert iterator to a list if needed
done_issues_list = list(done_iterator_all)
comments_list = []
issue_key_list = []
print(f"Total DONE issues found: {len(done_issues_list)}")
# More efficient: iterate directly over done_issues_list, avoid indexing
for issue in done_issues_list:
    # If issue is a dict (from REST API), extract the key
    issue_key = issue['key'] if isinstance(issue, dict) and 'key' in issue else getattr(issue, 'key', None)
    if not issue_key:
        continue  # skip if no key found

    try:
        comments = jira.comments(issue_key)
    except Exception as e:
        print(f"Failed to fetch comments for {issue_key}: {e}")
        comments = []

    # Try to get summary (works for both dict and Issue object)
    summary = issue['fields']['summary'] if isinstance(issue, dict) and 'fields' in issue and 'summary' in issue['fields'] else getattr(issue.fields, 'summary', None)
    comments_list.append(summary)
    issue_key_list.append(issue_key)
    if comments:
        for comment in comments:
            comments_list.append(getattr(comment, 'body', str(comment)))
            issue_key_list.append(issue_key)
# Out:
# Total DONE issues found: 82

# %%
len(comments_list)
# Out:
# 339

# %%
#text = issues_comments[0]['description']['content'][0]['content'][0]['text']
#text = text.replace('\n', ' ')
#text = text.strip()
#text = re.sub(' +', ' ', text)  # Replace multiple spaces with a single space

# %%
#print(text)

# %%
import re

len(issues_comments)
for i in range(len(issues_comments)):
    key = None  # Ensure key is always defined
    try:
        text = issues_comments[i]['description']['content'][0]['content'][0]['text']
        text = text.replace('\n', ' ')
        text = text.strip()
        text = re.sub(' +', ' ', text)  # Replace multiple spaces with a single space
        key = issues_comments[i].get('key')
        print(key, text)
        comments_list.append(text)
        issue_key_list.append(key)
    except (KeyError, IndexError, TypeError):
        print("No text found in description for issue:", key)
# Out:
# EIT-556 Finish 2025-Q3 report - make sure it includes screen show that Astrid asked for
# EIT-554 Once we get updated 2400 inventory - I need to plan out how I’m finishing up Q3 AR
# No text found in description for issue: None
# EIT-537 Prep switches to be available to send out
# EIT-462 Requester Name: Daniel Pyles Requester Email: daniel.pyles@audacy.com Description: I just did a headcount, it looks like we will likely need about 40 Dell Mini Optiplex desktops to complete the windows 11 upgrades. All 5 stations use multiple computers for Adobe Audition between the main studio and the Air 2 studio. When attempting to image these computers, I found that the Creative Cloud version of Adobe is not compatible with the current computers that we have in place, so I believe these will all have to be replaced. I have also run into the problem of the computers that are not running Adobe Audition, not having available drivers anymore once the upgrade is done. This would place us in a problematic place with Computers that are used to play sound from the internet, Vox Pro, OBS, StreamYard and a few other various applications. Then we have all of our individual productions rooms and their need for Adobe Audition as well.
# EIT-457 Currently the new ZCUBETES01 environment the Spring 2025 release is downloading multiple files fro 2024 and other previous releases when it should ust be the one. This is happening for all daypart breakouts.
# No text found in description for issue: None
# EIT-367 Requester Name: Mike E Prasser Requester Email: mike.prasser@audacy.com Description: Both of our audio loggers need to be replaced in order to upgrade them to Windows 11. We need 2 rack mount computers with RAID capability that we can use for loggers. Is there something in surplus that we can use or do we need to order them ourselves? Thank you.
# EIT-353 Collaborate with Johnny, Jaylon, and Katy to begin drafting a communication and onboarding plan for the markets. This plan will inform users that Microsoft Office is being retired and that DocuSign will be the new standard for contract templates, including training and support resources.
# DEVOPS-8479 This is for
# DEVOPS-8473 It was discovered recently that the
# No text found in description for issue: None
# DEVOPS-8468 The current grafana alloy install for localhost throws an error when trying to install on a new instance.
# DEVOPS-8466 Repo needs to be migrated to continue the work
# DEVOPS-8465 Repo needs migration to continue the work
# DEVOPS-8463 deborahhealthreport.com needs to redirect to
# DEVOPS-8460 The
# DEVOPS-8458 Add the Audacy TGW CIDR to the security group rules for access to the admin ports
# DEVOPS-8457 As part of the EDP Build Out project, we need a docker image with all the tools baked for liquibase, python and gcloud installed.
# DEVOPS-8456 As part of the EDP Build Out project, a SDLC pipeline to help us deployment SCHEMA changes to BQ using liquibase and airflow deployment using GCP native tools.
# DEVOPS-8455 As part of the EDP Build Out project, we need a docker image with all the tools baked for liquibase, python and gcloud installed.
# DEVOPS-8453 As part of the EDP Build Out project, we need a docker image with all the tools baked for liquibase, python and gcloud installed.
# DEVOPS-8452 As part of the EDP Build Out project, a gitlab runner needs to be created to handle the SDLC and CICD of DAGS and DBM changes.
# DEVOPS-8444 As an engineer, we need to ensure that all of our Terraform repositories have defined GitLab pipelines so that only the resources that are being changed are the resources that ultimately get planned and applied by the Terraform-enabled GitLab runner. To continue this mission, we need to add GitLab piplines to the Adtech production Terraform repository.
# No text found in description for issue: None
# DEVOPS-8438 As an engineer, we need to ensure that all production workloads on Kubernetes are running as expected. To continue this mission, we need to address why containers in the production Recommendation EKS cluster are not running when expected.
# DEVOPS-8437 At 3:00 p.m. MT it was reported by
# DEVOPS-8434 Create the following Access Layer Data Set in the EDP DEV prj-edp-dev-edw project.
# DEVOPS-8433 Create the following business layer data sets in the EDP DEV prj-edp-dev-edw project.
# DEVOPS-8432 Create the src_roc_nts data set in the EDP DEV prj-edp-dev-edw project.
# DEVOPS-8431 Delete the src_identity data set from the EDP DEV
# DEVOPS-8424 MLB Playoffs are here, starting with the Wild Card round. This will increase load/listener counts on several Iceberg Clusters. We want to double the server count temporarily and then after the wild card round, revisit which stations / clusters will get more traffic in the Divisional Round.
# DEVOPS-8422 As an engineer, we need to ensure that our helm releases are as up-to-date as possible when referring to internal or external providers. To continue this mission, we need to update the helm chart version for all instances of Grafana alloy on EKS and GKE to
# DEVOPS-8421 As an engineer, we need to ensure that our helm releases are as up-to-date as possible when referring to internal or external providers. To continue this mission, we need to update the helm chart version for all instances of Grafana alloy on EKS and GKE to
# DEVOPS-8419 As an engineer, we need to ensure that image tags pushed for new releases are always updated by Flux. To continue this mission, we need to troubleshoot why Flux in the Recommendation nonprod EKS cluster has not pushed new tags to master since June 27th, 2025.
# DEVOPS-8418 Wisconsin Sports Radio brand is launching on monday 10/13 with a Unity CMS site. Please point
# DEVOPS-8417 Snowflake Service Account:
# DEVOPS-8415 This task involves integrating Apigee metrics into Grafana Cloud to establish a vital data pipeline for accessing operational data. The goal is to maintain monitoring visibility comparable to our previous setups and ensure that users can access and query raw Apigee metrics, such as traffic volume, latency, and error codes, through Grafana. To achieve this, the developer will configure the necessary components to facilitate these integrations, including:
# DEVOPS-8414 Make the changes in the attcahed ticket in Production MWAA
# DEVOPS-8413 Hi
# DEVOPS-8411 As an engineer, we need to ensure that legacy service in older Amperwave accounts are migrated to the new Amperwave account. To continue this effort, we need to migrate the Podcast Player and Podcast Full-Page Player service to the new Amperwave accounts.
# DEVOPS-8405 Hi team,
# DEVOPS-8403 need to help determine why their tagging DB is hoses
# DEVOPS-8400 Add ENV VARs to the support tools k8s config for QA and STG
# DEVOPS-8399 We're trying to set up a Jira automation for the @Boop Slack bot https://api.slack.com/apps/A045KG7HNCV To do so we need a Jira account/token for it to operate under. It needs permissions to: Create/edit tickets in the CAR project Read tickets in other projects Read email addresses of other users (it uses to match identity with Slack users) Either a new user or the existing "Automation for Jira" user are fine. Reference: https://entercomdigitalservices.atlassian.net/browse/DEVOPS-6507
# DEVOPS-8398 I’d like permission to create and edit dashboards in Grafana to help with monitoring releases for the Podsquad team.
# DEVOPS-8397 Hello Team,
# DEVOPS-8396 Create the following base-layer data sets in the EDP DEV
# DEVOPS-8395 As part of the EDP Build Out project, the following apis need to be enabled in the
# DEVOPS-8394 annotations: configmap.reloader.stakater.com/reload: "clarity,clarity-nginx-template" secret.reloader.stakater.com/reload: "clarity"
# No text found in description for issue: None
# DEVOPS-8391 As part of the EDP Build Out project, the following apis need to be enabled in the
# DEVOPS-8390 The Iceberg OOM kills this week highlighted the fact the service does not auto-restart on any sort of failure. In this case an oom-kill.
# DEVOPS-8389 We need to create hosted zone rec in Route53 - "
# DEVOPS-8388 We need to add CNAMES for LACondom.com for our client.
# DEVOPS-8387 Remove all access for Angel Cancio
# DEVOPS-8383 The podcast-rss-parser should have access to this cloned table.
# DEVOPS-8381 We have an affiliate station that have rebranded and requested a redirect from the old slug.
# DEVOPS-8380 Hello, On Monday, September 29, our team published a merge request in the episode-topic-analyzer repository: https://gitlab.audacy.com/gcp/ai-initiatives/episode-topic-analyzer/-/merge_requests/11 The release pipelines for publishing the two associated K8s workloads completed successfully, as observed in Gitlab. However, those workloads were not updated with new revisions as a result of the successful pipelines as expected. After the merge, the latest revisions remaining those from September 8 and 9. Workload 1: https://console.cloud.google.com/kubernetes/deployment/us-east4/ai-initiatives-nonprod/dev/topic-analyzer/details?project=prj-initiatives-nonprod-1703 Workload 2: https://console.cloud.google.com/kubernetes/deployment/us-east4/ai-initiatives-nonprod/dev/topic-analyzer-webapp/overview?project=prj-initiatives-nonprod-1703 Would you please help us investigate why the Gitlab merge pipeline did not release our changes? Understanding how we can properly update these applications is critical to our ability to deliver new features and bugfixes for the business. Thanks, Chris
# DEVOPS-8378 We need to create a GCS bucket that will store the Kafka data delivered by the Kafka to GCS connectors in the EDP DEV environment
# DEVOPS-8364 As an engineer, we need to ensure that when environment variables are added to Kubernetes deployments, those deployments are gracefully restarted and the new environment variables are applied and available to the application or service. We accomplish this today by using a “reloader” controller.
# DEVOPS-8346 The current config for Icemaker gitlab-ci.yml and included scripts pass the wrong value(null) for the ARTIFACT_FILENAME to the ansible task for deploy_im. Define the variable and pass it to the ansible script in each of the environments dev/qa/stg/prod.
# No text found in description for issue: None
# DEVOPS-8304 Ship logs from S3 bucket
# DEVOPS-8291 Per the
# DEVOPS-8290 Per the
# DEVOPS-8289 Per the
# DEVOPS-8281 Per the
# DEVOPS-8235 This relates to
# DEVOPS-8234 This relates to
# No text found in description for issue: None
# DEVOPS-8182 Requester Name: Diane Harnly. Requester Email: diane.harnly@audacy.com Description: ali.faheem@arbisoft.com need permissions to approval and merge for data science gitlab projects. Request Details Email Address: First Name: Last Name: Manager's Name/Email: Department/Functional Area: Type of GCP Access: {{ticket.ticket_field_option_title_34147089894555}} Is This Request for Existing or New Resources?: {{ticket.ticket_field_option_title_34147216167707}} GCP Project Name: Resource Name or Description: Environment: {{ticket.ticket_field_option_title_34147328419227}} Name/Email of Someone with Similar Access (If Applicable): Requested Permissions Level: Reason for Access Request: Duration of Access (If Temporary): Existing AD Group?: {{ticket.ticket_field_option_title_34147452589467}}
# DEVOPS-8180 As an engineer, we need to ensure that we are sending log/event data from Fastly to Grafana so that we can shut off DataDog collection. To accomplish this, we need to create a Prometheus data source in Grafana and use Fastly Exporter to stream this data to Grafana.
# DEVOPS-8162 As an engineer, we need to ensure that our EC2 instances are correctly configured to collect and send metric & log data to Grafana Cloud. To accomplish this, we will need a local script for the EC2 images (iceberg,icemaker,icecast,ssais) that registers the instances with grafana cloud. The script should identify the instance hostname a unique ID for filtering with Grafana Fleet Management.
# DEVOPS-8119 As part of task (
# DEVOPS-8055 The Data team has a project to allow Megaphone impression data to be picked up by our partner, CBS (via Paramount). Platform engineering previously created an S3 bucket for this project. The details are in the linked task here DEVOPS-7488 To finalize the connection we have to create an IAM role containing a trust policy that uses the External Id that CBS (Paramount) provided as a condition for access. CBS confirmed the details of this trust policy below:
# DEVOPS-8053 Migrate Production Amperwave Redis to Valkey. The endpoint should not change.
# DEVOPS-7983 As an engineer, … This bucket in the Aardvark2 account needs to be accessible via podcast-rss-fetcher and podcast-rss-parser in PROD.
# DEVOPS-7981 The podcast-rss-fetcher and podcast-refresher should have access to this cloned table.
# DEVOPS-7961 Not to be completed until
# DEVOPS-7959 This is to be completed as part of cleanup phase of
# DEVOPS-7761 An issue has been identified where a radio trade reporter in New Jersey is receiving an "out of country" message, likely due to their IP address (68.197.201.242) being mis-categorized. This ticket is to investigate the reported mis-categorization and to determine if PE or other teams have a rapid method for submitting or checking IP addresses for similar issues in the future.

# %%
#done_issues_list

# %%
len(comments_list)
# Out:
# 414

# %%
len(issue_key_list)
# Out:
# 414

# %%
comments_df = pd.DataFrame({
    'issue_key': issue_key_list,
    'comment_body': comments_list
})
# Save comments to a CSV file
# comments_df.to_csv('jira_done_issues_comments.csv', index=False)
# print("Comments saved to 'jira_done_issues_comments.csv'.")

# %%
comments_df.sample(10)  # Display a sample of 10 comments for verification
# Out:
#        issue_key                                       comment_body
# 298  DEVOPS-8055  [~accountid:60e4d2b45cdb680071cdf5fa] can you ...
# 293  DEVOPS-8119  [~accountid:712020:620b0743-c627-44d9-8eef-f37...
# 94   DEVOPS-8418  [~accountid:557058:04a976b7-d9ba-4b7a-b70a-258...
# 87   DEVOPS-8421                                      This is done.
# 48   DEVOPS-8463  Turns out this redirect was actually being don...
# 119  DEVOPS-8411      The linked issue - CAR-2981 has been resolved
# 203  DEVOPS-8281  [NONPROD] Create serviceAccounts for prj-edp-q...
# 54   DEVOPS-8458  Add an internal Security rule to the SGs for I...
# 259  DEVOPS-8119  This ticket will unblock [https://entercomdigi...
# 362  DEVOPS-8434  Create the following Access Layer Data Set in ...

# %%
#comments_df[comments_df['issue_key'] == 'DEVOPS-8293']['comment_body'].values

# %%
len(comments_df['issue_key'].unique()) # Get the number of unique issue keys from the comments DataFrame
# Out:
# 82

# %% [markdown]
# # Word Cloud Generation

# %%
#! pip3 install wordcloud

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Combine all comments into a single string
all_comments_text = " ".join(comments_df['comment_body'].astype(str))
all_comments_text = all_comments_text.replace('\n', ' ')  # Replace newlines with spaces for better word cloud generation
all_comments_text = all_comments_text.replace('will', ' ')  # Replace 'will' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('Jira', ' ')  # Replace 'Jira' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('noformat', ' ')  # Replace 'noformat' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('https', ' ')  # Replace 'https' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('gitlab', ' ')  # Replace 'gitlab' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('audacy', ' ')  # Replace 'audacy' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('need', ' ')  # Replace 'need' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('done', ' ')  # Replace 'done' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('ticket', ' ')  # Replace 'ticket' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('h2', ' ')  # Replace 'h2' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('h3', ' ')  # Replace 'h3' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('index', ' ')  # Replace 'index' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('query', ' ')  # Replace 'query' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('issue', ' ')  # Replace 'issue' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('csv', ' ')  # Replace 'csv' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('gz', ' ')  # Replace 'gz' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('Thank', ' ')  # Replace 'Thank' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('arc', ' ')  # Replace 'arc' with a space for better word cloud generation
all_comments_text = all_comments_text.replace('accountid', ' ')  # Replace 'accountid' with a space for better word cloud generation

#all_comments_text = all_comments_text.replace('1e', ' ')  # Replace '1e' with a space for better word cloud generation
# Remove non-alphanumeric characters (keep spaces)
all_comments_text = re.sub(r'[^a-zA-Z0-9\s]', ' ', all_comments_text)
#all_comments_text = re.sub(r'\s+', ' ', all_comments_text)  # Replace multiple spaces with a single space
# Replace all words that start with a number with a blank
all_comments_text = re.sub(r'\b\d\w*\b', ' ', all_comments_text)
# Replace all words that start with a letter and are followed by a number with a blank
all_comments_text = re.sub(r'\b[a-zA-Z]\w*\d+\w*\b', ' ', all_comments_text)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_comments_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title(f'Most Frequent words in Jira Comment Keywords in the last {len(done_issues_list)} Done Tickets', fontsize=16)
plt.show() # Use plt.show() to display, or plt.savefig() to save

# %% [markdown]
# # https://stackoverflow.com/questions/38916452/nltk-download-ssl-certificate-verify-failed

# %% [markdown]
# # Top 20 Most Common Words Bar Chart

# %%
''''
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download()
'''
# Out:
# "'\nimport nltk\nimport ssl\n\ntry:\n    _create_unverified_https_context = ssl._create_unverified_context\nexcept AttributeError:\n    pass\nelse:\n    ssl._create_default_https_context = _create_unverified_https_context\n\nnltk.download()\n"

# %%
#!pip3 install nltk

# %%
import nltk

print("NLTK data search paths:")
for path in nltk.data.path:
    print(path)
# Out:
# NLTK data search paths:
# /Users/jorge.rodriguez/nltk_data
# /Library/Frameworks/Python.framework/Versions/3.14/nltk_data
# /Library/Frameworks/Python.framework/Versions/3.14/share/nltk_data
# /Library/Frameworks/Python.framework/Versions/3.14/lib/nltk_data
# /usr/share/nltk_data
# /usr/local/share/nltk_data
# /usr/lib/nltk_data
# /usr/local/lib/nltk_data

# %%
import nltk

# Example: Check for 'stopwords'
try:
    stopwords_path = nltk.data.find('corpora/stopwords')
    print(f"\n'stopwords' resource found at: {stopwords_path}")
except LookupError:
    print("\n'stopwords' resource not found in NLTK data paths.")

# Example: Check for 'wordnet'
try:
    wordnet_path = nltk.data.find('corpora/wordnet')
    print(f"'wordnet' resource found at: {wordnet_path}")
except LookupError:
    print("'wordnet' resource not found in NLTK data paths.")

# Example: Check for 'omw-1.4' (Open Multilingual Wordnet)
try:
    omw_path = nltk.data.find('tokenizers/punkt/')
    print(f"'punkt' resource found at: {omw_path}")
except LookupError:
    print("'punkt' resource not found in NLTK data paths.")
# Out:
# 'stopwords' resource found at: /Users/jorge.rodriguez/nltk_data/corpora/stopwords
# 'wordnet' resource found at: /Users/jorge.rodriguez/nltk_data/corpora/wordnet
# 'punkt' resource found at: /Users/jorge.rodriguez/nltk_data/tokenizers/punkt

# %%
#nltk.download('punkt')
#nltk.download('wordnet')
#nltk.download('stopwords')

# %%
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string

# Assuming 'all_comments_text' contains the combined preprocessed text
# (from the 'processed_comment' column of your DataFrame)

# Download required NLTK data if not already present
#nltk.download('punkt')
#nltk.download('wordnet')
#nltk.download('stopwords')

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Tokenize, lowercase, remove punctuation, remove stopwords, and lemmatize
tokens = nltk.word_tokenize(all_comments_text)
words = [
    lemmatizer.lemmatize(word.lower())
    for word in tokens
        if word.isalpha() and word.lower() not in stop_words
]
most_common_words = Counter(words).most_common(20) # Top 20 words

common_words_df = pd.DataFrame(most_common_words, columns=['word', 'count'])

plt.figure(figsize=(12, 6))
plt.bar(common_words_df['word'], common_words_df['count'], color='skyblue')
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title(f'Top 20 Most Frequent words in Jira Comment Keywords in the last {len(done_issues_list)} Done Tickets')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show() # Use plt.show() to display, or plt.savefig() to save

# %% [markdown]
# # Top 15 Jira Issues by Comment Count Bar Chart

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming 'df' is your DataFrame with 'issue_key' column

comments_per_issue = comments_df['issue_key'].value_counts().reset_index()
comments_per_issue.columns = ['issue_key', 'comment_count']

top_15_issues = comments_per_issue.head(15)

plt.figure(figsize=(14, 7))
plt.bar(top_15_issues['issue_key'], top_15_issues['comment_count'], color='lightcoral')
plt.xlabel('Jira Issue Key')
plt.ylabel('Number of Comments')
plt.title('Top 15 Jira Issues by Comment Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show() # Use plt.show() to display, or plt.savefig() to save

# %% [markdown]
# # generate the bi-grams visualization and analysis:

# %%
import re
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd

NUMBER_OF_WORDS_TO_CONNECT = 2 # For bi-grams, set to 2; for tri-grams, set to 3, etc.
# Function for basic text preprocessing
def basic_preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove non-alphanumeric characters (keep spaces)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Function to generate N-grams (e.g., bi-grams if n=2)
def generate_ngrams(text, n=NUMBER_OF_WORDS_TO_CONNECT):
    # Split text into words
    words = text.split()
    # Generate n-grams
    ngrams = []
    for i in range(len(words) - n + 1):
        ngrams.append(" ".join(words[i:i+n]))
    return ngrams

# Assuming 'df' is your DataFrame loaded from 'jira_done_issues_comments.csv'
# If you are running this code independently, you'll need to load the CSV first:
# df = pd.read_csv('jira_done_issues_comments.csv')

# Apply basic preprocessing to the 'comment_body' column
comments_df['processed_comment'] = comments_df['comment_body'].apply(basic_preprocess_text)

# Combine all processed comments into a single string
all_comments_text = " ".join(comments_df['processed_comment'])

# Generate bi-grams from the combined text
bi_grams = generate_ngrams(all_comments_text, n=NUMBER_OF_WORDS_TO_CONNECT)

# Get the most common bi-grams
most_common_bi_grams = Counter(bi_grams).most_common(40) # Top 20 bi-grams

# Create a DataFrame for common bi-grams for easy plotting
common_bi_grams_df = pd.DataFrame(most_common_bi_grams, columns=['bi_gram', 'count'])

# Plotting the most common bi-grams
plt.figure(figsize=(14, 7))
plt.bar(common_bi_grams_df['bi_gram'], common_bi_grams_df['count'], color='lightgreen')
plt.xlabel('Bi-gram Phrase')
plt.ylabel('Frequency')
plt.title('Top 20 Most Common Bi-grams in Jira Comments')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show() # Use plt.show() to display the plot, or plt.savefig('top_20_bi_grams.png') to save it

# %% [markdown]
# ## --- Velocity Graphs ---

# %%
# --- Plotting ---
# Set the visual theme for the plots
sns.set_theme(style="whitegrid")

# Create the figure and axes for the plot
# Adjust figsize=(width, height) in inches as needed
plt.figure(figsize=(10, 6))

# --- Create the Box Plot ---
# x-axis: The status categories from your 'velocity' column
# y-axis: The age values from your age column
# data: Your DataFrame
# palette: Optional color scheme
df = df_issues.copy()
#df = df[(df['updated'].dt.year > 2000) & (df['created'].dt.year > 2000)] # Filter out rows with NaT values
# Now you can safely use the .dt accessor
#df = df[df['status'] == 'In Progress'] # Filter out NaT values
df = df[df['status'] != 'Done'] # Filter out NaT values
df = df[df['status'] != 'Will Not Do'] # Filter out NaT values
#df = df[df['status'] != 'Blocked'] # Filter out NaT values
#df = df[df['status'] != 'Resource Constrained'] # Filter out NaT values
#df = df[df['status'] != 'On Hold'] # Filter out NaT values
#df = df[df['status'] != 'Tech Discovery Required'] # Filter out NaT values
#df = df[df['days_old'] <= 365] # Filter out NaT values

# Ensure 'velocity' is of type timedelta
#df['velocity'] = pd.to_timedelta(df['velocity'], errors='coerce')

# Use .dt.days to extract the number of days from the 'velocity' column
#d f['velocity_days'] = df['velocity'].dt.days


# Create the box plot using the 'velocity_days' column
ax = sns.boxplot(x='status', y='days_old', data=df, palette="viridis", hue='status')

# --- Customize the Plot ---
# Add a title
plt.title(f'Distribution of Ticket Age by Status')

# Set axis labels
plt.xlabel('Status')
plt.ylabel('Ticket Age (days old)')
y_min, y_max = plt.ylim() # Get current y-axis limits
y_min = 0 # Set minimum y-axis limit to 0
#y_max = 400
plt.ylim(y_min, y_max) # Set y-axis limits to the current limits


# Rotate x-axis labels if they are long or overlap
plt.xticks(rotation=45, ha='right')

# Adjust layout to prevent labels from overlapping
plt.tight_layout()

# --- Display the Plot ---
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/3580838917.py:53: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) Arial.
#   plt.tight_layout()
# /Users/jorge.rodriguez/Library/Python/3.14/lib/python/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10060 (\N{CROSS MARK}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# df[df['days_old'] > 400].head(10)  # Display the first 10 rows of the DataFrame for verification

# %%
#df['status'].unique()  # Get unique status values in the DataFrame

# %%
# --- Alternative: Violin Plot ---
# If you prefer a violin plot (shows density distribution), uncomment the lines below:

df = df_issues.copy()
#df = df[(df['updated'].dt.year > 2000) & (df['created'].dt.year > 2000)] # Filter out rows with NaT values
# Now you can safely use the .dt accessor
#df = df[df['status'] == 'In Progress'] # Filter out NaT values
df = df[df['status'] != 'Done'] # Filter out NaT values
df = df[df['status'] != 'Will Not Do'] # Filter out NaT values
#df = df[df['status'] != 'Blocked'] # Filter out NaT values
df = df[df['status'] != 'Resource Constrained'] # Filter out NaT values
df = df[df['status'] != 'Released Successfully to Production'] # Filter out NaT values
df = df[df['status'] != '❌ Rolled Back'] # Filter out NaT values
df = df[df['status'] != 'Blocked For Development'] # Filter out NaT values
df = df[df['status'] != 'Plan Release'] # Filter out NaT values
plt.figure(figsize=(10, 6))
ax_violin = sns.violinplot(x='status', y='velocity_days', data=df[(df['status'] != 'Done') & (df['status'] != 'Will Not Do') & (df['status'] != 'Released Successfully to Production')], 
                           palette="viridis", inner="stick", hue='status') # 'inner' can be 'box', 'quartile', 'point', 'stick', None
#plt.title(f'Distribution by Status ({status.capitalize()}) - Violin Plot')
plt.title(f'Distribution by Status - Violin Plot')
plt.xlabel(f"Status ({', '.join(status)})")
plt.ylabel('Ticket Age (days old)')
plt.xticks(rotation=45, ha='right')
y_min, y_max = plt.ylim() # Get current y-axis limits
y_min = 0 # Set minimum y-axis limit to 0
#y_max = 400
plt.ylim(y_min, y_max) # Set y-axis limits to the current limits
plt.tight_layout()
plt.show()

# %%
# Import ticker from matplotlib
# from matplotlib import ticker

# Convert the 'velocity' column to timedelta if not already in that format
#df_issues['velocity'] = pd.to_timedelta(df_issues['velocity'], errors='coerce')

df_velocity = df_issues.copy()
# Now you can safely use the .dt accessor
df = df_velocity[df_velocity['days_old'] <= 100].copy() # Filter out NaT values
df = df[df['status'] == 'To Do'] # Filter out NaT values
#df = df[df['status'] != 'Done'] # Filter out NaT values
#df = df[df['status'] != 'Will Not Do'] # Filter out NaT values
#df = df[df['status'] != 'In Progress'] # Filter out NaT values
#df = df[df['status'] != 'In Review'] # Filter out NaT values
#df = df[df['status'] != 'To Do'] # Filter out NaT values
#df = df[df['status'] != 'Backlog'] # Filter out NaT values
#df = df[df['status'] != 'In Analysis'] # Filter out NaT values
#df = df[df['status'] != 'In Development'] # Filter out NaT values
#df = df[df['status'] != 'In Test'] # Filter out NaT values
#df = df[df['status'] != 'In QA'] # Filter out NaT values
#df = df[df['status'] != 'In UAT'] # Filter out NaT values
#df = df[df['status'] != 'In Deployment'] # Filter out NaT values
#df = df[df['status'] != 'In Production'] # Filter out NaT values
#df = df[df['status'] != 'In Review'] # Filter out NaT values
#df = df[df['status'] != 'In Verification'] # Filter out NaT values
#df = df[df['status'] != 'In Validation'] # Filter out NaT values
#df = df[df['status'] != 'In Release'] # Filter out NaT values
#df = df[df['status'] != 'In Staging'] # Filter out NaT values
#df = df[df['status'] != 'In Pre-Production'] # Filter out NaT values
#df = df[df['status'] != 'In Production'] # Filter out NaT values
#df['velocity'].dt.days
#df['velocity'].dt.days.value_counts()
#df['velocity'].dt.days.value_counts().sort_index()
# Plotting the velocity of issues
plt.figure(figsize=(12, 6))
#sns.barplot(x=df['velocity'].dt.days.value_counts().sort_index().index,
#            y=df['velocity'].dt.days.value_counts().sort_index().values
#            ) # Filter out NaT values
sns.barplot(x=df['days_old'].value_counts().sort_index().index,
            y=df['days_old'].value_counts().sort_index().values
            ) # Filter out NaT values
plt.title('Velocity of Tickets (100 Days) - Backlog - ' + str(df['days_old'].value_counts().sum()) + ' Tickets in the To Do Status')
plt.xlabel('Days')
plt.ylabel('Number of Tickets')
plt.tight_layout()
#plt.axhline(y=df['velocity'].dt.days.value_counts().sort_index().mean(), color='r', linestyle='--', label='Mean Velocity')
plt.ylim(0, df['days_old'].value_counts().sort_index().max() + 2) # Set y-axis limits to the current limits
from matplotlib.ticker import MultipleLocator
# Set the step size for y-axis ticks
plt.gca().yaxis.set_major_locator(MultipleLocator(2))
plt.show()
#print(df['velocity_days'].value_counts().sum())
#print(df.shape)

# %%
df_velocity = df_issues.copy()
# Now you can safely use the .dt accessor
df = df_velocity[df_velocity['days_old'] <= 400].copy() # Filter out NaT values
#df = df[df['status'] == 'To Do'] # Filter out NaT values
#df = df[df['status'] != 'Done'] # Filter out NaT values
#df = df[df['status'] != 'Will Not Do'] # Filter out NaT values
df = df[df['status'] == 'In Progress'] # Filter out NaT values
#df = df[df['status'] != 'In Review'] # Filter out NaT values
#df = df[df['status'] != 'To Do'] # Filter out NaT values
#df = df[df['status'] != 'Backlog'] # Filter out NaT values
#df = df[df['status'] != 'In Analysis'] # Filter out NaT values
#df = df[df['status'] != 'In Development'] # Filter out NaT values
#df = df[df['status'] != 'In Test'] # Filter out NaT values
#df = df[df['status'] != 'In QA'] # Filter out NaT values
#df = df[df['status'] != 'In UAT'] # Filter out NaT values
#df = df[df['status'] != 'In Deployment'] # Filter out NaT values
#df = df[df['status'] != 'In Production'] # Filter out NaT values
#df = df[df['status'] != 'In Review'] # Filter out NaT values
#df = df[df['status'] != 'In Verification'] # Filter out NaT values
#df = df[df['status'] != 'In Validation'] # Filter out NaT values
#df = df[df['status'] != 'In Release'] # Filter out NaT values
#df = df[df['status'] != 'In Staging'] # Filter out NaT values
#df = df[df['status'] != 'In Pre-Production'] # Filter out NaT values
#df = df[df['status'] != 'In Production'] # Filter out NaT values
#df['velocity'].dt.days
#df['velocity'].dt.days.value_counts()
#df['velocity'].dt.days.value_counts().sort_index()
# Plotting the velocity of issues
plt.figure(figsize=(12, 6))
#sns.barplot(x=df['velocity'].dt.days.value_counts().sort_index().index,
#            y=df['velocity'].dt.days.value_counts().sort_index().values
#            ) # Filter out NaT values

sns.barplot(x=df['days_old'].value_counts().sort_index().index,
            y=df['days_old'].value_counts().sort_index().values
            ) # Filter out NaT values
plt.title('Velocity of Tickets (100 Days) - Backlog - ' + str(df['days_old'].value_counts().sum()) + ' Tickets in the In Progress Status')
plt.xlabel('Days')
plt.ylabel('Number of Tickets')
plt.xticks(rotation=90) # Rotate x-axis labels if needed
plt.tight_layout()
#plt.axhline(y=df['velocity'].dt.days.value_counts().sort_index().mean(), color='r', linestyle='--', label='Mean Velocity')
plt.ylim(0, df['days_old'].value_counts().sort_index().max() + 2) # Set y-axis limits to the current limits
plt.show()
#print(df['velocity_days'].value_counts().sum())
#print(df.shape)

# %%
df_issues['priority_name'].value_counts().sort_values(ascending=False)
# Out:
# priority_name
# None           5418
# High           1280
# Medium         1029
# No Priority     590
# Urgent          342
# Low             302
# P2 - Normal      13
# P1 - Major        1
# Name: count, dtype: int64

# %%
df_issues['status'].value_counts()
# Out:
# status
# Done                                   7217
# Will Not Do                            1322
# Released Successfully to Production     227
# To Do                                    52
# Triage                                   49
# Resource Constrained                     29
# In Progress                              27
# Tech Discovery Required                  10
# Backlog                                   9
# Blocked                                   7
# On Hold                                   7
# Technical Debt                            6
# Validating                                5
# ❌ Rolled Back                             5
# Prepare Release                           2
# Plan Release                              1
# Name: count, dtype: int64

# %%
print(f"Finished fetching. Found {total_issues_processed} issues in total.")
print("\n--- Summary of Counts ---")
print("\nAssignee Counts:")
for assignee, count in assignee_counts.items():
    print(f"- {assignee}: {count}")
print("\nIssue Creator Counts:")
for creator, count in issue_creator_counts.items():
    print(f"- {creator}: {count}")
print("\nStatus Counts:")
for status, count in status_counts.items():
    print(f"- {status}: {count}")
print("\nIssue Type Counts:")
for issue_type, count in issue_type_counts.items():
    print(f"- {issue_type}: {count}")
print("\nScript finished.")
# Out:
# Finished fetching. Found 0 issues in total.
#
# --- Summary of Counts ---
#
# Assignee Counts:
# - Aaron Schultheis: 1
# - Aaron Wolfrom: 62
# - Adam Shero: 412
# - Adrien.Carlson: 11
# - Aislinn Joyce: 11
# - AkashD: 39
# - Alec Sands: 66
# - Alejandro Benjumea: 16
# - Alejandro Ponce: 21
# - Alex Peguero-Cruz: 4
# - Alex Wilson: 10
# - Alison Dougherty: 2
# - Amit Manocha: 1
# - Amy Van Hook: 4
# - Anas Ahmad: 6
# - Andriy Petryshyn: 23
# - Andy Drake: 1
# - Angel Cancio: 395
# - Anne Tiotuico: 1
# - Arjun Parajuli: 1
# - Austin Lane: 38
# - Ben Bonora: 22
# - Beverly Lam: 19
# - bilal.waheed: 2
# - Bolanle: 796
# - Brad Dunnigan: 2
# - brent.bonet: 1
# - Brian Bosworth: 71
# - Brian Wagner: 3
# - Bryan.DeVries: 9
# - Bryan Harris: 39
# - Carlos Zuniga Ballestero: 3
# - Chandler Deming: 1
# - Chris Haggard: 1
# - Chris Hodges: 135
# - Chris Strolia-Davis: 5
# - Christian Tragesser: 1
# - Christina Koerte: 1
# - Cris Stoddard: 1
# - Cristhiam David Henao Moreno: 2
# - Crystal.Ju: 2
# - Cullen Philippson: 441
# - Daniel.Newell: 14
# - Daniel Warshaw: 1
# - Danish Sattar: 6
# - Dan Shepard: 573
# - David Caballero: 617
# - David Caballero Miranda: 67
# - David Wright: 104
# - Davirlein Prada Devia: 2
# - Denys Loboda: 11
# - Devesh Singh: 1
# - Dewayne Korth: 58
# - Dmytro Oliinyk: 13
# - Don.Furline: 9
# - Dorin Onofrei: 3
# - Dwayne Steinway: 9
# - Ebenezer: 5
# - Ed Colgan: 3
# - Elizabeth Jones: 2
# - Ella Arana: 1
# - Emmanuel Adjei: 3
# - Eric Paul: 209
# - Erika Moya: 2
# - Erin Fink: 41
# - Fadi Elkhatib: 2
# - Felix Curry: 1
# - Former user: 239
# - Nathan Carmine: 1
# - Harold Wilson: 1
# - Ben Leffler: 3
# - Jon West: 6
# - Chad: 30
# - Nicholas Booth: 1
# - Kiran Yellamarthi: 7
# - Gary Ivy: 1
# - Gil Orellana: 6
# - Giovani Mombelli Mussio: 2
# - Grace Martorano: 22
# - Hammad Daoud: 13
# - hani.kanafani: 2
# - Henry Wadsworth: 1
# - James Brown: 6
# - Jason Cox: 50
# - Jeff Naparstek: 5
# - Jeff Slutz: 103
# - Jeff Stuewe: 296
# - Jen Mercer: 24
# - Jere Jones: 23
# - Jeremy Chase: 40
# - Jeremy Fisher: 1
# - jeremy.williams: 13
# - Jeremy Zevin: 10
# - Jerry Hill: 1
# - Jesse.Larson: 24
# - Joel Flickinger: 68
# - Joel Stoker: 4
# - Joe Parlett: 79
# - Johnathan Kulovitz: 195
# - John Martyniak: 1
# - Jonathan Duck: 121
# - Jonathan Sass: 57
# - Jorge.Rodriguez: 2
# - Josh Currier: 4
# - joshua.saunders: 1
# - Joshua.Saunders: 2
# - Josh Wolfe: 8
# - Josiah Nosek: 26
# - Juan Camilo Giraldo Chaverra: 1
# - Juan David Restrepo Toro: 1
# - Juan Reyes: 294
# - Julian Figueroa Torres: 3
# - Justin Filion: 48
# - Kandarp Bhatt: 1
# - Keith.Sherwood: 2
# - Kenny Fakunle: 5
# - Kenny Lanza: 4
# - Kerri Walker: 3
# - Kevin Damazyn: 1
# - kevin.warnock: 12
# - Kristyn Howarth: 2
# - Kurtis Moffett: 15
# - Laura Tejada Cardona: 2
# - Leah.Laux: 4
# - Leah Walker: 6
# - leland kwong: 13
# - Liz Brown: 1
# - Luis Felipe Bertel Mercado: 3
# - Mark Buchanan: 2
# - Markham Rollins: 40
# - mark white: 63
# - Matt Osminer: 1
# - Max Campolo: 3
# - MeLissa Elwell: 16
# - Michael.Estes: 3
# - Michelle Arbeeny: 1
# - Mike Admire: 186
# - Mrinal Kaustuv: 2
# - M Sheridan: 60
# - Nazarii Sheremet: 5
# - Nebiyou Yismaw: 1
# - Nick Wheeler: 1
# - Nina Mischenko: 1
# - Omotola Enwe: 1
# - Owen Tregoning: 1
# - Pablo Navarro: 1
# - Paul Brower: 1
# - Pavel Novodvorskiy: 6
# - Pavlo Prokhorov: 1
# - Philip Johnson: 2
# - Phil Olson: 3
# - Ramandeep Kaur: 1
# - Randall Puterbaugh: 108
# - Raymond DeRoo: 15
# - Ricky Harkins: 1
# - Roman Jimenez: 13
# - Roman Ostash: 2
# - Ronald Porch: 13
# - Ryan Hartman: 31
# - Saad Savari: 2
# - Sabrina Szymczak: 5
# - sabrina.szymczak: 6
# - Sam Clark: 13
# - satish kumar marana: 208
# - scott.ennover: 94
# - Sean Finley: 1
# - Shala Warner: 5
# - Sharad Patel: 229
# - Sherman Glass: 60
# - Shubham Panday: 2
# - Simon Davison: 538
# - simon.davison: 20
# - Sireesha Maddineni: 3
# - soban.khalid: 352
# - Sohaib Aslam: 2
# - Somisetty Chowdappa: 1
# - Stanley Griggs: 9
# - stephanie.barulic: 1
# - stephen.smith: 16
# - Steven Perez: 5
# - Terry Dougal: 227
# - Tiffany Chow: 46
# - Tim Browne: 1
# - Tim Matyas: 41
# - Tommy O'Keefe: 36
# - Tom Terry: 1171
# - Tony Istvan: 2
# - Tyler Hyndman: 2
# - Tyler Wardhaugh: 2
# - Victoria Benecke: 1
# - Vincent Ma: 1
# - Vincent Murr: 2
# - Vitaly Shoykhet: 1
# - Web Beveridge: 1
# - Yosuf Monis: 2
# - Yuriy.kukhtin: 3
# - Zach Hahn: 8
# - Zach Sheehan: 4
# - Unassigned: 1628
#
# Issue Creator Counts:
# - Aaron Schultheis: 39
# - Christina Koerte: 6
# - Grace Martorano: 122
# - scott.ennover: 55
# - Zendesk Support for Jira: 353
# - Mark Buchanan: 294
# - Jeff Stuewe: 185
# - Aaron Wolfrom: 6
# - Adam Shero: 483
# - Randall Puterbaugh: 62
# - simon.davison: 17
# - Kerri Walker: 8
# - Andriy Petryshyn: 11
# - Anne Tiotuico: 6
# - Jeff Slutz: 287
# - Seneca Widvey: 24
# - eric.duell: 31
# - Zach Hahn: 26
# - Matt Osminer: 47
# - Joe Parlett: 190
# - Ben Bonora: 83
# - Shubham Panday: 9
# - Mrinal Kaustuv: 98
# - Simon Davison: 297
# - Bryan Harris: 50
# - David Caballero: 482
# - Juan Reyes: 191
# - Erin Fink: 12
# - Terry Dougal: 291
# - Brian Miner: 22
# - Automation for Jira: 111
# - Jared Hanks: 16
# - Jason Cox: 174
# - Roger Williams: 64
# - Daniel.Newell: 114
# - Jere Jones: 46
# - mark white: 56
# - MeLissa Elwell: 75
# - Alec Sands: 60
# - stephen.smith: 69
# - Jonathan Duck: 170
# - Dennis Byford: 7
# - Mike Admire: 164
# - Raymond DeRoo: 97
# - Taylor Graham: 4
# - Chris Hodges: 171
# - Kenny Fakunle: 210
# - David Wright: 120
# - Tiffany Chow: 68
# - Sam Clark: 22
# - Phil Olson: 15
# - Eric Paul: 159
# - Ed Colgan: 10
# - Former user: 526
# - Nick Wheeler: 3
# - Keith.Sherwood: 37
# - Chris Strolia-Davis: 11
# - Amy Van Hook: 102
# - Jessica Levy: 1
# - Sabrina Szymczak: 31
# - Matt Macchia: 44
# - Tyla Mayo: 5
# - Eric Bee: 17
# - Aislinn Joyce: 12
# - satish kumar marana: 69
# - Dan Shepard: 80
# - AkashD: 11
# - Jerry Hill: 5
# - Ryan Hartman: 36
# - Brian Koehler: 13
# - Yuriy.kukhtin: 11
# - Leah.Laux: 96
# - Alejandro Benjumea: 2
# - Alejandro Ponce: 38
# - Alex Peguero-Cruz: 15
# - Alex Wilson: 24
# - Dewayne Korth: 112
# - Sherman Glass: 147
# - Alison Dougherty: 13
# - Amit Manocha: 1
# - Tommy O'Keefe: 67
# - Anas Ahmad: 27
# - Joel Stoker: 8
# - Dmytro Oliinyk: 6
# - Denys Loboda: 1
# - Jeff Naparstek: 16
# - Angel Cancio: 137
# - Tom Terry: 240
# - Johnathan Kulovitz: 136
# - Chris Ulmer: 52
# - Kiran Mawani: 6
# - Bolanle: 57
# - Vincent Ma: 28
# - Tiffany McKay: 11
# - Son Mai: 1
# - Gil Orellana: 37
# - kalyan.sudhakar: 10
# - stephanie.barulic: 32
# - Josiah Nosek: 5
# - Monika Spielman: 13
# - Christopher Caldwell: 1
# - Cullen Philippson: 231
# - Josh Currier: 69
# - Ryan Balsick: 12
# - Soban Akhter: 3
# - Kenny Lanza: 44
# - Joshua.Saunders: 13
# - Liz Brown: 5
# - kevin.warnock: 13
# - Chris Haggard: 3
# - Tim Browne: 83
# - jeremy.williams: 22
# - Carlos Zuniga Ballestero: 14
# - Tim Matyas: 116
# - Jeanette Neuner: 23
# - Sandhya Narasimharaj: 17
# - Steve Matysik: 4
# - Andres Oviedo: 5
# - Pablo Navarro: 4
# - Sireesha Maddineni: 1
# - Victoria Benecke: 267
# - Ramandeep Kaur: 23
# - Anton Anisimov: 1
# - Lindsey Allison: 4
# - Cris Stoddard: 24
# - David Caballero Miranda: 45
# - Austin Lane: 5
# - Rohini.Batchu: 37
# - Ebenezer: 45
# - Anaja.Metellus: 22
# - Nina Mischenko: 6
# - Tony Senes: 113
# - Beverly Lam: 17
# - bilal.waheed: 12
# - Nazar Lytvyn: 3
# - Ali Mir: 14
# - Bohdan.Herasymiv: 1
# - Ella Arana: 47
# - Eric Domingo: 4
# - Burhan Ud Din Muhammad: 1
# - William Young: 2
# - Taylor Joiner: 6
# - Fazila Ashraf: 3
# - Andy Drake: 40
# - Paige Nolan: 1
# - Joe HUBERT: 7
# - Marcos Nelson: 3
# - Chris Gatzke: 10
# - soban.khalid: 156
# - Todd Dolan: 2
# - Yosuf Monis: 3
# - Dominic Mendicino: 1
# - Ryan Hsu: 1
# - Aaron Wiley: 1
# - Kandarp Bhatt: 18
# - Jesse.Larson: 37
# - Sean Finley: 14
# - Muzdak Afzal: 168
# - John Callahan: 2
# - Mike Campobasso: 1
# - Pavel Novodvorskiy: 16
# - Brian Bosworth: 76
# - Crystal.Ju: 10
# - Justin Filion: 36
# - Matthew Lee: 5
# - Web Beveridge: 3
# - Dallin Nickle: 2
# - adil.maqsood: 5
# - sabrina.szymczak: 36
# - Yergeni Cabranes Perez: 4
# - Stanley Griggs: 6
# - Jason Hill: 7
# - Philip Johnson: 2
# - Katie Williams: 6
# - Henry Wadsworth: 3
# - Renato Bonicio: 7
# - Tsipora Gross: 5
# - Jonathan Sass: 21
# - Andres Mejias: 2
# - Dorin Onofrei: 9
# - Adrien.Carlson: 8
# - Linda Moi: 10
# - Priscila Nakazato: 8
# - Erika Moya: 11
# - Morgan Donovan: 5
# - Jessina Wong: 4
# - Nozima Botirova: 4
# - Brent Marquez: 1
# - Brad Dunnigan: 2
# - Max Campolo: 13
# - Brian Wagner: 7
# - Bryan.DeVries: 11
# - Ricky Harkins: 2
# - Cristhiam David Henao Moreno: 3
# - Christopher Dixon: 12
# - Jessica Hahn: 1
# - Volodymyr Synytsia: 4
# - Bailey Cavanaugh: 1
# - Luke Cori: 1
# - Amanda Hankel: 7
# - Todd Brochu: 5
# - Brian.Medley: 2
# - Jerimiah Baldwin: 3
# - Daniel Warshaw: 1
# - Sohaib Aslam: 215
# - Ken Lenga: 8
# - Elizabeth Jones: 20
# - Sai Tejaswi Bezawada: 1
# - Nebiyou Yismaw: 10
# - Bonaparte Ituze: 7
# - Ladd Hoffman: 9
# - Fadi Elkhatib: 22
# - Tyler Hyndman: 7
# - Brian Coursen: 32
# - Tony Istvan: 11
# - Beatriz Gonzalez: 1
# - Alex Bondar: 1
# - M Sheridan: 38
# - Jon West: 68
# - Harold Wilson: 7
# - Kurtis Moffett: 19
# - Jeremy Zevin: 6
# - Jessica Wells: 6
# - Roman Ostash: 18
# - leland kwong: 3
# - Nick Renford: 2
# - Marius Ngaboyamahina: 3
# - Juan Camilo Giraldo Chaverra: 2
# - Ferney Peña Rivillas: 3
# - Luis Felipe Bertel Mercado: 12
# - Julian Figueroa Torres: 5
# - Vincent Murr: 24
# - Alyssa.Roselli: 16
# - Markham Rollins: 55
# - John Martyniak: 42
# - Nicholas Booth: 14
# - Brian.hood: 2
# - Alejandro Chaves Orozco: 1
# - Jorge.Rodriguez: 3
# - Nate Luzod: 3
# - Keith Martin: 1
# - Gabe Rogan: 9
# - Bryan Jones: 2
# - Eric Serge Uwimana: 7
# - Gary Ivy: 2
# - Jill Montgomery: 126
# - Christian Tragesser: 2
# - Luis Ortiz Martinez: 1
# - Tyler Wardhaugh: 3
# - Michelle Benninghoven: 7
# - Davirlein Prada Devia: 2
# - Don.Furline: 6
# - Dwayne Steinway: 11
# - Jeremy Chase: 18
# - brent.bonet: 2
# - Jon Redick: 4
# - Ronald Porch: 4
# - Clement.beauvais: 1
# - Nathan Carmine: 7
# - Ben Leffler: 4
# - Chad: 21
# - Michael Zandstra: 9
# - Matt Zandstra: 1
# - Drew Cuthbertson: 1
# - Fabio Anselmo: 1
# - Sue-Mun.Huang@entercom.com: 10
# - John Pacino: 2
# - Sue-Mun Huang: 7
# - Jamie Lamberski: 8
# - Rachel Komeshak: 1
# - Rob Parker: 1
# - Zach Sheehan: 17
# - Omotola Enwe: 2
# - Jen Mercer: 74
# - Timmy Garrabrant: 1
# - Joel Flickinger: 15
# - Benji Bernstein: 1
# - Josh Hollandsworth: 1
# - Brian Blosser: 1
# - Jason Valladolid: 4
# - Vitaly Shoykhet: 2
# - Asim Javed: 21
# - automationforjira: 2
# - Leah Walker: 9
# - joshua.saunders: 4
# - Josh Wolfe: 8
# - Juan David Restrepo Toro: 1
# - Michelle Rivera: 1
# - Kristyn Howarth: 7
# - Laura Tejada Cardona: 2
# - Brad Scarlett: 7
# - Tracy Oxner: 3
# - Wes Johnson: 5
# - Michael.Estes: 2
# - Paul Brower: 4
# - Ganesh Bhanage: 1
# - Sharad Patel: 35
# - Amir.Eminov: 1
# - Roman Jimenez: 13
# - Saad Savari: 1
# - John Kenny: 1
# - Giovani Mombelli Mussio: 1
# - Pavel Ivanov: 4
# - Adnan Nasir: 3
# - Zaid Javed: 1
# - Bogdan Shkribliak: 3
# - Chelsea Johnston: 1
# - Hammad Daoud: 1
# - Mark Borcherding: 1
# - Nick Perrin: 1
# - Felix Curry: 1
# - Artur Kishinets: 2
# - Steven Perez: 5
# - Giuseppe Schiavello: 3
# - Serhii.Nikolaichuk: 1
# - Benji Rose: 1
# - christian.cotham: 1
# - Don Peters: 1
# - John Roman: 1
# - Jennifer Pearson: 2
# - Liliana Espinosa: 2
# - JD Bertron: 2
# - Nate Tussy: 2
# - Mark Coffey: 1
# - Duane Lee: 1
# - Justin Gibbemeyer: 5
# - Richard Kriheli: 3
# - Kelly Murphy: 1
# - Kevin Damazyn: 1
# - Weiang.Li: 2
# - Stephen Wolters: 1
# - Shala Warner: 1
# - Lilith Saer: 1
# - Jeffrey.Berest: 1
# - David Schwartz: 1
# - Steven Williams: 1
# - Michelle Arbeeny: 10
# - Sam Kim: 1
# - Chelsea Pereira: 1
# - John Morris: 1
# - Bolot K.: 1
# - Severyn Matsiak: 1
# - Joshua Pappalardo: 2
# - Andrew Dizenzo: 1
# - Thomas McCauley: 12
# - Rob McClain: 1
# - Tammy LaTier: 1
# - tom.schairer: 1
# - Jason Lowenthal-Hershey: 1
#
# Status Counts:
# - Released Successfully to Production: 2418
# - Done: 7217
# - Backlog: 9
# - Will Not Do: 1755
# - Plan Release: 18
# - In Progress: 27
# - ❌ Rolled Back: 56
# - On Hold: 7
# - Resource Constrained: 29
# - Blocked: 7
# - Post Implementation Review: 12
# - Prepare Release: 11
# - To Do: 52
# - Validating: 5
# - Tech Discovery Required: 10
# - Review Release Plan: 4
# - Technical Debt: 6
# - Build Release: 1
# - Test and Validate: 2
# - Triage: 49
#
# Issue Type Counts:
# - Change and Release: 3008
# - Task: 5169
# - Story: 2109
# - Feature: 405
# - Hotfix: 10
# - Sub-task: 214
# - Bug: 273
# - Legend: 24
# - Support: 410
# - Incident: 21
# - Security: 5
# - Improvement: 6
# - Post Mortem: 21
# - Change: 19
# - Regression: 1
#
# Script finished.

# %%
df_assignee = pd.DataFrame(assignee_counts.items(), columns=['Assignee', 'Count'])
df_assignee = df_assignee.sort_values(by='Count', ascending=False)
df_assignee.reset_index(drop=True, inplace=True)
print("\n--- Assignee Counts DataFrame ---")
df_assignee
# Out:
# --- Assignee Counts DataFrame ---
#               Assignee  Count
# 0           Unassigned   1628
# 1            Tom Terry   1171
# 2              Bolanle    796
# 3      David Caballero    617
# 4          Dan Shepard    573
# ..                 ...    ...
# 194  stephanie.barulic      1
# 195         Vincent Ma      1
# 196   Victoria Benecke      1
# 197      Web Beveridge      1
# 198    Vitaly Shoykhet      1
#
# [199 rows x 2 columns]

# %% [markdown]
# ## -- Distribution of Tickets per Assignee --

# %%
import seaborn as sns
# Set the seaborn style
sns.set(style="whitegrid")
# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Assignee', y='Count', data=df_assignee[df_assignee['Count'] > 50], palette='viridis')
plt.title('Assignee Counts Total')
plt.xlabel('Assignee')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/4021496809.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Assignee', y='Count', data=df_assignee[df_assignee['Count'] > 50], palette='viridis')

# %%
df_issues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8975 entries, 1 to 11694
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   key                    8975 non-null   object
#  1   id                     8975 non-null   object
#  2   summary                8975 non-null   object
#  3   status                 8975 non-null   object
#  4   issuetype              8975 non-null   object
#  5   creator_name           8975 non-null   object
#  6   assignee_name          8975 non-null   object
#  7   created                8975 non-null   object
#  8   updated                8975 non-null   object
#  9   project_name           8975 non-null   object
#  10  project_id             8975 non-null   object
#  11  priority_name          8975 non-null   object
#  12  priority_id            8975 non-null   object
#  13  project_due_date       8975 non-null   datetime64[ns, UTC-06:00]
#  14  issue_url              0 non-null      object
#  15  today                  8975 non-null   datetime64[ns, UTC-06:00]
#  16  days_old               8975 non-null   int64
#  17  year_updated           8975 non-null   int64
#  18  month_updated          8975 non-null   int64
#  19  year_created           8975 non-null   int64
#  20  month_created          8975 non-null   int64
#  21  last_updated_days      8975 non-null   int64
#  22  project_due_date_days  8975 non-null   int64
#  23  velocity               8975 non-null   int64
#  24  velocity_hours         8975 non-null   float64
#  25  velocity_days          8975 non-null   int64
#  26  target_end_date        1604 non-null   datetime64[ns, UTC]
#  27  bussiness_lead         8975 non-null   object
#  28  planning_rank          8975 non-null   object
#  29  portfolio_rank         0 non-null      datetime64[ns]
#  30  legend                 0 non-null      object
#  31  parent_project         0 non-null      object
#  32  parent                 4133 non-null   object
#  33  week                   8975 non-null   object
#  34  parent_str             8975 non-null   object
#  35  month                  8975 non-null   object
# dtypes: datetime64[ns, UTC-06:00](2), datetime64[ns, UTC](1), datetime64[ns](1), float64(1), int64(9), object(22)
# memory usage: 2.8+ MB

# %%
start_year = 2000
total_per_assignee_df = df_issues[df_issues['year_updated'] >= start_year ].groupby(['year_updated', 'month_updated','assignee_name']).agg(Total=('assignee_name', 'count')).sort_values(['year_updated', 'month_updated'])

# %%
total_per_assignee_df
# Out:
#                                                 Total
# year_updated month_updated assignee_name
# 2019         1             Former user              1
#                            Unassigned               2
#              2             Chad                     4
#                            Former user              8
#                            Unassigned               8
# ...                                               ...
# 2025         10            Unassigned              59
#                            sabrina.szymczak         1
#                            satish kumar marana      8
#                            scott.ennover            1
#                            simon.davison           14
#
# [1023 rows x 1 columns]

# %%
start_year = 2023
total_per_assignee_df = df_issues[df_issues['year_updated'] >= start_year ].groupby(['year_updated','assignee_name']).agg(Total=('assignee_name', 'count')).sort_values(['year_updated'])
# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(15, 10))

sns.barplot(x="assignee_name", y="Total", data=total_per_assignee_df[(total_per_assignee_df['Total'] > 5) & (total_per_assignee_df['Total'] < 300)],
            hue='year_updated', legend=True, color='green',palette='bright')


# Add a legend and informative axis label
#ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set_xlabel("Assignee Name")
ax.set_ylabel("No. of Tickets")
#ax.set_title("AWS Total Accumulated Cost by Services over " + "${:,.2f}".format(int(anual_cost)) + "\n")
ax.set_title("Total Tickets assigned by Assignee Name per Year \n")
#plt.xticks(rotation=90) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')
#ax.set_xticklabels(labels=services_df['Service'],rotation=45)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.set_major_locator(MultipleLocator(10))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.0f}".format(int(x))))
ax.legend(title='Year', loc='upper right')
#plt.savefig("AWS Yearly Cost by Service")
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/520573457.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='center')

# %%
start_year = 2020
total_per_year_df = df_issues[df_issues['year_updated'] >= start_year ].groupby(['year_updated']).agg(Total=('year_updated', 'count')).sort_values(['year_updated'])
# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(15, 10))

sns.barplot(x="year_updated", y="Total", data=total_per_year_df,
            hue='year_updated', legend=True, color='green',palette='bright')


# Add a legend and informative axis label
#ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set_xlabel("Calendar Year")
ax.set_ylabel("No. of Tickets")
#ax.set_title("AWS Total Accumulated Cost by Services over " + "${:,.2f}".format(int(anual_cost)) + "\n")
ax.set_title("Total Tickets Worked per Year \n")
#plt.xticks(rotation=90) 
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, ha='center')
#ax.set_xticklabels(labels=services_df['Service'],rotation=45)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.gca().yaxis.set_major_locator(MultipleLocator(100))
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,.0f}".format(int(x))))
ax.legend(title='Year', loc='upper left')
#plt.savefig("AWS Yearly Cost by Service")
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/3984111295.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=0, ha='center')

# %%
#df_issues[(df_issues['status'] == 'In Progress') & (df_issues['days_old'] < 365)]

# %%
#data = df_issues.groupby(['status','assignee_name'])['days_old'].mean().sort_values(ascending=False).copy()
sns.set(style="whitegrid")
plt.figure(figsize=(12, 6)) 
sns.barplot(x='assignee_name', y='days_old', data=df_issues[(df_issues['status'] == 'In Progress') & (df_issues['days_old'] < 365)], palette='viridis')
plt.title('Assignee Velocity (Days) - In Progress')
plt.xlabel('Assignee')
plt.ylabel('Velocity (Days)')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/1004839157.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='assignee_name', y='days_old', data=df_issues[(df_issues['status'] == 'In Progress') & (df_issues['days_old'] < 365)], palette='viridis')

# %%
df_creator = pd.DataFrame(issue_creator_counts.items(), columns=['creator', 'Count'])
df_creator = df_creator.sort_values(by='Count', ascending=False)
df_creator.reset_index(drop=True, inplace=True)
print("\n--- creator Counts DataFrame ---")
df_creator
# Out:
# --- creator Counts DataFrame ---
#                       creator  Count
# 0                 Former user    526
# 1                  Adam Shero    483
# 2             David Caballero    482
# 3    Zendesk Support for Jira    353
# 4               Simon Davison    297
# ..                        ...    ...
# 344            Andrew Dizenzo      1
# 345               Rob McClain      1
# 346              Tammy LaTier      1
# 347              tom.schairer      1
# 348   Jason Lowenthal-Hershey      1
#
# [349 rows x 2 columns]

# %%
import seaborn as sns
# Set the seaborn style
sns.set(style="whitegrid")
# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='creator', y='Count', data=df_creator[df_creator['Count'] > 50], palette='viridis')
plt.title('Creator Counts')
plt.xlabel('Creator')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/2755360980.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='creator', y='Count', data=df_creator[df_creator['Count'] > 50], palette='viridis')

# %%
df_issue_type = pd.DataFrame(issue_type_counts.items(), columns=['Issue Type', 'Count'])
df_issue_type = df_issue_type.sort_values(by='Count', ascending=False)
df_issue_type.reset_index(drop=True, inplace=True)
print("\n--- Issue Type Counts DataFrame ---")
df_issue_type
# Out:
# --- Issue Type Counts DataFrame ---
#             Issue Type  Count
# 0                 Task   5169
# 1   Change and Release   3008
# 2                Story   2109
# 3              Support    410
# 4              Feature    405
# 5                  Bug    273
# 6             Sub-task    214
# 7               Legend     24
# 8             Incident     21
# 9          Post Mortem     21
# 10              Change     19
# 11              Hotfix     10
# 12         Improvement      6
# 13            Security      5
# 14          Regression      1

# %%
import seaborn as sns
# Set the seaborn style
sns.set(style="whitegrid")
# Create a bar plot using seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x='Issue Type', y='Count', data=df_issue_type[df_issue_type['Count'] > 50], palette='viridis')
plt.title('Issue Type Counts')
plt.xlabel('Issue Type')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/bc/rbbb9nc96zd3bj2l2mq3klq00000gp/T/ipykernel_82100/3259829271.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Issue Type', y='Count', data=df_issue_type[df_issue_type['Count'] > 50], palette='viridis')

# %% [markdown]
# ## -- Custom Fields in Jira --

# %%
print("Fetching field definitions...")
all_fields = jira.fields()
custom_field_map = {field['id']: field['name'] for field in all_fields if field['custom']}
print("Field definitions fetched.")
# Out:
# Fetching field definitions...
# Field definitions fetched.

# %%
custom_field_map
# Out:
# {'customfield_10872': 'Mobile Platform',
#  'customfield_11720': 'Idea archived on',
#  'customfield_10873': 'Mobile Device Model',
#  'customfield_10500': 'Team',
#  'customfield_11719': 'Idea archived by',
#  'customfield_11718': 'Idea archived',
#  'customfield_10980': 'Planning Notes',
#  'customfield_10981': 'Reference',
#  'customfield_10862': 'QA',
#  'customfield_10975': 'Issues to be Load Tested',
#  'customfield_10976': 'Load Testing',
#  'customfield_10977': 'Request Type',
#  'customfield_10978': 'Request Type',
#  'customfield_10979': 'Fixed Version',
#  'customfield_11949': 'Rollback Category',
#  'customfield_10970': 'Defect Severity and Environment',
#  'customfield_10971': 'DevOps',
#  'customfield_10972': 'Program Manager',
#  'customfield_10962': 'Measurement & Analysis Plan',
#  'customfield_10963': 'Resources',
#  'customfield_10600': 'Organizations',
#  'customfield_10965': 'Assumptions and Constraints',
#  'customfield_10966': 'Risks and Mitigations',
#  'customfield_10967': 'Champion',
#  'customfield_10968': 'Estimated Size',
#  'customfield_10969': 'Scrum Master',
#  'customfield_10848': 'Issue color',
#  'customfield_11817': 'Deliverables',
#  'customfield_10960': 'Product Owner',
#  'customfield_10840': 'Business Owner(s)',
#  'customfield_10961': 'Business Case',
#  'customfield_10951': 'Incident Manager',
#  'customfield_10952': 'Incident Communication Manager',
#  'customfield_10953': 'Markets',
#  'customfield_10954': 'Station Callsign',
#  'customfield_10834': 'Start date',
#  'customfield_10955': 'Dependent Teams',
#  'customfield_10835': 'Acceptance Criteria',
#  'customfield_10956': 'Incident Impact',
#  'customfield_10836': 'Benefit Hypothesis',
#  'customfield_10957': 'Developer',
#  'customfield_10837': 'Request participants',
#  'customfield_10958': 'Sponsor',
#  'customfield_10838': 'Story point estimate',
#  'customfield_10959': 'Product Manager',
#  'customfield_10950': 'Incident Priority',
#  'customfield_10940': 'Type of Release',
#  'customfield_10941': 'Release Testing Description',
#  'customfield_10700': 'Request Type',
#  'customfield_10946': 'Target start',
#  'customfield_10947': 'Target end',
#  'customfield_10949': 'Incident Urgency',
#  'customfield_11916': 'Focus Areas',
#  'customfield_10930': 'Testing and Validation',
#  'customfield_10931': 'Date Released',
#  'customfield_10932': 'Associated Tickets',
#  'customfield_10933': 'Testing and Validation Plans',
#  'customfield_10934': 'Release Notes',
#  'customfield_10935': 'Acceptance Criteria',
#  'customfield_10936': 'Failed upon initial release',
#  'customfield_10937': 'CAR Priority',
#  'customfield_10938': 'CAR Urgency',
#  'customfield_10939': 'CAR Impact',
#  'customfield_10921': 'Checklist Text',
#  'customfield_10922': 'Risk Management',
#  'customfield_10923': 'Planned Release Date',
#  'customfield_10924': 'Stakeholders',
#  'customfield_10925': 'Product Manager Approval',
#  'customfield_10926': 'Product Owner/Engineering Lead Approval',
#  'customfield_10927': 'QA Approval',
#  'customfield_10928': 'Release Manager Approval',
#  'customfield_10929': 'Test and Validation Plans',
#  'customfield_10910': 'Design Status',
#  'customfield_10913': 'Architecture Review',
#  'customfield_10914': 'Reproducibility',
#  'customfield_10915': 'Bug Priority',
#  'customfield_10919': 'Checklist Completed',
#  'customfield_11441': 'Release Management Signoff',
#  'customfield_11320': 'Time Criticality',
#  'customfield_11685': 'Collaborators',
#  'customfield_11321': 'Opportunity Enablement',
#  'customfield_11200': 'Problem Statement',
#  'customfield_11322': 'Job Size',
#  'customfield_11201': 'How to get it done',
#  'customfield_11323': '---------------------',
#  'customfield_11445': 'Planning Rank',
#  'customfield_11202': 'Technical Implementation',
#  'customfield_11324': 'Time Taken in Backlog',
#  'customfield_11444': 'Links',
#  'customfield_11203': 'How to measure',
#  'customfield_11436': 'Time Zone',
#  'customfield_11435': 'Design',
#  'customfield_11316': 'Cost of Delay_',
#  'customfield_11437': 'EDE Description',
#  'customfield_11318': 'WSJF',
#  'customfield_11319': 'Business Value',
#  'customfield_11551': 'LOB',
#  'customfield_11550': 'Cumulative Burn %',
#  'customfield_11553': 'Release Space',
#  'customfield_10101': 'Steps to Reproduce',
#  'customfield_11552': 'Objectives',
#  'customfield_11312': 'Portfolio Rank',
#  'customfield_11303': 'Time Taken at Post Implementation Review',
#  'customfield_11545': 'Resource Estimate',
#  'customfield_11548': 'Invested',
#  'customfield_11427': 'Score',
#  'customfield_11547': 'Non-Resource Costs',
#  'customfield_11426': 'Insights impact',
#  'customfield_11784': 'Actual Dev Days',
#  'customfield_11300': 'Time Taken at Waiting for Approval',
#  'customfield_11544': 'Legend Space',
#  'customfield_11301': 'Time Taken at Prepare Release',
#  'customfield_11535': 'AR Number',
#  'customfield_11534': 'Merge Request',
#  'customfield_11413': 'Priority Score',
#  'customfield_11536': 'Original Story Points',
#  'customfield_11652': 'Project Type',
#  'customfield_10200': 'Approvals',
#  'customfield_11533': 'Allocation',
#  'customfield_11412': 'Insights impact',
#  'customfield_11883': 'Project Complete',
#  'customfield_11751': 'Business Lead',
#  'customfield_10300': 'Parent Link',
#  'customfield_10896': 'Rollout Process',
#  'customfield_10897': 'Rollback Strategy',
#  'customfield_10898': 'Risks',
#  'customfield_10899': 'Risk Mitigation',
#  'customfield_10890': 'Level of Risk',
#  'customfield_10891': 'Product(s)/Environment(s) Impacted',
#  'customfield_10892': 'Type of Changes',
#  'customfield_11982': 'Manager Approval Date',
#  'customfield_11860': 'Other: Internal Only',
#  'customfield_10893': 'Intended Results',
#  'customfield_11500': 'Product Sync Page',
#  'customfield_11854': 'New features: Internal Only',
#  'customfield_11853': 'New features: Audacy Only',
#  'customfield_11856': 'Bug Fixes: Audacy Only',
#  'customfield_11855': 'Bug Fixes: All',
#  'customfield_11858': 'Other: All',
#  'customfield_11857': 'Bug Fixes: Internal Only',
#  'customfield_11859': 'Other: Audacy Only',
#  'customfield_11619': 'Proposed Solution',
#  'customfield_11850': 'New features: All',
#  'customfield_10400': 'Development',
#  'customfield_10874': 'Frequency of Mobile Issue',
#  'customfield_11722': 'Atlassian project status',
#  'customfield_10995': 'Checklist Progress',
#  'customfield_11721': 'Atlassian project',
#  'customfield_10875': 'Severity of Mobile Issue',
#  'customfield_10996': 'Checklist Progress %',
#  'customfield_10876': 'Mobile App Version',
#  'customfield_11724': 'Comments',
#  'customfield_10997': 'Checklist Template',
#  'customfield_11723': 'Insights',
#  'customfield_10877': 'Satisfaction',
#  'customfield_10878': 'Satisfaction date',
#  'customfield_11726': 'Delivery progress',
#  'customfield_10999': 'Zendesk Ticket IDs',
#  'customfield_11725': 'Linked items',
#  'customfield_11727': 'Delivery status',
#  'customfield_11280': 'Time Taken at Validating',
#  'customfield_11160': 'Time to review normal change',
#  'customfield_11161': 'CDB Required',
#  'customfield_11162': 'ARB Required',
#  'customfield_11163': 'Sprint Iteration Release',
#  'customfield_11164': 'CoP Teams',
#  'customfield_11044': 'Expected Behavior',
#  'customfield_11165': 'Checklist Text (view-only)',
#  'customfield_11045': 'Actual Behavior',
#  'customfield_11167': 'Business Impact ',
#  'customfield_11168': 'User Impact ',
#  'customfield_11049': 'Bucket',
#  'customfield_11270': 'Time Taken at Product Backlog',
#  'customfield_11150': 'Actual start',
#  'customfield_11271': 'Time Taken at Ready for Grooming',
#  'customfield_11151': 'Actual end',
#  'customfield_11272': 'Time Taken at Ready for Implementation',
#  'customfield_11152': 'Investigation reason',
#  'customfield_11273': 'Time Taken at Requires Tech Discovery',
#  'customfield_11153': 'Root cause',
#  'customfield_11274': 'Time Taken at Requires Solution Architecture',
#  'customfield_11154': 'Workaround',
#  'customfield_11155': 'Responders',
#  'customfield_11156': 'Major incident',
#  'customfield_11157': 'Time to resolution',
#  'customfield_11158': 'Time to first response',
#  'customfield_11159': 'Time to close after resolution',
#  'customfield_11149': 'Planned end',
#  'customfield_11260': 'Time Taken at Backlog',
#  'customfield_11261': 'Time Taken at In Progress',
#  'customfield_11140': 'Severity',
#  'customfield_11262': 'Time Taken at Code Review',
#  'customfield_11141': 'Source',
#  'customfield_11263': 'Time Taken at QA Review',
#  'customfield_11142': 'Change type',
#  'customfield_11264': 'Time Taken at Staging',
#  'customfield_11143': 'Change risk',
#  'customfield_11265': 'Time Taken at Ready to Merge',
#  'customfield_11144': 'Change reason',
#  'customfield_11266': 'Time Taken at On Hold',
#  'customfield_11145': 'Implementation plan',
#  'customfield_11267': 'Time Taken at Blocked',
#  'customfield_11146': 'Backout plan',
#  'customfield_11147': 'Test plan',
#  'customfield_11268': 'Time Taken at Needs to be groomed',
#  'customfield_11148': 'Planned start',
#  'customfield_11259': 'End Date Auto',
#  'customfield_11138': 'Approver groups',
#  'customfield_11139': 'Affected hardware',
#  'customfield_11490': 'Feature Automation',
#  'customfield_11371': 'Time Taken in To Do',
#  'customfield_11370': 'Time Taken in Test and Validate',
#  'customfield_11250': 'Additional Information',
#  'customfield_11491': 'Product Sync Notes',
#  'customfield_11373': 'Time Taken in Validating',
#  'customfield_11494': 'Goals',
#  'customfield_11130': 'Engineering CoP Lead',
#  'customfield_11372': 'Time Taken in Triage',
#  'customfield_11493': 'Strategic Theme',
#  'customfield_11131': 'Work category',
#  'customfield_11253': 'Required Staff',
#  'customfield_11375': 'Release Impact',
#  'customfield_11132': 'Urgency',
#  'customfield_11254': 'Release Notes',
#  'customfield_11495': 'Pre-Deployment Communication Plan',
#  'customfield_11133': 'Impact',
#  'customfield_11255': 'Total Hours',
#  'customfield_11377': 'Planned Devs',
#  'customfield_11134': 'Pending reason',
#  'customfield_11497': 'Operational Readiness Plan',
#  'customfield_11256': 'Sprint Count',
#  'customfield_11135': 'Product categorization',
#  'customfield_11376': 'Total Business Hours',
#  'customfield_11257': 'Total Time (hours)',
#  'customfield_11136': 'Operational categorization',
#  'customfield_11499': 'Target Release',
#  'customfield_11258': 'Start Date Auto',
#  'customfield_11137': 'Approvers',
#  'customfield_11378': 'Committed Date',
#  'customfield_11369': 'Time Taken in Technical Discovery',
#  'customfield_11360': 'Time Taken in Ready for Story Writing',
#  'customfield_11362': 'Time Taken in Ready for UAT',
#  'customfield_11361': 'Time Taken in Ready for Testing',
#  'customfield_11364': 'Time Taken in Requires Solution Architecture',
#  'customfield_11000': 'Zendesk Ticket Count',
#  'customfield_11363': 'Time Taken in Ready to Merge',
#  'customfield_11243': 'Post Deployment Signoff',
#  'customfield_11001': 'Priority Order',
#  'customfield_11366': 'Time Taken in Review Release Plan',
#  'customfield_11244': 'Project overview key',
#  'customfield_11487': 'Stakeholders',
#  'customfield_11365': 'Time Taken in Requires Tech Discovery',
#  'customfield_11245': 'Project overview status',
#  'customfield_11486': 'Secondary Architect',
#  'customfield_11368': 'Time Taken in Staging',
#  'customfield_11489': 'Sentiment',
#  'customfield_11246': 'Service Category',
#  'customfield_11367': 'Time Taken in Staged',
#  'customfield_11488': 'Slack Channel',
#  'customfield_11247': 'Project Details',
#  'customfield_11359': 'Time Taken in Ready for Refinement',
#  'customfield_11237': 'KPIs',
#  'customfield_11358': 'Time Taken in Ready for QA',
#  'customfield_11238': 'Delivery Impact(s)',
#  'customfield_11239': 'Health Context',
#  'customfield_11351': 'Time Taken in QA',
#  'customfield_11350': 'Time Taken in PR Review',
#  'customfield_11231': 'Remaining Story Points',
#  'customfield_11352': 'Time Taken in QA Review',
#  'customfield_11232': 'Design Number of Days',
#  'customfield_11112': 'Quarters',
#  'customfield_11233': 'Dev Number of Days',
#  'customfield_11113': 'Teams',
#  'customfield_11234': 'QA Number of Days',
#  'customfield_11357': 'Time Taken in Ready for Planning',
#  'customfield_11114': 'Public description',
#  'customfield_11235': 'Reason for Delivery Impact',
#  'customfield_11115': 'Key customers',
#  'customfield_11236': 'Hypotheses',
#  'customfield_11226': 'Development Start',
#  'customfield_11348': 'Time Taken in Product Backlog',
#  'customfield_11105': 'Short description',
#  'customfield_11227': 'Development End',
#  'customfield_11347': 'Time Taken in Prioritized',
#  'customfield_11106': 'Theme',
#  'customfield_11107': 'Effort',
#  'customfield_11349': 'Time Taken in Product & Design Discovery',
#  'customfield_11109': 'Goal impact',
#  'customfield_11340': 'Time Taken in Launch',
#  'customfield_11220': 'Design Start',
#  'customfield_10010': 'Epic Status',
#  'customfield_11342': 'Time Taken in Needs to be groomed',
#  'customfield_11221': 'Design End',
#  'customfield_10011': 'Epic Color',
#  'customfield_11341': 'Time Taken in Merged to Feature Branch',
#  'customfield_11222': 'Development Start',
#  'customfield_10012': 'Rank',
#  'customfield_11586': 'OpEx',
#  'customfield_11344': 'Time Taken in Plan Release',
#  'customfield_11102': 'Bucket',
#  'customfield_11343': 'Time Taken in On Hold',
#  'customfield_11224': 'QA Start',
#  'customfield_11103': 'Goal',
#  'customfield_11346': 'Time Taken in Prepare Release',
#  'customfield_11225': 'QA End',
#  'customfield_11104': 'Roadmap',
#  'customfield_11345': 'Time Taken in Post Implementation Review',
#  'customfield_11337': 'Time Taken in Epic Creation',
#  'customfield_11215': 'Microservice(s)',
#  'customfield_10005': 'Story Points',
#  'customfield_11336': 'Time Taken in Deploy Release',
#  'customfield_11216': 'Confidence Vote',
#  'customfield_10006': 'Business Value',
#  'customfield_11217': 'Projected Sprint Delivery',
#  'customfield_10007': 'Sprint',
#  'customfield_11339': 'Time Taken in In Progress',
#  'customfield_11218': 'QA Signoff',
#  'customfield_10008': 'Epic Name',
#  'customfield_11338': 'Time Taken in Implementation',
#  'customfield_11219': 'Manager Signoff',
#  'customfield_10009': 'Epic Link',
#  'customfield_11450': 'Rollback Date/Time',
#  'customfield_11331': 'Time Taken in Blocked for Development',
#  'customfield_11330': 'Time Taken in Blocked',
#  'customfield_10000': '[CHART] Date of First Response',
#  'customfield_11333': 'Time Taken in Build Release',
#  'customfield_11454': 'Developers',
#  'customfield_10001': '[CHART] Time in Status',
#  'customfield_11332': 'Time Taken in Build',
#  'customfield_11335': 'Time Taken in Deploying to Production',
#  'customfield_11213': 'Project Health',
#  'customfield_10003': 'Flagged',
#  'customfield_11334': 'Time Taken in Code Review',
#  'customfield_11214': 'QA Notes',
#  'customfield_11326': 'Time Taken in Approved for Development',
#  'customfield_11447': 'Rollback',
#  'customfield_11204': 'Team',
#  'customfield_11325': 'Time Taken in Analysis & Design',
#  'customfield_11446': 'Vulnerability',
#  'customfield_11205': 'Performance',
#  'customfield_11328': 'Time Taken in Awaiting Priorization',
#  'customfield_11206': 'Process and Product',
#  'customfield_11449': 'Arch Estimated Size',
#  'customfield_11327': 'Time Taken in Architecture Review',
#  'customfield_11207': 'Test Fix Version List',
#  'customfield_11448': 'Testing checks',
#  'customfield_11208': 'External issue ID',
#  'customfield_11329': 'Time Taken in Awaiting Review',
#  'customfield_11209': 'Estimated Potential User Downtime',
#  'customfield_10901': 'Date/Time of Change',
#  'customfield_10902': 'Duration of Change',
#  'customfield_11082': 'Watchers',
#  'customfield_11083': 'Engineering Reviewed',
#  'customfield_11085': 'Delivery Confidence',
#  'customfield_11086': 'Confidence ',
#  'customfield_11190': 'Challenge(s)',
#  'customfield_11191': 'Engineering Lead',
#  'customfield_11192': 'Architect',
#  'customfield_11193': 'Product Lead',
#  'customfield_11195': 'Approvals',
#  'customfield_11196': 'Dev Teams',
#  'customfield_11075': 'Target Release',
#  'customfield_11076': 'Team',
#  'customfield_11197': 'Design Links',
#  'customfield_11077': 'Engineering Status',
#  'customfield_11198': 'Version',
#  'customfield_11078': 'Goal',
#  'customfield_11199': 'Cost of Delay',
#  'customfield_11180': 'Priority Order',
#  'customfield_11060': 'Teams',
#  'customfield_11182': 'Category',
#  'customfield_11061': 'Public description',
#  'customfield_11183': 'Label',
#  'customfield_11062': 'Key customers',
#  'customfield_11184': 'Core Objective(s)',
#  'customfield_11063': 'Original Requirement Area',
#  'customfield_11185': 'KPI(s)',
#  'customfield_11064': 'Product Management Team',
#  'customfield_11186': 'Target Cohort(s)',
#  'customfield_11065': 'Design Status',
#  'customfield_11187': 'Creative & Copy',
#  'customfield_11188': 'Target Launch',
#  'customfield_11067': 'Request language',
#  'customfield_11189': 'Learnings',
#  'customfield_11068': 'Affected services',
#  'customfield_11069': 'Scenario',
#  'customfield_11051': 'Roadmap',
#  'customfield_11172': 'Solution',
#  'customfield_11052': 'Short description',
#  'customfield_11173': 'Open forms',
#  'customfield_11295': 'Time Taken at Plan Release',
#  'customfield_11053': 'Theme',
#  'customfield_11174': 'Submitted forms',
#  'customfield_11296': 'Time Taken at Review Release Plan',
#  'customfield_11054': 'Engineering Effort',
#  'customfield_11175': 'Locked forms',
#  'customfield_11297': 'Time Taken at Build Release',
#  'customfield_11176': 'Total forms',
#  'customfield_11298': 'Time Taken at Test and Validate',
#  'customfield_11177': 'Requirements Area',
#  'customfield_11299': 'Time Taken at QA SIgnoff',
#  'customfield_11059': 'Quarters'}

# %% [markdown]
# # End of the CODE!!!

# %%
print("END OF THE CODE Success#ful !!! at", datetime.now())
# Out:
# END OF THE CODE Success#ful !!! at 2025-10-28 08:52:41.248288

# %%
print(datetime.now())
# Out:
# 2025-10-28 08:52:41.316013

# %%
print("Completed!!!!")
# Out:
# Completed!!!!

# %% [markdown]
# CAPACITY, TREND AND VELOCITY
#
# IN PROGRESS WITH NO DATES OR BEHIND SCHEDULE
#
# VALIDATING
#
# BLOCKED
#
# BACKLOG
#
# older than 50 days
#
# older than 50 days on tech discovery
#
# FORECAST
#
# DISTRIBUTION OF TICKET'S AGE
#
# DISTRIBUTION OF TICKETS PER BUSINESS LEADER.
#
#  CLOUD WORD
